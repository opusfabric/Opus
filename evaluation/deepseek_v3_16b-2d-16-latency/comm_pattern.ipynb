# %%
import re
import argparse
import os
import datetime

# backend 0 default, backend 1 pp, backend 2, 5, 6 DP, backend 3 TP

def custom_print(message, file_path=None, mode='a'):
    print(message)  # Print to terminal
    if file_path:
        with open(file_path, mode) as file:
            file.write(message + '\n')

def backend_to_comm_type(backend, rank_tid=None):
    if backend == 0:
        return "Default"
    elif backend % 10 == 1:
        return "PP"
    # elif backend in [2, 5, 6]:
    #     return "DP"
    elif backend == 2:
        return "TP"
    else:
        return "unknown"

def time_to_ms(t):
    return (
        t.hour * 3600_000 +
        t.minute * 60_000 +
        t.second * 1000 +
        t.microsecond / 1000.0
    )
    
def calculate_pp_backend(backend, pp_comm_group = -1):
    if pp_comm_group == -1:
        return backend
    else:
        return pp_comm_group * 10 + backend
    
def is_same_comm_type(backend1, backend2):
    if backend1 is None or backend2 is None:
        return False
    type1 = backend_to_comm_type(backend1)
    type2 = backend_to_comm_type(backend2)

    if type1 == type2 and type1 == "PP":
        return backend1 == backend2
    
    return type1 == type2


def parse_communication_pattern(log_file, rank_tid):
    pattern = re.compile(r"\x1b\[[0-9;]*m?Backend (\d+) RANK (\d+) tid: (\d+).*?Idx: (\d+), issuing")
    # pattern = re.compile(r"\x1b\[[0-9;]*m?Backend (\d+) RANK (\d+) tid: (\d+).*? pre_coll, Idx: (\d+)")
    communication_pattern = []

    time_pat = re.compile(
        r"t:\[(\d+:\d+:\d+\.\d+)\]"
    )

    with open(log_file, 'r') as file:
        start_backend = None
        idx_list = None
        end_backend = None

        start_time = None
        end_time = None

        # Track per-idx timestamps
        idx_start_times = {}
        idx_end_times = {}

        time_gap = {}

        for line in file:
            match = pattern.search(line)
            if match:
                backend = int(match.group(1))
                tid = int(match.group(3))
                idx = int(match.group(4))

                # Check if the line contains "PP comm group"
                pp_comm_group_match = re.search(r"PP comm group: (\d+)", line)
                if pp_comm_group_match:
                    pp_comm_group = int(pp_comm_group_match.group(1))
                else:
                    pp_comm_group = -1

                # remove TP traffic and backend 0 traffic, PP allreduce traffic
                if backend_to_comm_type(backend) == "TP" or backend == 0:
                    continue
                if backend_to_comm_type(backend) == "PP" and "allreduce" in line:
                    continue

                if (backend == 1):
                    assert(pp_comm_group != -1)
                    backend = calculate_pp_backend(backend, pp_comm_group) # has information of pp group

                # extract timestamp if present
                tmatch = time_pat.search(line)
                ts = None
                if tmatch:
                    ts = datetime.datetime.strptime(tmatch.group(1), "%H:%M:%S.%f")
                    ts = time_to_ms(ts)

                # record pre/post timestamps
                # if "pre_coll" in line and ts:
                
                #     idx_start_times[(backend, idx)] = ts
                # elif "post_coll" in line and ts:
                #     idx_end_times[(backend, idx)] = ts

                if tid == rank_tid:
                    if not is_same_comm_type(backend, start_backend):
                        # transition to a new backend
                        if start_backend is not None:
                            communication_pattern.append((start_backend, idx_list, end_backend))
                        start_backend = backend
                        idx_list = [idx]
                        end_backend = backend
                    else:
                        idx_list.append(idx)
                        end_backend = backend

        # Append the last backend, rank, and idx
        if start_backend is not None:
            communication_pattern.append((start_backend, idx_list, end_backend))

    return communication_pattern

def get_rank_tid(log_file, node_id, num_local_ranks):
    pattern = re.compile(r"Backend 0 RANK (\d+) tid: (\d+)")
    with open(log_file, 'r') as file:
        for line in file:
            match = pattern.search(line)
            if match:
                backend = int(match.group(1))
                tid = int(match.group(2))
                return [tid] * num_local_ranks  # Assuming all local ranks share the same pattern
    raise ValueError(f"No matching line found in log file {log_file}")

# List all files in the folder that match the pattern torchrun_nid*
log_folder = "<path-to-opus>/Opus/torchtitan/opus-test/deepseek-pp-4-tp-4-pm/output-opus-l_0-no-ctl/"
torchrun_files = [f for f in os.listdir(log_folder) if f.startswith("torchrun_nid")]
torchrun_files.sort()

print(torchrun_files)
num_local_ranks = 4

output_folder = "comm_pattern"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for i, log_file in enumerate(torchrun_files):
    log_file_full_path = os.path.join(log_folder, log_file)
    rank_tid_list = get_rank_tid(log_file_full_path, i, num_local_ranks)
    print(rank_tid_list)

    for rank, tid in enumerate(rank_tid_list):
        # rank is local rank
        output_file = f"{output_folder}/comm_pattern_{i}_rank{rank}.txt"
        # Clean the output file before writing
        with open(output_file, 'w') as file:
            file.truncate(0)
        custom_print(f"Node: {i}, Rank: {rank}, Tid: {tid}", output_file)
        pattern = parse_communication_pattern(log_file_full_path, tid)

        for backend, idx_list, end_backend in pattern:
            custom_print(f"{backend_to_comm_type(backend)} start_backend: {backend} start_idx: {idx_list[0]} end_backend: {end_backend} end_idx: {idx_list[-1]} len: {len(idx_list)}", output_file)
# Out:
# ['torchrun_nid001024.ans', 'torchrun_nid001029.ans', 'torchrun_nid200377.ans', 'torchrun_nid200380.ans']
# [139736130148160, 139736130148160, 139736130148160, 139736130148160]
# Node: 0, Rank: 0, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84
# Node: 0, Rank: 1, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84
# Node: 0, Rank: 2, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84
# Node: 0, Rank: 3, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84
# [139842750940992, 139842750940992, 139842750940992, 139842750940992]
# Node: 1, Rank: 0, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1
# PP start_backend: 11 start_idx: 1000002 end_backend: 11 end_idx: 1000003 len: 2
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2
# PP start_backend: 11 start_idx: 1000004 end_backend: 11 end_idx: 1000004 len: 1
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1
# PP start_backend: 11 start_idx: 1000005 end_backend: 11 end_idx: 1000005 len: 1
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1
# PP start_backend: 11 start_idx: 1000006 end_backend: 11 end_idx: 1000006 len: 1
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2
# PP start_backend: 11 start_idx: 1000007 end_backend: 11 end_idx: 1000008 len: 2
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2
# PP start_backend: 11 start_idx: 1000009 end_backend: 11 end_idx: 1000009 len: 1
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1
# PP start_backend: 11 start_idx: 1000010 end_backend: 11 end_idx: 1000010 len: 1
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000011 len: 1
# PP start_backend: 11 start_idx: 1000011 end_backend: 11 end_idx: 1000012 len: 2
# PP start_backend: 21 start_idx: 2000012 end_backend: 21 end_idx: 2000012 len: 1
# PP start_backend: 11 start_idx: 1000013 end_backend: 11 end_idx: 1000013 len: 1
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1
# PP start_backend: 11 start_idx: 1000014 end_backend: 11 end_idx: 1000014 len: 1
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2
# PP start_backend: 11 start_idx: 1000015 end_backend: 11 end_idx: 1000016 len: 2
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2
# PP start_backend: 11 start_idx: 1000017 end_backend: 11 end_idx: 1000017 len: 1
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1
# PP start_backend: 11 start_idx: 1000018 end_backend: 11 end_idx: 1000018 len: 1
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000019 len: 1
# PP start_backend: 11 start_idx: 1000019 end_backend: 11 end_idx: 1000020 len: 2
# PP start_backend: 21 start_idx: 2000020 end_backend: 21 end_idx: 2000020 len: 1
# PP start_backend: 11 start_idx: 1000021 end_backend: 11 end_idx: 1000021 len: 1
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1
# PP start_backend: 11 start_idx: 1000022 end_backend: 11 end_idx: 1000022 len: 1
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2
# PP start_backend: 11 start_idx: 1000023 end_backend: 11 end_idx: 1000024 len: 2
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2
# PP start_backend: 11 start_idx: 1000025 end_backend: 11 end_idx: 1000025 len: 1
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1
# PP start_backend: 11 start_idx: 1000026 end_backend: 11 end_idx: 1000026 len: 1
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000027 len: 1
# PP start_backend: 11 start_idx: 1000027 end_backend: 11 end_idx: 1000028 len: 2
# PP start_backend: 21 start_idx: 2000028 end_backend: 21 end_idx: 2000028 len: 1
# PP start_backend: 11 start_idx: 1000029 end_backend: 11 end_idx: 1000029 len: 1
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1
# PP start_backend: 11 start_idx: 1000030 end_backend: 11 end_idx: 1000030 len: 1
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2
# PP start_backend: 11 start_idx: 1000031 end_backend: 11 end_idx: 1000032 len: 2
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2
# PP start_backend: 11 start_idx: 1000033 end_backend: 11 end_idx: 1000033 len: 1
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1
# PP start_backend: 11 start_idx: 1000034 end_backend: 11 end_idx: 1000034 len: 1
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000035 len: 1
# PP start_backend: 11 start_idx: 1000035 end_backend: 11 end_idx: 1000036 len: 2
# PP start_backend: 21 start_idx: 2000036 end_backend: 21 end_idx: 2000036 len: 1
# PP start_backend: 11 start_idx: 1000037 end_backend: 11 end_idx: 1000037 len: 1
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1
# PP start_backend: 11 start_idx: 1000038 end_backend: 11 end_idx: 1000038 len: 1
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2
# PP start_backend: 11 start_idx: 1000039 end_backend: 11 end_idx: 1000040 len: 2
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2
# PP start_backend: 11 start_idx: 1000041 end_backend: 11 end_idx: 1000041 len: 1
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1
# PP start_backend: 11 start_idx: 1000042 end_backend: 11 end_idx: 1000042 len: 1
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000043 len: 1
# PP start_backend: 11 start_idx: 1000043 end_backend: 11 end_idx: 1000044 len: 2
# PP start_backend: 21 start_idx: 2000044 end_backend: 21 end_idx: 2000044 len: 1
# PP start_backend: 11 start_idx: 1000045 end_backend: 11 end_idx: 1000045 len: 1
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1
# PP start_backend: 11 start_idx: 1000046 end_backend: 11 end_idx: 1000046 len: 1
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2
# PP start_backend: 11 start_idx: 1000047 end_backend: 11 end_idx: 1000048 len: 2
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2
# PP start_backend: 11 start_idx: 1000049 end_backend: 11 end_idx: 1000049 len: 1
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1
# PP start_backend: 11 start_idx: 1000050 end_backend: 11 end_idx: 1000050 len: 1
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000051 len: 1
# PP start_backend: 11 start_idx: 1000051 end_backend: 11 end_idx: 1000052 len: 2
# PP start_backend: 21 start_idx: 2000052 end_backend: 21 end_idx: 2000052 len: 1
# PP start_backend: 11 start_idx: 1000053 end_backend: 11 end_idx: 1000053 len: 1
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1
# PP start_backend: 11 start_idx: 1000054 end_backend: 11 end_idx: 1000054 len: 1
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2
# PP start_backend: 11 start_idx: 1000055 end_backend: 11 end_idx: 1000056 len: 2
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2
# PP start_backend: 11 start_idx: 1000057 end_backend: 11 end_idx: 1000057 len: 1
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1
# PP start_backend: 11 start_idx: 1000058 end_backend: 11 end_idx: 1000058 len: 1
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000059 len: 1
# PP start_backend: 11 start_idx: 1000059 end_backend: 11 end_idx: 1000060 len: 2
# PP start_backend: 21 start_idx: 2000060 end_backend: 21 end_idx: 2000060 len: 1
# PP start_backend: 11 start_idx: 1000061 end_backend: 11 end_idx: 1000061 len: 1
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1
# PP start_backend: 11 start_idx: 1000062 end_backend: 11 end_idx: 1000062 len: 1
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2
# PP start_backend: 11 start_idx: 1000063 end_backend: 11 end_idx: 1000064 len: 2
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2
# PP start_backend: 11 start_idx: 1000065 end_backend: 11 end_idx: 1000065 len: 1
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1
# PP start_backend: 11 start_idx: 1000066 end_backend: 11 end_idx: 1000066 len: 1
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000067 len: 1
# PP start_backend: 11 start_idx: 1000067 end_backend: 11 end_idx: 1000068 len: 2
# PP start_backend: 21 start_idx: 2000068 end_backend: 21 end_idx: 2000068 len: 1
# PP start_backend: 11 start_idx: 1000069 end_backend: 11 end_idx: 1000069 len: 1
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1
# PP start_backend: 11 start_idx: 1000070 end_backend: 11 end_idx: 1000070 len: 1
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2
# PP start_backend: 11 start_idx: 1000071 end_backend: 11 end_idx: 1000072 len: 2
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2
# PP start_backend: 11 start_idx: 1000073 end_backend: 11 end_idx: 1000073 len: 1
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1
# PP start_backend: 11 start_idx: 1000074 end_backend: 11 end_idx: 1000074 len: 1
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000075 len: 1
# PP start_backend: 11 start_idx: 1000075 end_backend: 11 end_idx: 1000076 len: 2
# PP start_backend: 21 start_idx: 2000076 end_backend: 21 end_idx: 2000076 len: 1
# PP start_backend: 11 start_idx: 1000077 end_backend: 11 end_idx: 1000077 len: 1
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1
# PP start_backend: 11 start_idx: 1000078 end_backend: 11 end_idx: 1000078 len: 1
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2
# PP start_backend: 11 start_idx: 1000079 end_backend: 11 end_idx: 1000080 len: 2
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2
# PP start_backend: 11 start_idx: 1000081 end_backend: 11 end_idx: 1000081 len: 1
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1
# PP start_backend: 11 start_idx: 1000082 end_backend: 11 end_idx: 1000082 len: 1
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1
# PP start_backend: 11 start_idx: 1000083 end_backend: 11 end_idx: 1000083 len: 1
# Node: 1, Rank: 1, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1
# PP start_backend: 11 start_idx: 1000002 end_backend: 11 end_idx: 1000003 len: 2
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2
# PP start_backend: 11 start_idx: 1000004 end_backend: 11 end_idx: 1000004 len: 1
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1
# PP start_backend: 11 start_idx: 1000005 end_backend: 11 end_idx: 1000005 len: 1
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1
# PP start_backend: 11 start_idx: 1000006 end_backend: 11 end_idx: 1000006 len: 1
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2
# PP start_backend: 11 start_idx: 1000007 end_backend: 11 end_idx: 1000008 len: 2
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2
# PP start_backend: 11 start_idx: 1000009 end_backend: 11 end_idx: 1000009 len: 1
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1
# PP start_backend: 11 start_idx: 1000010 end_backend: 11 end_idx: 1000010 len: 1
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000011 len: 1
# PP start_backend: 11 start_idx: 1000011 end_backend: 11 end_idx: 1000012 len: 2
# PP start_backend: 21 start_idx: 2000012 end_backend: 21 end_idx: 2000012 len: 1
# PP start_backend: 11 start_idx: 1000013 end_backend: 11 end_idx: 1000013 len: 1
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1
# PP start_backend: 11 start_idx: 1000014 end_backend: 11 end_idx: 1000014 len: 1
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2
# PP start_backend: 11 start_idx: 1000015 end_backend: 11 end_idx: 1000016 len: 2
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2
# PP start_backend: 11 start_idx: 1000017 end_backend: 11 end_idx: 1000017 len: 1
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1
# PP start_backend: 11 start_idx: 1000018 end_backend: 11 end_idx: 1000018 len: 1
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000019 len: 1
# PP start_backend: 11 start_idx: 1000019 end_backend: 11 end_idx: 1000020 len: 2
# PP start_backend: 21 start_idx: 2000020 end_backend: 21 end_idx: 2000020 len: 1
# PP start_backend: 11 start_idx: 1000021 end_backend: 11 end_idx: 1000021 len: 1
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1
# PP start_backend: 11 start_idx: 1000022 end_backend: 11 end_idx: 1000022 len: 1
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2
# PP start_backend: 11 start_idx: 1000023 end_backend: 11 end_idx: 1000024 len: 2
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2
# PP start_backend: 11 start_idx: 1000025 end_backend: 11 end_idx: 1000025 len: 1
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1
# PP start_backend: 11 start_idx: 1000026 end_backend: 11 end_idx: 1000026 len: 1
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000027 len: 1
# PP start_backend: 11 start_idx: 1000027 end_backend: 11 end_idx: 1000028 len: 2
# PP start_backend: 21 start_idx: 2000028 end_backend: 21 end_idx: 2000028 len: 1
# PP start_backend: 11 start_idx: 1000029 end_backend: 11 end_idx: 1000029 len: 1
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1
# PP start_backend: 11 start_idx: 1000030 end_backend: 11 end_idx: 1000030 len: 1
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2
# PP start_backend: 11 start_idx: 1000031 end_backend: 11 end_idx: 1000032 len: 2
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2
# PP start_backend: 11 start_idx: 1000033 end_backend: 11 end_idx: 1000033 len: 1
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1
# PP start_backend: 11 start_idx: 1000034 end_backend: 11 end_idx: 1000034 len: 1
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000035 len: 1
# PP start_backend: 11 start_idx: 1000035 end_backend: 11 end_idx: 1000036 len: 2
# PP start_backend: 21 start_idx: 2000036 end_backend: 21 end_idx: 2000036 len: 1
# PP start_backend: 11 start_idx: 1000037 end_backend: 11 end_idx: 1000037 len: 1
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1
# PP start_backend: 11 start_idx: 1000038 end_backend: 11 end_idx: 1000038 len: 1
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2
# PP start_backend: 11 start_idx: 1000039 end_backend: 11 end_idx: 1000040 len: 2
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2
# PP start_backend: 11 start_idx: 1000041 end_backend: 11 end_idx: 1000041 len: 1
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1
# PP start_backend: 11 start_idx: 1000042 end_backend: 11 end_idx: 1000042 len: 1
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000043 len: 1
# PP start_backend: 11 start_idx: 1000043 end_backend: 11 end_idx: 1000044 len: 2
# PP start_backend: 21 start_idx: 2000044 end_backend: 21 end_idx: 2000044 len: 1
# PP start_backend: 11 start_idx: 1000045 end_backend: 11 end_idx: 1000045 len: 1
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1
# PP start_backend: 11 start_idx: 1000046 end_backend: 11 end_idx: 1000046 len: 1
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2
# PP start_backend: 11 start_idx: 1000047 end_backend: 11 end_idx: 1000048 len: 2
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2
# PP start_backend: 11 start_idx: 1000049 end_backend: 11 end_idx: 1000049 len: 1
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1
# PP start_backend: 11 start_idx: 1000050 end_backend: 11 end_idx: 1000050 len: 1
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000051 len: 1
# PP start_backend: 11 start_idx: 1000051 end_backend: 11 end_idx: 1000052 len: 2
# PP start_backend: 21 start_idx: 2000052 end_backend: 21 end_idx: 2000052 len: 1
# PP start_backend: 11 start_idx: 1000053 end_backend: 11 end_idx: 1000053 len: 1
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1
# PP start_backend: 11 start_idx: 1000054 end_backend: 11 end_idx: 1000054 len: 1
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2
# PP start_backend: 11 start_idx: 1000055 end_backend: 11 end_idx: 1000056 len: 2
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2
# PP start_backend: 11 start_idx: 1000057 end_backend: 11 end_idx: 1000057 len: 1
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1
# PP start_backend: 11 start_idx: 1000058 end_backend: 11 end_idx: 1000058 len: 1
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000059 len: 1
# PP start_backend: 11 start_idx: 1000059 end_backend: 11 end_idx: 1000060 len: 2
# PP start_backend: 21 start_idx: 2000060 end_backend: 21 end_idx: 2000060 len: 1
# PP start_backend: 11 start_idx: 1000061 end_backend: 11 end_idx: 1000061 len: 1
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1
# PP start_backend: 11 start_idx: 1000062 end_backend: 11 end_idx: 1000062 len: 1
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2
# PP start_backend: 11 start_idx: 1000063 end_backend: 11 end_idx: 1000064 len: 2
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2
# PP start_backend: 11 start_idx: 1000065 end_backend: 11 end_idx: 1000065 len: 1
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1
# PP start_backend: 11 start_idx: 1000066 end_backend: 11 end_idx: 1000066 len: 1
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000067 len: 1
# PP start_backend: 11 start_idx: 1000067 end_backend: 11 end_idx: 1000068 len: 2
# PP start_backend: 21 start_idx: 2000068 end_backend: 21 end_idx: 2000068 len: 1
# PP start_backend: 11 start_idx: 1000069 end_backend: 11 end_idx: 1000069 len: 1
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1
# PP start_backend: 11 start_idx: 1000070 end_backend: 11 end_idx: 1000070 len: 1
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2
# PP start_backend: 11 start_idx: 1000071 end_backend: 11 end_idx: 1000072 len: 2
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2
# PP start_backend: 11 start_idx: 1000073 end_backend: 11 end_idx: 1000073 len: 1
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1
# PP start_backend: 11 start_idx: 1000074 end_backend: 11 end_idx: 1000074 len: 1
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000075 len: 1
# PP start_backend: 11 start_idx: 1000075 end_backend: 11 end_idx: 1000076 len: 2
# PP start_backend: 21 start_idx: 2000076 end_backend: 21 end_idx: 2000076 len: 1
# PP start_backend: 11 start_idx: 1000077 end_backend: 11 end_idx: 1000077 len: 1
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1
# PP start_backend: 11 start_idx: 1000078 end_backend: 11 end_idx: 1000078 len: 1
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2
# PP start_backend: 11 start_idx: 1000079 end_backend: 11 end_idx: 1000080 len: 2
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2
# PP start_backend: 11 start_idx: 1000081 end_backend: 11 end_idx: 1000081 len: 1
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1
# PP start_backend: 11 start_idx: 1000082 end_backend: 11 end_idx: 1000082 len: 1
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1
# PP start_backend: 11 start_idx: 1000083 end_backend: 11 end_idx: 1000083 len: 1
# Node: 1, Rank: 2, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1
# PP start_backend: 11 start_idx: 1000002 end_backend: 11 end_idx: 1000003 len: 2
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2
# PP start_backend: 11 start_idx: 1000004 end_backend: 11 end_idx: 1000004 len: 1
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1
# PP start_backend: 11 start_idx: 1000005 end_backend: 11 end_idx: 1000005 len: 1
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1
# PP start_backend: 11 start_idx: 1000006 end_backend: 11 end_idx: 1000006 len: 1
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2
# PP start_backend: 11 start_idx: 1000007 end_backend: 11 end_idx: 1000008 len: 2
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2
# PP start_backend: 11 start_idx: 1000009 end_backend: 11 end_idx: 1000009 len: 1
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1
# PP start_backend: 11 start_idx: 1000010 end_backend: 11 end_idx: 1000010 len: 1
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000011 len: 1
# PP start_backend: 11 start_idx: 1000011 end_backend: 11 end_idx: 1000012 len: 2
# PP start_backend: 21 start_idx: 2000012 end_backend: 21 end_idx: 2000012 len: 1
# PP start_backend: 11 start_idx: 1000013 end_backend: 11 end_idx: 1000013 len: 1
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1
# PP start_backend: 11 start_idx: 1000014 end_backend: 11 end_idx: 1000014 len: 1
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2
# PP start_backend: 11 start_idx: 1000015 end_backend: 11 end_idx: 1000016 len: 2
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2
# PP start_backend: 11 start_idx: 1000017 end_backend: 11 end_idx: 1000017 len: 1
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1
# PP start_backend: 11 start_idx: 1000018 end_backend: 11 end_idx: 1000018 len: 1
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000019 len: 1
# PP start_backend: 11 start_idx: 1000019 end_backend: 11 end_idx: 1000020 len: 2
# PP start_backend: 21 start_idx: 2000020 end_backend: 21 end_idx: 2000020 len: 1
# PP start_backend: 11 start_idx: 1000021 end_backend: 11 end_idx: 1000021 len: 1
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1
# PP start_backend: 11 start_idx: 1000022 end_backend: 11 end_idx: 1000022 len: 1
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2
# PP start_backend: 11 start_idx: 1000023 end_backend: 11 end_idx: 1000024 len: 2
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2
# PP start_backend: 11 start_idx: 1000025 end_backend: 11 end_idx: 1000025 len: 1
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1
# PP start_backend: 11 start_idx: 1000026 end_backend: 11 end_idx: 1000026 len: 1
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000027 len: 1
# PP start_backend: 11 start_idx: 1000027 end_backend: 11 end_idx: 1000028 len: 2
# PP start_backend: 21 start_idx: 2000028 end_backend: 21 end_idx: 2000028 len: 1
# PP start_backend: 11 start_idx: 1000029 end_backend: 11 end_idx: 1000029 len: 1
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1
# PP start_backend: 11 start_idx: 1000030 end_backend: 11 end_idx: 1000030 len: 1
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2
# PP start_backend: 11 start_idx: 1000031 end_backend: 11 end_idx: 1000032 len: 2
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2
# PP start_backend: 11 start_idx: 1000033 end_backend: 11 end_idx: 1000033 len: 1
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1
# PP start_backend: 11 start_idx: 1000034 end_backend: 11 end_idx: 1000034 len: 1
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000035 len: 1
# PP start_backend: 11 start_idx: 1000035 end_backend: 11 end_idx: 1000036 len: 2
# PP start_backend: 21 start_idx: 2000036 end_backend: 21 end_idx: 2000036 len: 1
# PP start_backend: 11 start_idx: 1000037 end_backend: 11 end_idx: 1000037 len: 1
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1
# PP start_backend: 11 start_idx: 1000038 end_backend: 11 end_idx: 1000038 len: 1
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2
# PP start_backend: 11 start_idx: 1000039 end_backend: 11 end_idx: 1000040 len: 2
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2
# PP start_backend: 11 start_idx: 1000041 end_backend: 11 end_idx: 1000041 len: 1
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1
# PP start_backend: 11 start_idx: 1000042 end_backend: 11 end_idx: 1000042 len: 1
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000043 len: 1
# PP start_backend: 11 start_idx: 1000043 end_backend: 11 end_idx: 1000044 len: 2
# PP start_backend: 21 start_idx: 2000044 end_backend: 21 end_idx: 2000044 len: 1
# PP start_backend: 11 start_idx: 1000045 end_backend: 11 end_idx: 1000045 len: 1
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1
# PP start_backend: 11 start_idx: 1000046 end_backend: 11 end_idx: 1000046 len: 1
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2
# PP start_backend: 11 start_idx: 1000047 end_backend: 11 end_idx: 1000048 len: 2
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2
# PP start_backend: 11 start_idx: 1000049 end_backend: 11 end_idx: 1000049 len: 1
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1
# PP start_backend: 11 start_idx: 1000050 end_backend: 11 end_idx: 1000050 len: 1
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000051 len: 1
# PP start_backend: 11 start_idx: 1000051 end_backend: 11 end_idx: 1000052 len: 2
# PP start_backend: 21 start_idx: 2000052 end_backend: 21 end_idx: 2000052 len: 1
# PP start_backend: 11 start_idx: 1000053 end_backend: 11 end_idx: 1000053 len: 1
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1
# PP start_backend: 11 start_idx: 1000054 end_backend: 11 end_idx: 1000054 len: 1
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2
# PP start_backend: 11 start_idx: 1000055 end_backend: 11 end_idx: 1000056 len: 2
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2
# PP start_backend: 11 start_idx: 1000057 end_backend: 11 end_idx: 1000057 len: 1
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1
# PP start_backend: 11 start_idx: 1000058 end_backend: 11 end_idx: 1000058 len: 1
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000059 len: 1
# PP start_backend: 11 start_idx: 1000059 end_backend: 11 end_idx: 1000060 len: 2
# PP start_backend: 21 start_idx: 2000060 end_backend: 21 end_idx: 2000060 len: 1
# PP start_backend: 11 start_idx: 1000061 end_backend: 11 end_idx: 1000061 len: 1
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1
# PP start_backend: 11 start_idx: 1000062 end_backend: 11 end_idx: 1000062 len: 1
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2
# PP start_backend: 11 start_idx: 1000063 end_backend: 11 end_idx: 1000064 len: 2
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2
# PP start_backend: 11 start_idx: 1000065 end_backend: 11 end_idx: 1000065 len: 1
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1
# PP start_backend: 11 start_idx: 1000066 end_backend: 11 end_idx: 1000066 len: 1
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000067 len: 1
# PP start_backend: 11 start_idx: 1000067 end_backend: 11 end_idx: 1000068 len: 2
# PP start_backend: 21 start_idx: 2000068 end_backend: 21 end_idx: 2000068 len: 1
# PP start_backend: 11 start_idx: 1000069 end_backend: 11 end_idx: 1000069 len: 1
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1
# PP start_backend: 11 start_idx: 1000070 end_backend: 11 end_idx: 1000070 len: 1
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2
# PP start_backend: 11 start_idx: 1000071 end_backend: 11 end_idx: 1000072 len: 2
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2
# PP start_backend: 11 start_idx: 1000073 end_backend: 11 end_idx: 1000073 len: 1
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1
# PP start_backend: 11 start_idx: 1000074 end_backend: 11 end_idx: 1000074 len: 1
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000075 len: 1
# PP start_backend: 11 start_idx: 1000075 end_backend: 11 end_idx: 1000076 len: 2
# PP start_backend: 21 start_idx: 2000076 end_backend: 21 end_idx: 2000076 len: 1
# PP start_backend: 11 start_idx: 1000077 end_backend: 11 end_idx: 1000077 len: 1
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1
# PP start_backend: 11 start_idx: 1000078 end_backend: 11 end_idx: 1000078 len: 1
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2
# PP start_backend: 11 start_idx: 1000079 end_backend: 11 end_idx: 1000080 len: 2
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2
# PP start_backend: 11 start_idx: 1000081 end_backend: 11 end_idx: 1000081 len: 1
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1
# PP start_backend: 11 start_idx: 1000082 end_backend: 11 end_idx: 1000082 len: 1
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1
# PP start_backend: 11 start_idx: 1000083 end_backend: 11 end_idx: 1000083 len: 1
# Node: 1, Rank: 3, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1
# PP start_backend: 11 start_idx: 1000002 end_backend: 11 end_idx: 1000003 len: 2
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2
# PP start_backend: 11 start_idx: 1000004 end_backend: 11 end_idx: 1000004 len: 1
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1
# PP start_backend: 11 start_idx: 1000005 end_backend: 11 end_idx: 1000005 len: 1
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1
# PP start_backend: 11 start_idx: 1000006 end_backend: 11 end_idx: 1000006 len: 1
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2
# PP start_backend: 11 start_idx: 1000007 end_backend: 11 end_idx: 1000008 len: 2
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2
# PP start_backend: 11 start_idx: 1000009 end_backend: 11 end_idx: 1000009 len: 1
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1
# PP start_backend: 11 start_idx: 1000010 end_backend: 11 end_idx: 1000010 len: 1
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000011 len: 1
# PP start_backend: 11 start_idx: 1000011 end_backend: 11 end_idx: 1000012 len: 2
# PP start_backend: 21 start_idx: 2000012 end_backend: 21 end_idx: 2000012 len: 1
# PP start_backend: 11 start_idx: 1000013 end_backend: 11 end_idx: 1000013 len: 1
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1
# PP start_backend: 11 start_idx: 1000014 end_backend: 11 end_idx: 1000014 len: 1
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2
# PP start_backend: 11 start_idx: 1000015 end_backend: 11 end_idx: 1000016 len: 2
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2
# PP start_backend: 11 start_idx: 1000017 end_backend: 11 end_idx: 1000017 len: 1
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1
# PP start_backend: 11 start_idx: 1000018 end_backend: 11 end_idx: 1000018 len: 1
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000019 len: 1
# PP start_backend: 11 start_idx: 1000019 end_backend: 11 end_idx: 1000020 len: 2
# PP start_backend: 21 start_idx: 2000020 end_backend: 21 end_idx: 2000020 len: 1
# PP start_backend: 11 start_idx: 1000021 end_backend: 11 end_idx: 1000021 len: 1
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1
# PP start_backend: 11 start_idx: 1000022 end_backend: 11 end_idx: 1000022 len: 1
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2
# PP start_backend: 11 start_idx: 1000023 end_backend: 11 end_idx: 1000024 len: 2
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2
# PP start_backend: 11 start_idx: 1000025 end_backend: 11 end_idx: 1000025 len: 1
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1
# PP start_backend: 11 start_idx: 1000026 end_backend: 11 end_idx: 1000026 len: 1
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000027 len: 1
# PP start_backend: 11 start_idx: 1000027 end_backend: 11 end_idx: 1000028 len: 2
# PP start_backend: 21 start_idx: 2000028 end_backend: 21 end_idx: 2000028 len: 1
# PP start_backend: 11 start_idx: 1000029 end_backend: 11 end_idx: 1000029 len: 1
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1
# PP start_backend: 11 start_idx: 1000030 end_backend: 11 end_idx: 1000030 len: 1
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2
# PP start_backend: 11 start_idx: 1000031 end_backend: 11 end_idx: 1000032 len: 2
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2
# PP start_backend: 11 start_idx: 1000033 end_backend: 11 end_idx: 1000033 len: 1
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1
# PP start_backend: 11 start_idx: 1000034 end_backend: 11 end_idx: 1000034 len: 1
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000035 len: 1
# PP start_backend: 11 start_idx: 1000035 end_backend: 11 end_idx: 1000036 len: 2
# PP start_backend: 21 start_idx: 2000036 end_backend: 21 end_idx: 2000036 len: 1
# PP start_backend: 11 start_idx: 1000037 end_backend: 11 end_idx: 1000037 len: 1
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1
# PP start_backend: 11 start_idx: 1000038 end_backend: 11 end_idx: 1000038 len: 1
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2
# PP start_backend: 11 start_idx: 1000039 end_backend: 11 end_idx: 1000040 len: 2
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2
# PP start_backend: 11 start_idx: 1000041 end_backend: 11 end_idx: 1000041 len: 1
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1
# PP start_backend: 11 start_idx: 1000042 end_backend: 11 end_idx: 1000042 len: 1
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000043 len: 1
# PP start_backend: 11 start_idx: 1000043 end_backend: 11 end_idx: 1000044 len: 2
# PP start_backend: 21 start_idx: 2000044 end_backend: 21 end_idx: 2000044 len: 1
# PP start_backend: 11 start_idx: 1000045 end_backend: 11 end_idx: 1000045 len: 1
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1
# PP start_backend: 11 start_idx: 1000046 end_backend: 11 end_idx: 1000046 len: 1
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2
# PP start_backend: 11 start_idx: 1000047 end_backend: 11 end_idx: 1000048 len: 2
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2
# PP start_backend: 11 start_idx: 1000049 end_backend: 11 end_idx: 1000049 len: 1
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1
# PP start_backend: 11 start_idx: 1000050 end_backend: 11 end_idx: 1000050 len: 1
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000051 len: 1
# PP start_backend: 11 start_idx: 1000051 end_backend: 11 end_idx: 1000052 len: 2
# PP start_backend: 21 start_idx: 2000052 end_backend: 21 end_idx: 2000052 len: 1
# PP start_backend: 11 start_idx: 1000053 end_backend: 11 end_idx: 1000053 len: 1
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1
# PP start_backend: 11 start_idx: 1000054 end_backend: 11 end_idx: 1000054 len: 1
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2
# PP start_backend: 11 start_idx: 1000055 end_backend: 11 end_idx: 1000056 len: 2
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2
# PP start_backend: 11 start_idx: 1000057 end_backend: 11 end_idx: 1000057 len: 1
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1
# PP start_backend: 11 start_idx: 1000058 end_backend: 11 end_idx: 1000058 len: 1
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000059 len: 1
# PP start_backend: 11 start_idx: 1000059 end_backend: 11 end_idx: 1000060 len: 2
# PP start_backend: 21 start_idx: 2000060 end_backend: 21 end_idx: 2000060 len: 1
# PP start_backend: 11 start_idx: 1000061 end_backend: 11 end_idx: 1000061 len: 1
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1
# PP start_backend: 11 start_idx: 1000062 end_backend: 11 end_idx: 1000062 len: 1
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2
# PP start_backend: 11 start_idx: 1000063 end_backend: 11 end_idx: 1000064 len: 2
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2
# PP start_backend: 11 start_idx: 1000065 end_backend: 11 end_idx: 1000065 len: 1
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1
# PP start_backend: 11 start_idx: 1000066 end_backend: 11 end_idx: 1000066 len: 1
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000067 len: 1
# PP start_backend: 11 start_idx: 1000067 end_backend: 11 end_idx: 1000068 len: 2
# PP start_backend: 21 start_idx: 2000068 end_backend: 21 end_idx: 2000068 len: 1
# PP start_backend: 11 start_idx: 1000069 end_backend: 11 end_idx: 1000069 len: 1
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1
# PP start_backend: 11 start_idx: 1000070 end_backend: 11 end_idx: 1000070 len: 1
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2
# PP start_backend: 11 start_idx: 1000071 end_backend: 11 end_idx: 1000072 len: 2
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2
# PP start_backend: 11 start_idx: 1000073 end_backend: 11 end_idx: 1000073 len: 1
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1
# PP start_backend: 11 start_idx: 1000074 end_backend: 11 end_idx: 1000074 len: 1
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000075 len: 1
# PP start_backend: 11 start_idx: 1000075 end_backend: 11 end_idx: 1000076 len: 2
# PP start_backend: 21 start_idx: 2000076 end_backend: 21 end_idx: 2000076 len: 1
# PP start_backend: 11 start_idx: 1000077 end_backend: 11 end_idx: 1000077 len: 1
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1
# PP start_backend: 11 start_idx: 1000078 end_backend: 11 end_idx: 1000078 len: 1
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2
# PP start_backend: 11 start_idx: 1000079 end_backend: 11 end_idx: 1000080 len: 2
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2
# PP start_backend: 11 start_idx: 1000081 end_backend: 11 end_idx: 1000081 len: 1
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1
# PP start_backend: 11 start_idx: 1000082 end_backend: 11 end_idx: 1000082 len: 1
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1
# PP start_backend: 11 start_idx: 1000083 end_backend: 11 end_idx: 1000083 len: 1
# [140265442469696, 140265442469696, 140265442469696, 140265442469696]
# Node: 2, Rank: 0, Tid: 140265442469696
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000000 len: 1
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1
# PP start_backend: 31 start_idx: 3000001 end_backend: 31 end_idx: 3000001 len: 1
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2
# PP start_backend: 31 start_idx: 3000002 end_backend: 31 end_idx: 3000003 len: 2
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1
# PP start_backend: 31 start_idx: 3000004 end_backend: 31 end_idx: 3000004 len: 1
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1
# PP start_backend: 31 start_idx: 3000005 end_backend: 31 end_idx: 3000006 len: 2
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2
# PP start_backend: 31 start_idx: 3000007 end_backend: 31 end_idx: 3000008 len: 2
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2
# PP start_backend: 31 start_idx: 3000009 end_backend: 31 end_idx: 3000010 len: 2
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1
# PP start_backend: 31 start_idx: 3000011 end_backend: 31 end_idx: 3000011 len: 1
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000012 len: 2
# PP start_backend: 31 start_idx: 3000012 end_backend: 31 end_idx: 3000012 len: 1
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1
# PP start_backend: 31 start_idx: 3000013 end_backend: 31 end_idx: 3000014 len: 2
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2
# PP start_backend: 31 start_idx: 3000015 end_backend: 31 end_idx: 3000016 len: 2
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2
# PP start_backend: 31 start_idx: 3000017 end_backend: 31 end_idx: 3000018 len: 2
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1
# PP start_backend: 31 start_idx: 3000019 end_backend: 31 end_idx: 3000019 len: 1
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000020 len: 2
# PP start_backend: 31 start_idx: 3000020 end_backend: 31 end_idx: 3000020 len: 1
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1
# PP start_backend: 31 start_idx: 3000021 end_backend: 31 end_idx: 3000022 len: 2
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2
# PP start_backend: 31 start_idx: 3000023 end_backend: 31 end_idx: 3000024 len: 2
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2
# PP start_backend: 31 start_idx: 3000025 end_backend: 31 end_idx: 3000026 len: 2
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1
# PP start_backend: 31 start_idx: 3000027 end_backend: 31 end_idx: 3000027 len: 1
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000028 len: 2
# PP start_backend: 31 start_idx: 3000028 end_backend: 31 end_idx: 3000028 len: 1
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1
# PP start_backend: 31 start_idx: 3000029 end_backend: 31 end_idx: 3000030 len: 2
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2
# PP start_backend: 31 start_idx: 3000031 end_backend: 31 end_idx: 3000032 len: 2
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2
# PP start_backend: 31 start_idx: 3000033 end_backend: 31 end_idx: 3000034 len: 2
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1
# PP start_backend: 31 start_idx: 3000035 end_backend: 31 end_idx: 3000035 len: 1
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000036 len: 2
# PP start_backend: 31 start_idx: 3000036 end_backend: 31 end_idx: 3000036 len: 1
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1
# PP start_backend: 31 start_idx: 3000037 end_backend: 31 end_idx: 3000038 len: 2
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2
# PP start_backend: 31 start_idx: 3000039 end_backend: 31 end_idx: 3000040 len: 2
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2
# PP start_backend: 31 start_idx: 3000041 end_backend: 31 end_idx: 3000042 len: 2
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1
# PP start_backend: 31 start_idx: 3000043 end_backend: 31 end_idx: 3000043 len: 1
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000044 len: 2
# PP start_backend: 31 start_idx: 3000044 end_backend: 31 end_idx: 3000044 len: 1
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1
# PP start_backend: 31 start_idx: 3000045 end_backend: 31 end_idx: 3000046 len: 2
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2
# PP start_backend: 31 start_idx: 3000047 end_backend: 31 end_idx: 3000048 len: 2
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2
# PP start_backend: 31 start_idx: 3000049 end_backend: 31 end_idx: 3000050 len: 2
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1
# PP start_backend: 31 start_idx: 3000051 end_backend: 31 end_idx: 3000051 len: 1
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000052 len: 2
# PP start_backend: 31 start_idx: 3000052 end_backend: 31 end_idx: 3000052 len: 1
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1
# PP start_backend: 31 start_idx: 3000053 end_backend: 31 end_idx: 3000054 len: 2
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2
# PP start_backend: 31 start_idx: 3000055 end_backend: 31 end_idx: 3000056 len: 2
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2
# PP start_backend: 31 start_idx: 3000057 end_backend: 31 end_idx: 3000058 len: 2
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1
# PP start_backend: 31 start_idx: 3000059 end_backend: 31 end_idx: 3000059 len: 1
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000060 len: 2
# PP start_backend: 31 start_idx: 3000060 end_backend: 31 end_idx: 3000060 len: 1
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1
# ...
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2
# PP start_backend: 31 start_idx: 3000017 end_backend: 31 end_idx: 3000018 len: 2
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1
# PP start_backend: 31 start_idx: 3000019 end_backend: 31 end_idx: 3000019 len: 1
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000020 len: 2
# PP start_backend: 31 start_idx: 3000020 end_backend: 31 end_idx: 3000020 len: 1
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1
# PP start_backend: 31 start_idx: 3000021 end_backend: 31 end_idx: 3000022 len: 2
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2
# PP start_backend: 31 start_idx: 3000023 end_backend: 31 end_idx: 3000024 len: 2
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2
# PP start_backend: 31 start_idx: 3000025 end_backend: 31 end_idx: 3000026 len: 2
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1
# PP start_backend: 31 start_idx: 3000027 end_backend: 31 end_idx: 3000027 len: 1
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000028 len: 2
# PP start_backend: 31 start_idx: 3000028 end_backend: 31 end_idx: 3000028 len: 1
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1
# PP start_backend: 31 start_idx: 3000029 end_backend: 31 end_idx: 3000030 len: 2
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2
# PP start_backend: 31 start_idx: 3000031 end_backend: 31 end_idx: 3000032 len: 2
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2
# PP start_backend: 31 start_idx: 3000033 end_backend: 31 end_idx: 3000034 len: 2
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1
# PP start_backend: 31 start_idx: 3000035 end_backend: 31 end_idx: 3000035 len: 1
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000036 len: 2
# PP start_backend: 31 start_idx: 3000036 end_backend: 31 end_idx: 3000036 len: 1
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1
# PP start_backend: 31 start_idx: 3000037 end_backend: 31 end_idx: 3000038 len: 2
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2
# PP start_backend: 31 start_idx: 3000039 end_backend: 31 end_idx: 3000040 len: 2
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2
# PP start_backend: 31 start_idx: 3000041 end_backend: 31 end_idx: 3000042 len: 2
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1
# PP start_backend: 31 start_idx: 3000043 end_backend: 31 end_idx: 3000043 len: 1
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000044 len: 2
# PP start_backend: 31 start_idx: 3000044 end_backend: 31 end_idx: 3000044 len: 1
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1
# PP start_backend: 31 start_idx: 3000045 end_backend: 31 end_idx: 3000046 len: 2
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2
# PP start_backend: 31 start_idx: 3000047 end_backend: 31 end_idx: 3000048 len: 2
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2
# PP start_backend: 31 start_idx: 3000049 end_backend: 31 end_idx: 3000050 len: 2
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1
# PP start_backend: 31 start_idx: 3000051 end_backend: 31 end_idx: 3000051 len: 1
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000052 len: 2
# PP start_backend: 31 start_idx: 3000052 end_backend: 31 end_idx: 3000052 len: 1
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1
# PP start_backend: 31 start_idx: 3000053 end_backend: 31 end_idx: 3000054 len: 2
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2
# PP start_backend: 31 start_idx: 3000055 end_backend: 31 end_idx: 3000056 len: 2
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2
# PP start_backend: 31 start_idx: 3000057 end_backend: 31 end_idx: 3000058 len: 2
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1
# PP start_backend: 31 start_idx: 3000059 end_backend: 31 end_idx: 3000059 len: 1
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000060 len: 2
# PP start_backend: 31 start_idx: 3000060 end_backend: 31 end_idx: 3000060 len: 1
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1
# PP start_backend: 31 start_idx: 3000061 end_backend: 31 end_idx: 3000062 len: 2
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2
# PP start_backend: 31 start_idx: 3000063 end_backend: 31 end_idx: 3000064 len: 2
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2
# PP start_backend: 31 start_idx: 3000065 end_backend: 31 end_idx: 3000066 len: 2
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1
# PP start_backend: 31 start_idx: 3000067 end_backend: 31 end_idx: 3000067 len: 1
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000068 len: 2
# PP start_backend: 31 start_idx: 3000068 end_backend: 31 end_idx: 3000068 len: 1
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1
# PP start_backend: 31 start_idx: 3000069 end_backend: 31 end_idx: 3000070 len: 2
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2
# PP start_backend: 31 start_idx: 3000071 end_backend: 31 end_idx: 3000072 len: 2
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2
# PP start_backend: 31 start_idx: 3000073 end_backend: 31 end_idx: 3000074 len: 2
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1
# PP start_backend: 31 start_idx: 3000075 end_backend: 31 end_idx: 3000075 len: 1
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000076 len: 2
# PP start_backend: 31 start_idx: 3000076 end_backend: 31 end_idx: 3000076 len: 1
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1
# PP start_backend: 31 start_idx: 3000077 end_backend: 31 end_idx: 3000078 len: 2
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2
# PP start_backend: 31 start_idx: 3000079 end_backend: 31 end_idx: 3000080 len: 2
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2
# PP start_backend: 31 start_idx: 3000081 end_backend: 31 end_idx: 3000082 len: 2
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1
# PP start_backend: 31 start_idx: 3000083 end_backend: 31 end_idx: 3000083 len: 1
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1
# Node: 2, Rank: 3, Tid: 140265442469696
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000000 len: 1
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1
# PP start_backend: 31 start_idx: 3000001 end_backend: 31 end_idx: 3000001 len: 1
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2
# PP start_backend: 31 start_idx: 3000002 end_backend: 31 end_idx: 3000003 len: 2
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1
# PP start_backend: 31 start_idx: 3000004 end_backend: 31 end_idx: 3000004 len: 1
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1
# PP start_backend: 31 start_idx: 3000005 end_backend: 31 end_idx: 3000006 len: 2
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2
# PP start_backend: 31 start_idx: 3000007 end_backend: 31 end_idx: 3000008 len: 2
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2
# PP start_backend: 31 start_idx: 3000009 end_backend: 31 end_idx: 3000010 len: 2
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1
# PP start_backend: 31 start_idx: 3000011 end_backend: 31 end_idx: 3000011 len: 1
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000012 len: 2
# PP start_backend: 31 start_idx: 3000012 end_backend: 31 end_idx: 3000012 len: 1
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1
# PP start_backend: 31 start_idx: 3000013 end_backend: 31 end_idx: 3000014 len: 2
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2
# PP start_backend: 31 start_idx: 3000015 end_backend: 31 end_idx: 3000016 len: 2
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2
# PP start_backend: 31 start_idx: 3000017 end_backend: 31 end_idx: 3000018 len: 2
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1
# PP start_backend: 31 start_idx: 3000019 end_backend: 31 end_idx: 3000019 len: 1
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000020 len: 2
# PP start_backend: 31 start_idx: 3000020 end_backend: 31 end_idx: 3000020 len: 1
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1
# PP start_backend: 31 start_idx: 3000021 end_backend: 31 end_idx: 3000022 len: 2
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2
# PP start_backend: 31 start_idx: 3000023 end_backend: 31 end_idx: 3000024 len: 2
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2
# PP start_backend: 31 start_idx: 3000025 end_backend: 31 end_idx: 3000026 len: 2
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1
# PP start_backend: 31 start_idx: 3000027 end_backend: 31 end_idx: 3000027 len: 1
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000028 len: 2
# PP start_backend: 31 start_idx: 3000028 end_backend: 31 end_idx: 3000028 len: 1
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1
# PP start_backend: 31 start_idx: 3000029 end_backend: 31 end_idx: 3000030 len: 2
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2
# PP start_backend: 31 start_idx: 3000031 end_backend: 31 end_idx: 3000032 len: 2
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2
# PP start_backend: 31 start_idx: 3000033 end_backend: 31 end_idx: 3000034 len: 2
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1
# PP start_backend: 31 start_idx: 3000035 end_backend: 31 end_idx: 3000035 len: 1
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000036 len: 2
# PP start_backend: 31 start_idx: 3000036 end_backend: 31 end_idx: 3000036 len: 1
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1
# PP start_backend: 31 start_idx: 3000037 end_backend: 31 end_idx: 3000038 len: 2
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2
# PP start_backend: 31 start_idx: 3000039 end_backend: 31 end_idx: 3000040 len: 2
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2
# PP start_backend: 31 start_idx: 3000041 end_backend: 31 end_idx: 3000042 len: 2
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1
# PP start_backend: 31 start_idx: 3000043 end_backend: 31 end_idx: 3000043 len: 1
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000044 len: 2
# PP start_backend: 31 start_idx: 3000044 end_backend: 31 end_idx: 3000044 len: 1
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1
# PP start_backend: 31 start_idx: 3000045 end_backend: 31 end_idx: 3000046 len: 2
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2
# PP start_backend: 31 start_idx: 3000047 end_backend: 31 end_idx: 3000048 len: 2
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2
# PP start_backend: 31 start_idx: 3000049 end_backend: 31 end_idx: 3000050 len: 2
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1
# PP start_backend: 31 start_idx: 3000051 end_backend: 31 end_idx: 3000051 len: 1
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000052 len: 2
# PP start_backend: 31 start_idx: 3000052 end_backend: 31 end_idx: 3000052 len: 1
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1
# PP start_backend: 31 start_idx: 3000053 end_backend: 31 end_idx: 3000054 len: 2
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2
# PP start_backend: 31 start_idx: 3000055 end_backend: 31 end_idx: 3000056 len: 2
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2
# PP start_backend: 31 start_idx: 3000057 end_backend: 31 end_idx: 3000058 len: 2
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1
# PP start_backend: 31 start_idx: 3000059 end_backend: 31 end_idx: 3000059 len: 1
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000060 len: 2
# PP start_backend: 31 start_idx: 3000060 end_backend: 31 end_idx: 3000060 len: 1
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1
# PP start_backend: 31 start_idx: 3000061 end_backend: 31 end_idx: 3000062 len: 2
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2
# PP start_backend: 31 start_idx: 3000063 end_backend: 31 end_idx: 3000064 len: 2
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2
# PP start_backend: 31 start_idx: 3000065 end_backend: 31 end_idx: 3000066 len: 2
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1
# PP start_backend: 31 start_idx: 3000067 end_backend: 31 end_idx: 3000067 len: 1
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000068 len: 2
# PP start_backend: 31 start_idx: 3000068 end_backend: 31 end_idx: 3000068 len: 1
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1
# PP start_backend: 31 start_idx: 3000069 end_backend: 31 end_idx: 3000070 len: 2
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2
# PP start_backend: 31 start_idx: 3000071 end_backend: 31 end_idx: 3000072 len: 2
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2
# PP start_backend: 31 start_idx: 3000073 end_backend: 31 end_idx: 3000074 len: 2
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1
# PP start_backend: 31 start_idx: 3000075 end_backend: 31 end_idx: 3000075 len: 1
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000076 len: 2
# PP start_backend: 31 start_idx: 3000076 end_backend: 31 end_idx: 3000076 len: 1
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1
# PP start_backend: 31 start_idx: 3000077 end_backend: 31 end_idx: 3000078 len: 2
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2
# PP start_backend: 31 start_idx: 3000079 end_backend: 31 end_idx: 3000080 len: 2
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2
# PP start_backend: 31 start_idx: 3000081 end_backend: 31 end_idx: 3000082 len: 2
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1
# PP start_backend: 31 start_idx: 3000083 end_backend: 31 end_idx: 3000083 len: 1
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1
# [140478540224320, 140478540224320, 140478540224320, 140478540224320]
# Node: 3, Rank: 0, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84
# Node: 3, Rank: 1, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84
# Node: 3, Rank: 2, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84
# Node: 3, Rank: 3, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84

# %%
import re
import argparse
import os
import datetime

# backend 0 default, backend 1 pp, backend 2, 5, 6 DP, backend 3 TP

def custom_print(message, file_path=None, mode='a'):
    print(message)  # Print to terminal
    if file_path:
        with open(file_path, mode) as file:
            file.write(message + '\n')

def backend_to_comm_type(backend, rank_tid=None):
    if backend == 0:
        return "Default"
    elif backend % 10 == 1:
        return "PP"
    # elif backend in [2, 5, 6]:
    #     return "DP"
    elif backend == 2:
        return "TP"
    else:
        return "unknown"

def time_to_ms(t):
    return (
        t.hour * 3600_000 +
        t.minute * 60_000 +
        t.second * 1000 +
        t.microsecond / 1000.0
    )
    
def calculate_pp_backend(backend, pp_comm_group = -1):
    if pp_comm_group == -1:
        return backend
    else:
        return pp_comm_group * 10 + backend
    
def is_same_comm_type(backend1, backend2):
    if backend1 is None or backend2 is None:
        return False
    type1 = backend_to_comm_type(backend1)
    type2 = backend_to_comm_type(backend2)

    if type1 == type2 and type1 == "PP":
        return backend1 == backend2
    
    return type1 == type2


def parse_communication_pattern(log_file, rank_tid):
    pattern = re.compile(r"\x1b\[[0-9;]*m?Backend (\d+) RANK (\d+) tid: (\d+).*?Idx: (\d+)")
    # pattern = re.compile(r"\x1b\[[0-9;]*m?Backend (\d+) RANK (\d+) tid: (\d+).*? pre_coll, Idx: (\d+)")
    communication_pattern = []

    time_pat = re.compile(
        r"t:\[(\d+:\d+:\d+\.\d+)\]"
    )

    with open(log_file, 'r') as file:
        start_backend = None
        idx_list = None
        end_backend = None

        start_time = None
        end_time = None

        # Track per-idx timestamps
        idx_start_times = {}
        idx_end_times = {}

        time_gap = {}

        for line in file:
            match = pattern.search(line)
            if match:
                backend = int(match.group(1))
                tid = int(match.group(3))
                idx = int(match.group(4))

                # Check if the line contains "PP comm group"
                pp_comm_group_match = re.search(r"PP comm group: (\d+)", line)
                if pp_comm_group_match:
                    pp_comm_group = int(pp_comm_group_match.group(1))
                else:
                    pp_comm_group = -1

                # remove TP traffic and backend 0 traffic, PP allreduce traffic
                if backend_to_comm_type(backend) == "TP" or backend == 0:
                    continue
                if backend_to_comm_type(backend) == "PP" and "allreduce" in line:
                    continue

                if (backend == 1):
                    assert(pp_comm_group != -1)
                    backend = calculate_pp_backend(backend, pp_comm_group) # has information of pp group

                # extract timestamp if present
                tmatch = time_pat.search(line)
                ts = None
                if tmatch:
                    ts = datetime.datetime.strptime(tmatch.group(1), "%H:%M:%S.%f")
                    ts = time_to_ms(ts)

                # comm-type transition
                if tid == rank_tid:
                    # record pre/post timestamps
                    if "issuing" in line and ts:
                        idx_start_times[(backend, idx)] = ts
                    elif "post_coll" in line and ts:
                        idx_end_times[(backend, idx)] = ts

                    if "issuing" in line:
                        if not is_same_comm_type(backend, start_backend):
                            if start_backend is not None:
                                communication_pattern.append(
                                    (start_backend, idx_list, end_backend, start_time, end_time)
                                )
                            
                            start_time = ts
                            if end_time:
                                time_gap[(start_backend, idx_list[0])] = start_time - end_time
                            start_backend = backend
                            idx_list = [idx]
                            end_backend = backend
                        else:
                            end_backend = backend
                            idx_list.append(idx)

                    if "post_coll" in line:
                        end_time = ts

        # Append the last backend, rank, and idx
        if start_backend is not None:
            communication_pattern.append((start_backend, idx_list, end_backend, start_time, end_time))

    return communication_pattern

def get_rank_tid(log_file, node_id, num_local_ranks):
    pattern = re.compile(r"Backend 0 RANK (\d+) tid: (\d+)")
    with open(log_file, 'r') as file:
        for line in file:
            match = pattern.search(line)
            if match:
                backend = int(match.group(1))
                tid = int(match.group(2))
                return [tid] * num_local_ranks  # Assuming all local ranks share the same pattern
    raise ValueError(f"No matching line found in log file {log_file}")

# List all files in the folder that match the pattern torchrun_nid*
log_folder = "<path-to-opus>/Opus/torchtitan/opus-test/deepseek-pp-4-tp-4-pm/output-opus-l_0-no-ctl/"
torchrun_files = [f for f in os.listdir(log_folder) if f.startswith("torchrun_nid")]
torchrun_files.sort()

print(torchrun_files)
num_local_ranks = 4

output_folder = "comm_pattern_time"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for i, log_file in enumerate(torchrun_files):
    log_file_full_path = os.path.join(log_folder, log_file)
    rank_tid_list = get_rank_tid(log_file_full_path, i, num_local_ranks)
    print(rank_tid_list)

    for rank, tid in enumerate(rank_tid_list):
        # rank is local rank
        output_file = f"{output_folder}/comm_pattern_{i}_rank{rank}.txt"
        # Clean the output file before writing
        with open(output_file, 'w') as file:
            file.truncate(0)
        custom_print(f"Node: {i}, Rank: {rank}, Tid: {tid}", output_file)
        pattern = parse_communication_pattern(log_file_full_path, tid)

        for backend, idx_list, end_backend, start_time, end_time in pattern:
            custom_print(f"{backend_to_comm_type(backend)} start_backend: {backend} start_idx: {idx_list[0]} end_backend: {end_backend} end_idx: {idx_list[-1]} len: {len(idx_list)}, start_time: {start_time}, end_time: {end_time}", output_file)
# Out:
# ['torchrun_nid001024.ans', 'torchrun_nid001029.ans', 'torchrun_nid200377.ans', 'torchrun_nid200380.ans']
# [139736130148160, 139736130148160, 139736130148160, 139736130148160]
# Node: 0, Rank: 0, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84, start_time: 59824129.008, end_time: None
# Node: 0, Rank: 1, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84, start_time: 59824129.008, end_time: None
# Node: 0, Rank: 2, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84, start_time: 59824129.008, end_time: None
# Node: 0, Rank: 3, Tid: 139736130148160
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000083 len: 84, start_time: 59824129.008, end_time: None
# [139842750940992, 139842750940992, 139842750940992, 139842750940992]
# Node: 1, Rank: 0, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1, start_time: 59824044.276, end_time: None
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1, start_time: 59824045.163, end_time: None
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1, start_time: 59824045.744, end_time: None
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1, start_time: 59824046.375, end_time: None
# PP start_backend: 11 start_idx: 1000002 end_backend: 11 end_idx: 1000003 len: 2, start_time: 59824166.294, end_time: None
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2, start_time: 59844131.571, end_time: None
# PP start_backend: 11 start_idx: 1000004 end_backend: 11 end_idx: 1000004 len: 1, start_time: 59844133.078, end_time: None
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1, start_time: 59844424.857, end_time: None
# PP start_backend: 11 start_idx: 1000005 end_backend: 11 end_idx: 1000005 len: 1, start_time: 59844425.422, end_time: None
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1, start_time: 59854196.814, end_time: None
# PP start_backend: 11 start_idx: 1000006 end_backend: 11 end_idx: 1000006 len: 1, start_time: 59854197.296, end_time: None
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2, start_time: 59854397.746, end_time: None
# PP start_backend: 11 start_idx: 1000007 end_backend: 11 end_idx: 1000008 len: 2, start_time: 59869938.313, end_time: None
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2, start_time: 59870177.499, end_time: None
# PP start_backend: 11 start_idx: 1000009 end_backend: 11 end_idx: 1000009 len: 1, start_time: 59871105.173, end_time: None
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1, start_time: 59871105.493, end_time: None
# PP start_backend: 11 start_idx: 1000010 end_backend: 11 end_idx: 1000010 len: 1, start_time: 59872305.916, end_time: None
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000011 len: 1, start_time: 59872306.331, end_time: None
# PP start_backend: 11 start_idx: 1000011 end_backend: 11 end_idx: 1000012 len: 2, start_time: 59873284.626, end_time: None
# PP start_backend: 21 start_idx: 2000012 end_backend: 21 end_idx: 2000012 len: 1, start_time: 59876029.581, end_time: None
# PP start_backend: 11 start_idx: 1000013 end_backend: 11 end_idx: 1000013 len: 1, start_time: 59876029.888, end_time: None
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1, start_time: 59876204.252, end_time: None
# PP start_backend: 11 start_idx: 1000014 end_backend: 11 end_idx: 1000014 len: 1, start_time: 59876204.693, end_time: None
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2, start_time: 59876379.83, end_time: None
# PP start_backend: 11 start_idx: 1000015 end_backend: 11 end_idx: 1000016 len: 2, start_time: 59878758.871, end_time: None
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2, start_time: 59879006.938, end_time: None
# PP start_backend: 11 start_idx: 1000017 end_backend: 11 end_idx: 1000017 len: 1, start_time: 59879932.329, end_time: None
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1, start_time: 59879932.733, end_time: None
# PP start_backend: 11 start_idx: 1000018 end_backend: 11 end_idx: 1000018 len: 1, start_time: 59880918.75, end_time: None
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000019 len: 1, start_time: 59880919.049, end_time: None
# PP start_backend: 11 start_idx: 1000019 end_backend: 11 end_idx: 1000020 len: 2, start_time: 59881902.333, end_time: None
# PP start_backend: 21 start_idx: 2000020 end_backend: 21 end_idx: 2000020 len: 1, start_time: 59883363.988, end_time: None
# PP start_backend: 11 start_idx: 1000021 end_backend: 11 end_idx: 1000021 len: 1, start_time: 59883364.341, end_time: None
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1, start_time: 59883520.251, end_time: None
# PP start_backend: 11 start_idx: 1000022 end_backend: 11 end_idx: 1000022 len: 1, start_time: 59883520.84, end_time: None
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2, start_time: 59883691.19, end_time: None
# PP start_backend: 11 start_idx: 1000023 end_backend: 11 end_idx: 1000024 len: 2, start_time: 59886094.813, end_time: None
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2, start_time: 59886329.525, end_time: None
# PP start_backend: 11 start_idx: 1000025 end_backend: 11 end_idx: 1000025 len: 1, start_time: 59887254.355, end_time: None
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1, start_time: 59887254.7, end_time: None
# PP start_backend: 11 start_idx: 1000026 end_backend: 11 end_idx: 1000026 len: 1, start_time: 59888236.331, end_time: None
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000027 len: 1, start_time: 59888237.266, end_time: None
# PP start_backend: 11 start_idx: 1000027 end_backend: 11 end_idx: 1000028 len: 2, start_time: 59889213.885, end_time: None
# PP start_backend: 21 start_idx: 2000028 end_backend: 21 end_idx: 2000028 len: 1, start_time: 59890648.506, end_time: None
# PP start_backend: 11 start_idx: 1000029 end_backend: 11 end_idx: 1000029 len: 1, start_time: 59890648.793, end_time: None
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1, start_time: 59890807.699, end_time: None
# PP start_backend: 11 start_idx: 1000030 end_backend: 11 end_idx: 1000030 len: 1, start_time: 59890808.193, end_time: None
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2, start_time: 59890979.061, end_time: None
# PP start_backend: 11 start_idx: 1000031 end_backend: 11 end_idx: 1000032 len: 2, start_time: 59893368.379, end_time: None
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2, start_time: 59893605.345, end_time: None
# PP start_backend: 11 start_idx: 1000033 end_backend: 11 end_idx: 1000033 len: 1, start_time: 59894502.065, end_time: None
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1, start_time: 59894502.363, end_time: None
# PP start_backend: 11 start_idx: 1000034 end_backend: 11 end_idx: 1000034 len: 1, start_time: 59895483.799, end_time: None
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000035 len: 1, start_time: 59895484.124, end_time: None
# PP start_backend: 11 start_idx: 1000035 end_backend: 11 end_idx: 1000036 len: 2, start_time: 59896462.673, end_time: None
# PP start_backend: 21 start_idx: 2000036 end_backend: 21 end_idx: 2000036 len: 1, start_time: 59897895.04, end_time: None
# PP start_backend: 11 start_idx: 1000037 end_backend: 11 end_idx: 1000037 len: 1, start_time: 59897895.448, end_time: None
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1, start_time: 59898054.025, end_time: None
# PP start_backend: 11 start_idx: 1000038 end_backend: 11 end_idx: 1000038 len: 1, start_time: 59898054.445, end_time: None
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2, start_time: 59898218.324, end_time: None
# PP start_backend: 11 start_idx: 1000039 end_backend: 11 end_idx: 1000040 len: 2, start_time: 59900612.05, end_time: None
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2, start_time: 59900845.017, end_time: None
# PP start_backend: 11 start_idx: 1000041 end_backend: 11 end_idx: 1000041 len: 1, start_time: 59901747.278, end_time: None
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1, start_time: 59901747.587, end_time: None
# PP start_backend: 11 start_idx: 1000042 end_backend: 11 end_idx: 1000042 len: 1, start_time: 59902728.561, end_time: None
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000043 len: 1, start_time: 59902728.84, end_time: None
# PP start_backend: 11 start_idx: 1000043 end_backend: 11 end_idx: 1000044 len: 2, start_time: 59903709.118, end_time: None
# PP start_backend: 21 start_idx: 2000044 end_backend: 21 end_idx: 2000044 len: 1, start_time: 59905338.461, end_time: None
# PP start_backend: 11 start_idx: 1000045 end_backend: 11 end_idx: 1000045 len: 1, start_time: 59905338.883, end_time: None
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1, start_time: 59905499.209, end_time: None
# PP start_backend: 11 start_idx: 1000046 end_backend: 11 end_idx: 1000046 len: 1, start_time: 59905499.601, end_time: None
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2, start_time: 59905668.805, end_time: None
# PP start_backend: 11 start_idx: 1000047 end_backend: 11 end_idx: 1000048 len: 2, start_time: 59908053.79, end_time: None
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2, start_time: 59908285.831, end_time: None
# PP start_backend: 11 start_idx: 1000049 end_backend: 11 end_idx: 1000049 len: 1, start_time: 59909177.953, end_time: None
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1, start_time: 59909178.287, end_time: None
# PP start_backend: 11 start_idx: 1000050 end_backend: 11 end_idx: 1000050 len: 1, start_time: 59910159.951, end_time: None
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000051 len: 1, start_time: 59910160.237, end_time: None
# PP start_backend: 11 start_idx: 1000051 end_backend: 11 end_idx: 1000052 len: 2, start_time: 59911139.682, end_time: None
# PP start_backend: 21 start_idx: 2000052 end_backend: 21 end_idx: 2000052 len: 1, start_time: 59912575.528, end_time: None
# PP start_backend: 11 start_idx: 1000053 end_backend: 11 end_idx: 1000053 len: 1, start_time: 59912575.962, end_time: None
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1, start_time: 59912735.799, end_time: None
# PP start_backend: 11 start_idx: 1000054 end_backend: 11 end_idx: 1000054 len: 1, start_time: 59912736.26, end_time: None
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2, start_time: 59912898.722, end_time: None
# PP start_backend: 11 start_idx: 1000055 end_backend: 11 end_idx: 1000056 len: 2, start_time: 59915293.784, end_time: None
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2, start_time: 59915523.402, end_time: None
# PP start_backend: 11 start_idx: 1000057 end_backend: 11 end_idx: 1000057 len: 1, start_time: 59916417.234, end_time: None
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1, start_time: 59916417.525, end_time: None
# PP start_backend: 11 start_idx: 1000058 end_backend: 11 end_idx: 1000058 len: 1, start_time: 59917398.044, end_time: None
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000059 len: 1, start_time: 59917398.322, end_time: None
# PP start_backend: 11 start_idx: 1000059 end_backend: 11 end_idx: 1000060 len: 2, start_time: 59918377.976, end_time: None
# PP start_backend: 21 start_idx: 2000060 end_backend: 21 end_idx: 2000060 len: 1, start_time: 59919811.762, end_time: None
# PP start_backend: 11 start_idx: 1000061 end_backend: 11 end_idx: 1000061 len: 1, start_time: 59919812.19, end_time: None
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1, start_time: 59919979.419, end_time: None
# PP start_backend: 11 start_idx: 1000062 end_backend: 11 end_idx: 1000062 len: 1, start_time: 59919979.8, end_time: None
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2, start_time: 59920137.613, end_time: None
# PP start_backend: 11 start_idx: 1000063 end_backend: 11 end_idx: 1000064 len: 2, start_time: 59922529.528, end_time: None
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2, start_time: 59922761.238, end_time: None
# PP start_backend: 11 start_idx: 1000065 end_backend: 11 end_idx: 1000065 len: 1, start_time: 59923657.627, end_time: None
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1, start_time: 59923657.93, end_time: None
# PP start_backend: 11 start_idx: 1000066 end_backend: 11 end_idx: 1000066 len: 1, start_time: 59924637.025, end_time: None
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000067 len: 1, start_time: 59924637.367, end_time: None
# PP start_backend: 11 start_idx: 1000067 end_backend: 11 end_idx: 1000068 len: 2, start_time: 59925617.394, end_time: None
# PP start_backend: 21 start_idx: 2000068 end_backend: 21 end_idx: 2000068 len: 1, start_time: 59927045.743, end_time: None
# PP start_backend: 11 start_idx: 1000069 end_backend: 11 end_idx: 1000069 len: 1, start_time: 59927046.165, end_time: None
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1, start_time: 59927207.543, end_time: None
# PP start_backend: 11 start_idx: 1000070 end_backend: 11 end_idx: 1000070 len: 1, start_time: 59927208.004, end_time: None
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2, start_time: 59927370.89, end_time: None
# PP start_backend: 11 start_idx: 1000071 end_backend: 11 end_idx: 1000072 len: 2, start_time: 59929759.21, end_time: None
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2, start_time: 59929993.614, end_time: None
# PP start_backend: 11 start_idx: 1000073 end_backend: 11 end_idx: 1000073 len: 1, start_time: 59930886.751, end_time: None
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1, start_time: 59930887.588, end_time: None
# PP start_backend: 11 start_idx: 1000074 end_backend: 11 end_idx: 1000074 len: 1, start_time: 59931866.824, end_time: None
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000075 len: 1, start_time: 59931867.755, end_time: None
# PP start_backend: 11 start_idx: 1000075 end_backend: 11 end_idx: 1000076 len: 2, start_time: 59932847.188, end_time: None
# PP start_backend: 21 start_idx: 2000076 end_backend: 21 end_idx: 2000076 len: 1, start_time: 59934276.962, end_time: None
# PP start_backend: 11 start_idx: 1000077 end_backend: 11 end_idx: 1000077 len: 1, start_time: 59934277.39, end_time: None
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1, start_time: 59934438.97, end_time: None
# PP start_backend: 11 start_idx: 1000078 end_backend: 11 end_idx: 1000078 len: 1, start_time: 59934439.419, end_time: None
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2, start_time: 59934600.882, end_time: None
# PP start_backend: 11 start_idx: 1000079 end_backend: 11 end_idx: 1000080 len: 2, start_time: 59936990.799, end_time: None
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2, start_time: 59937225.393, end_time: None
# PP start_backend: 11 start_idx: 1000081 end_backend: 11 end_idx: 1000081 len: 1, start_time: 59938123.123, end_time: None
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1, start_time: 59938123.442, end_time: None
# PP start_backend: 11 start_idx: 1000082 end_backend: 11 end_idx: 1000082 len: 1, start_time: 59939105.255, end_time: None
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1, start_time: 59939105.555, end_time: None
# PP start_backend: 11 start_idx: 1000083 end_backend: 11 end_idx: 1000083 len: 1, start_time: 59940084.574, end_time: None
# Node: 1, Rank: 1, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1, start_time: 59824044.276, end_time: None
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1, start_time: 59824045.163, end_time: None
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1, start_time: 59824045.744, end_time: None
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1, start_time: 59824046.375, end_time: None
# PP start_backend: 11 start_idx: 1000002 end_backend: 11 end_idx: 1000003 len: 2, start_time: 59824166.294, end_time: None
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2, start_time: 59844131.571, end_time: None
# PP start_backend: 11 start_idx: 1000004 end_backend: 11 end_idx: 1000004 len: 1, start_time: 59844133.078, end_time: None
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1, start_time: 59844424.857, end_time: None
# PP start_backend: 11 start_idx: 1000005 end_backend: 11 end_idx: 1000005 len: 1, start_time: 59844425.422, end_time: None
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1, start_time: 59854196.814, end_time: None
# PP start_backend: 11 start_idx: 1000006 end_backend: 11 end_idx: 1000006 len: 1, start_time: 59854197.296, end_time: None
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2, start_time: 59854397.746, end_time: None
# PP start_backend: 11 start_idx: 1000007 end_backend: 11 end_idx: 1000008 len: 2, start_time: 59869938.313, end_time: None
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2, start_time: 59870177.499, end_time: None
# PP start_backend: 11 start_idx: 1000009 end_backend: 11 end_idx: 1000009 len: 1, start_time: 59871105.173, end_time: None
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1, start_time: 59871105.493, end_time: None
# PP start_backend: 11 start_idx: 1000010 end_backend: 11 end_idx: 1000010 len: 1, start_time: 59872305.916, end_time: None
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000011 len: 1, start_time: 59872306.331, end_time: None
# PP start_backend: 11 start_idx: 1000011 end_backend: 11 end_idx: 1000012 len: 2, start_time: 59873284.626, end_time: None
# PP start_backend: 21 start_idx: 2000012 end_backend: 21 end_idx: 2000012 len: 1, start_time: 59876029.581, end_time: None
# PP start_backend: 11 start_idx: 1000013 end_backend: 11 end_idx: 1000013 len: 1, start_time: 59876029.888, end_time: None
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1, start_time: 59876204.252, end_time: None
# PP start_backend: 11 start_idx: 1000014 end_backend: 11 end_idx: 1000014 len: 1, start_time: 59876204.693, end_time: None
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2, start_time: 59876379.83, end_time: None
# PP start_backend: 11 start_idx: 1000015 end_backend: 11 end_idx: 1000016 len: 2, start_time: 59878758.871, end_time: None
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2, start_time: 59879006.938, end_time: None
# PP start_backend: 11 start_idx: 1000017 end_backend: 11 end_idx: 1000017 len: 1, start_time: 59879932.329, end_time: None
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1, start_time: 59879932.733, end_time: None
# PP start_backend: 11 start_idx: 1000018 end_backend: 11 end_idx: 1000018 len: 1, start_time: 59880918.75, end_time: None
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000019 len: 1, start_time: 59880919.049, end_time: None
# PP start_backend: 11 start_idx: 1000019 end_backend: 11 end_idx: 1000020 len: 2, start_time: 59881902.333, end_time: None
# PP start_backend: 21 start_idx: 2000020 end_backend: 21 end_idx: 2000020 len: 1, start_time: 59883363.988, end_time: None
# PP start_backend: 11 start_idx: 1000021 end_backend: 11 end_idx: 1000021 len: 1, start_time: 59883364.341, end_time: None
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1, start_time: 59883520.251, end_time: None
# PP start_backend: 11 start_idx: 1000022 end_backend: 11 end_idx: 1000022 len: 1, start_time: 59883520.84, end_time: None
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2, start_time: 59883691.19, end_time: None
# PP start_backend: 11 start_idx: 1000023 end_backend: 11 end_idx: 1000024 len: 2, start_time: 59886094.813, end_time: None
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2, start_time: 59886329.525, end_time: None
# PP start_backend: 11 start_idx: 1000025 end_backend: 11 end_idx: 1000025 len: 1, start_time: 59887254.355, end_time: None
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1, start_time: 59887254.7, end_time: None
# PP start_backend: 11 start_idx: 1000026 end_backend: 11 end_idx: 1000026 len: 1, start_time: 59888236.331, end_time: None
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000027 len: 1, start_time: 59888237.266, end_time: None
# PP start_backend: 11 start_idx: 1000027 end_backend: 11 end_idx: 1000028 len: 2, start_time: 59889213.885, end_time: None
# PP start_backend: 21 start_idx: 2000028 end_backend: 21 end_idx: 2000028 len: 1, start_time: 59890648.506, end_time: None
# PP start_backend: 11 start_idx: 1000029 end_backend: 11 end_idx: 1000029 len: 1, start_time: 59890648.793, end_time: None
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1, start_time: 59890807.699, end_time: None
# PP start_backend: 11 start_idx: 1000030 end_backend: 11 end_idx: 1000030 len: 1, start_time: 59890808.193, end_time: None
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2, start_time: 59890979.061, end_time: None
# PP start_backend: 11 start_idx: 1000031 end_backend: 11 end_idx: 1000032 len: 2, start_time: 59893368.379, end_time: None
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2, start_time: 59893605.345, end_time: None
# PP start_backend: 11 start_idx: 1000033 end_backend: 11 end_idx: 1000033 len: 1, start_time: 59894502.065, end_time: None
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1, start_time: 59894502.363, end_time: None
# PP start_backend: 11 start_idx: 1000034 end_backend: 11 end_idx: 1000034 len: 1, start_time: 59895483.799, end_time: None
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000035 len: 1, start_time: 59895484.124, end_time: None
# PP start_backend: 11 start_idx: 1000035 end_backend: 11 end_idx: 1000036 len: 2, start_time: 59896462.673, end_time: None
# PP start_backend: 21 start_idx: 2000036 end_backend: 21 end_idx: 2000036 len: 1, start_time: 59897895.04, end_time: None
# PP start_backend: 11 start_idx: 1000037 end_backend: 11 end_idx: 1000037 len: 1, start_time: 59897895.448, end_time: None
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1, start_time: 59898054.025, end_time: None
# PP start_backend: 11 start_idx: 1000038 end_backend: 11 end_idx: 1000038 len: 1, start_time: 59898054.445, end_time: None
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2, start_time: 59898218.324, end_time: None
# PP start_backend: 11 start_idx: 1000039 end_backend: 11 end_idx: 1000040 len: 2, start_time: 59900612.05, end_time: None
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2, start_time: 59900845.017, end_time: None
# PP start_backend: 11 start_idx: 1000041 end_backend: 11 end_idx: 1000041 len: 1, start_time: 59901747.278, end_time: None
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1, start_time: 59901747.587, end_time: None
# PP start_backend: 11 start_idx: 1000042 end_backend: 11 end_idx: 1000042 len: 1, start_time: 59902728.561, end_time: None
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000043 len: 1, start_time: 59902728.84, end_time: None
# PP start_backend: 11 start_idx: 1000043 end_backend: 11 end_idx: 1000044 len: 2, start_time: 59903709.118, end_time: None
# PP start_backend: 21 start_idx: 2000044 end_backend: 21 end_idx: 2000044 len: 1, start_time: 59905338.461, end_time: None
# PP start_backend: 11 start_idx: 1000045 end_backend: 11 end_idx: 1000045 len: 1, start_time: 59905338.883, end_time: None
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1, start_time: 59905499.209, end_time: None
# PP start_backend: 11 start_idx: 1000046 end_backend: 11 end_idx: 1000046 len: 1, start_time: 59905499.601, end_time: None
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2, start_time: 59905668.805, end_time: None
# PP start_backend: 11 start_idx: 1000047 end_backend: 11 end_idx: 1000048 len: 2, start_time: 59908053.79, end_time: None
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2, start_time: 59908285.831, end_time: None
# PP start_backend: 11 start_idx: 1000049 end_backend: 11 end_idx: 1000049 len: 1, start_time: 59909177.953, end_time: None
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1, start_time: 59909178.287, end_time: None
# PP start_backend: 11 start_idx: 1000050 end_backend: 11 end_idx: 1000050 len: 1, start_time: 59910159.951, end_time: None
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000051 len: 1, start_time: 59910160.237, end_time: None
# PP start_backend: 11 start_idx: 1000051 end_backend: 11 end_idx: 1000052 len: 2, start_time: 59911139.682, end_time: None
# PP start_backend: 21 start_idx: 2000052 end_backend: 21 end_idx: 2000052 len: 1, start_time: 59912575.528, end_time: None
# PP start_backend: 11 start_idx: 1000053 end_backend: 11 end_idx: 1000053 len: 1, start_time: 59912575.962, end_time: None
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1, start_time: 59912735.799, end_time: None
# PP start_backend: 11 start_idx: 1000054 end_backend: 11 end_idx: 1000054 len: 1, start_time: 59912736.26, end_time: None
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2, start_time: 59912898.722, end_time: None
# PP start_backend: 11 start_idx: 1000055 end_backend: 11 end_idx: 1000056 len: 2, start_time: 59915293.784, end_time: None
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2, start_time: 59915523.402, end_time: None
# PP start_backend: 11 start_idx: 1000057 end_backend: 11 end_idx: 1000057 len: 1, start_time: 59916417.234, end_time: None
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1, start_time: 59916417.525, end_time: None
# PP start_backend: 11 start_idx: 1000058 end_backend: 11 end_idx: 1000058 len: 1, start_time: 59917398.044, end_time: None
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000059 len: 1, start_time: 59917398.322, end_time: None
# PP start_backend: 11 start_idx: 1000059 end_backend: 11 end_idx: 1000060 len: 2, start_time: 59918377.976, end_time: None
# PP start_backend: 21 start_idx: 2000060 end_backend: 21 end_idx: 2000060 len: 1, start_time: 59919811.762, end_time: None
# PP start_backend: 11 start_idx: 1000061 end_backend: 11 end_idx: 1000061 len: 1, start_time: 59919812.19, end_time: None
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1, start_time: 59919979.419, end_time: None
# PP start_backend: 11 start_idx: 1000062 end_backend: 11 end_idx: 1000062 len: 1, start_time: 59919979.8, end_time: None
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2, start_time: 59920137.613, end_time: None
# PP start_backend: 11 start_idx: 1000063 end_backend: 11 end_idx: 1000064 len: 2, start_time: 59922529.528, end_time: None
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2, start_time: 59922761.238, end_time: None
# PP start_backend: 11 start_idx: 1000065 end_backend: 11 end_idx: 1000065 len: 1, start_time: 59923657.627, end_time: None
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1, start_time: 59923657.93, end_time: None
# PP start_backend: 11 start_idx: 1000066 end_backend: 11 end_idx: 1000066 len: 1, start_time: 59924637.025, end_time: None
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000067 len: 1, start_time: 59924637.367, end_time: None
# PP start_backend: 11 start_idx: 1000067 end_backend: 11 end_idx: 1000068 len: 2, start_time: 59925617.394, end_time: None
# PP start_backend: 21 start_idx: 2000068 end_backend: 21 end_idx: 2000068 len: 1, start_time: 59927045.743, end_time: None
# PP start_backend: 11 start_idx: 1000069 end_backend: 11 end_idx: 1000069 len: 1, start_time: 59927046.165, end_time: None
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1, start_time: 59927207.543, end_time: None
# PP start_backend: 11 start_idx: 1000070 end_backend: 11 end_idx: 1000070 len: 1, start_time: 59927208.004, end_time: None
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2, start_time: 59927370.89, end_time: None
# PP start_backend: 11 start_idx: 1000071 end_backend: 11 end_idx: 1000072 len: 2, start_time: 59929759.21, end_time: None
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2, start_time: 59929993.614, end_time: None
# PP start_backend: 11 start_idx: 1000073 end_backend: 11 end_idx: 1000073 len: 1, start_time: 59930886.751, end_time: None
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1, start_time: 59930887.588, end_time: None
# PP start_backend: 11 start_idx: 1000074 end_backend: 11 end_idx: 1000074 len: 1, start_time: 59931866.824, end_time: None
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000075 len: 1, start_time: 59931867.755, end_time: None
# PP start_backend: 11 start_idx: 1000075 end_backend: 11 end_idx: 1000076 len: 2, start_time: 59932847.188, end_time: None
# PP start_backend: 21 start_idx: 2000076 end_backend: 21 end_idx: 2000076 len: 1, start_time: 59934276.962, end_time: None
# PP start_backend: 11 start_idx: 1000077 end_backend: 11 end_idx: 1000077 len: 1, start_time: 59934277.39, end_time: None
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1, start_time: 59934438.97, end_time: None
# PP start_backend: 11 start_idx: 1000078 end_backend: 11 end_idx: 1000078 len: 1, start_time: 59934439.419, end_time: None
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2, start_time: 59934600.882, end_time: None
# PP start_backend: 11 start_idx: 1000079 end_backend: 11 end_idx: 1000080 len: 2, start_time: 59936990.799, end_time: None
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2, start_time: 59937225.393, end_time: None
# PP start_backend: 11 start_idx: 1000081 end_backend: 11 end_idx: 1000081 len: 1, start_time: 59938123.123, end_time: None
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1, start_time: 59938123.442, end_time: None
# PP start_backend: 11 start_idx: 1000082 end_backend: 11 end_idx: 1000082 len: 1, start_time: 59939105.255, end_time: None
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1, start_time: 59939105.555, end_time: None
# PP start_backend: 11 start_idx: 1000083 end_backend: 11 end_idx: 1000083 len: 1, start_time: 59940084.574, end_time: None
# Node: 1, Rank: 2, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1, start_time: 59824044.276, end_time: None
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1, start_time: 59824045.163, end_time: None
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1, start_time: 59824045.744, end_time: None
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1, start_time: 59824046.375, end_time: None
# PP start_backend: 11 start_idx: 1000002 end_backend: 11 end_idx: 1000003 len: 2, start_time: 59824166.294, end_time: None
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2, start_time: 59844131.571, end_time: None
# PP start_backend: 11 start_idx: 1000004 end_backend: 11 end_idx: 1000004 len: 1, start_time: 59844133.078, end_time: None
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1, start_time: 59844424.857, end_time: None
# PP start_backend: 11 start_idx: 1000005 end_backend: 11 end_idx: 1000005 len: 1, start_time: 59844425.422, end_time: None
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1, start_time: 59854196.814, end_time: None
# PP start_backend: 11 start_idx: 1000006 end_backend: 11 end_idx: 1000006 len: 1, start_time: 59854197.296, end_time: None
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2, start_time: 59854397.746, end_time: None
# PP start_backend: 11 start_idx: 1000007 end_backend: 11 end_idx: 1000008 len: 2, start_time: 59869938.313, end_time: None
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2, start_time: 59870177.499, end_time: None
# PP start_backend: 11 start_idx: 1000009 end_backend: 11 end_idx: 1000009 len: 1, start_time: 59871105.173, end_time: None
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1, start_time: 59871105.493, end_time: None
# PP start_backend: 11 start_idx: 1000010 end_backend: 11 end_idx: 1000010 len: 1, start_time: 59872305.916, end_time: None
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000011 len: 1, start_time: 59872306.331, end_time: None
# PP start_backend: 11 start_idx: 1000011 end_backend: 11 end_idx: 1000012 len: 2, start_time: 59873284.626, end_time: None
# PP start_backend: 21 start_idx: 2000012 end_backend: 21 end_idx: 2000012 len: 1, start_time: 59876029.581, end_time: None
# PP start_backend: 11 start_idx: 1000013 end_backend: 11 end_idx: 1000013 len: 1, start_time: 59876029.888, end_time: None
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1, start_time: 59876204.252, end_time: None
# PP start_backend: 11 start_idx: 1000014 end_backend: 11 end_idx: 1000014 len: 1, start_time: 59876204.693, end_time: None
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2, start_time: 59876379.83, end_time: None
# PP start_backend: 11 start_idx: 1000015 end_backend: 11 end_idx: 1000016 len: 2, start_time: 59878758.871, end_time: None
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2, start_time: 59879006.938, end_time: None
# PP start_backend: 11 start_idx: 1000017 end_backend: 11 end_idx: 1000017 len: 1, start_time: 59879932.329, end_time: None
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1, start_time: 59879932.733, end_time: None
# PP start_backend: 11 start_idx: 1000018 end_backend: 11 end_idx: 1000018 len: 1, start_time: 59880918.75, end_time: None
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000019 len: 1, start_time: 59880919.049, end_time: None
# PP start_backend: 11 start_idx: 1000019 end_backend: 11 end_idx: 1000020 len: 2, start_time: 59881902.333, end_time: None
# PP start_backend: 21 start_idx: 2000020 end_backend: 21 end_idx: 2000020 len: 1, start_time: 59883363.988, end_time: None
# PP start_backend: 11 start_idx: 1000021 end_backend: 11 end_idx: 1000021 len: 1, start_time: 59883364.341, end_time: None
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1, start_time: 59883520.251, end_time: None
# PP start_backend: 11 start_idx: 1000022 end_backend: 11 end_idx: 1000022 len: 1, start_time: 59883520.84, end_time: None
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2, start_time: 59883691.19, end_time: None
# PP start_backend: 11 start_idx: 1000023 end_backend: 11 end_idx: 1000024 len: 2, start_time: 59886094.813, end_time: None
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2, start_time: 59886329.525, end_time: None
# PP start_backend: 11 start_idx: 1000025 end_backend: 11 end_idx: 1000025 len: 1, start_time: 59887254.355, end_time: None
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1, start_time: 59887254.7, end_time: None
# PP start_backend: 11 start_idx: 1000026 end_backend: 11 end_idx: 1000026 len: 1, start_time: 59888236.331, end_time: None
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000027 len: 1, start_time: 59888237.266, end_time: None
# PP start_backend: 11 start_idx: 1000027 end_backend: 11 end_idx: 1000028 len: 2, start_time: 59889213.885, end_time: None
# PP start_backend: 21 start_idx: 2000028 end_backend: 21 end_idx: 2000028 len: 1, start_time: 59890648.506, end_time: None
# PP start_backend: 11 start_idx: 1000029 end_backend: 11 end_idx: 1000029 len: 1, start_time: 59890648.793, end_time: None
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1, start_time: 59890807.699, end_time: None
# PP start_backend: 11 start_idx: 1000030 end_backend: 11 end_idx: 1000030 len: 1, start_time: 59890808.193, end_time: None
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2, start_time: 59890979.061, end_time: None
# PP start_backend: 11 start_idx: 1000031 end_backend: 11 end_idx: 1000032 len: 2, start_time: 59893368.379, end_time: None
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2, start_time: 59893605.345, end_time: None
# PP start_backend: 11 start_idx: 1000033 end_backend: 11 end_idx: 1000033 len: 1, start_time: 59894502.065, end_time: None
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1, start_time: 59894502.363, end_time: None
# PP start_backend: 11 start_idx: 1000034 end_backend: 11 end_idx: 1000034 len: 1, start_time: 59895483.799, end_time: None
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000035 len: 1, start_time: 59895484.124, end_time: None
# PP start_backend: 11 start_idx: 1000035 end_backend: 11 end_idx: 1000036 len: 2, start_time: 59896462.673, end_time: None
# PP start_backend: 21 start_idx: 2000036 end_backend: 21 end_idx: 2000036 len: 1, start_time: 59897895.04, end_time: None
# PP start_backend: 11 start_idx: 1000037 end_backend: 11 end_idx: 1000037 len: 1, start_time: 59897895.448, end_time: None
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1, start_time: 59898054.025, end_time: None
# PP start_backend: 11 start_idx: 1000038 end_backend: 11 end_idx: 1000038 len: 1, start_time: 59898054.445, end_time: None
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2, start_time: 59898218.324, end_time: None
# PP start_backend: 11 start_idx: 1000039 end_backend: 11 end_idx: 1000040 len: 2, start_time: 59900612.05, end_time: None
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2, start_time: 59900845.017, end_time: None
# PP start_backend: 11 start_idx: 1000041 end_backend: 11 end_idx: 1000041 len: 1, start_time: 59901747.278, end_time: None
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1, start_time: 59901747.587, end_time: None
# PP start_backend: 11 start_idx: 1000042 end_backend: 11 end_idx: 1000042 len: 1, start_time: 59902728.561, end_time: None
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000043 len: 1, start_time: 59902728.84, end_time: None
# PP start_backend: 11 start_idx: 1000043 end_backend: 11 end_idx: 1000044 len: 2, start_time: 59903709.118, end_time: None
# PP start_backend: 21 start_idx: 2000044 end_backend: 21 end_idx: 2000044 len: 1, start_time: 59905338.461, end_time: None
# PP start_backend: 11 start_idx: 1000045 end_backend: 11 end_idx: 1000045 len: 1, start_time: 59905338.883, end_time: None
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1, start_time: 59905499.209, end_time: None
# PP start_backend: 11 start_idx: 1000046 end_backend: 11 end_idx: 1000046 len: 1, start_time: 59905499.601, end_time: None
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2, start_time: 59905668.805, end_time: None
# PP start_backend: 11 start_idx: 1000047 end_backend: 11 end_idx: 1000048 len: 2, start_time: 59908053.79, end_time: None
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2, start_time: 59908285.831, end_time: None
# PP start_backend: 11 start_idx: 1000049 end_backend: 11 end_idx: 1000049 len: 1, start_time: 59909177.953, end_time: None
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1, start_time: 59909178.287, end_time: None
# PP start_backend: 11 start_idx: 1000050 end_backend: 11 end_idx: 1000050 len: 1, start_time: 59910159.951, end_time: None
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000051 len: 1, start_time: 59910160.237, end_time: None
# PP start_backend: 11 start_idx: 1000051 end_backend: 11 end_idx: 1000052 len: 2, start_time: 59911139.682, end_time: None
# PP start_backend: 21 start_idx: 2000052 end_backend: 21 end_idx: 2000052 len: 1, start_time: 59912575.528, end_time: None
# PP start_backend: 11 start_idx: 1000053 end_backend: 11 end_idx: 1000053 len: 1, start_time: 59912575.962, end_time: None
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1, start_time: 59912735.799, end_time: None
# PP start_backend: 11 start_idx: 1000054 end_backend: 11 end_idx: 1000054 len: 1, start_time: 59912736.26, end_time: None
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2, start_time: 59912898.722, end_time: None
# PP start_backend: 11 start_idx: 1000055 end_backend: 11 end_idx: 1000056 len: 2, start_time: 59915293.784, end_time: None
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2, start_time: 59915523.402, end_time: None
# PP start_backend: 11 start_idx: 1000057 end_backend: 11 end_idx: 1000057 len: 1, start_time: 59916417.234, end_time: None
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1, start_time: 59916417.525, end_time: None
# PP start_backend: 11 start_idx: 1000058 end_backend: 11 end_idx: 1000058 len: 1, start_time: 59917398.044, end_time: None
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000059 len: 1, start_time: 59917398.322, end_time: None
# PP start_backend: 11 start_idx: 1000059 end_backend: 11 end_idx: 1000060 len: 2, start_time: 59918377.976, end_time: None
# PP start_backend: 21 start_idx: 2000060 end_backend: 21 end_idx: 2000060 len: 1, start_time: 59919811.762, end_time: None
# PP start_backend: 11 start_idx: 1000061 end_backend: 11 end_idx: 1000061 len: 1, start_time: 59919812.19, end_time: None
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1, start_time: 59919979.419, end_time: None
# PP start_backend: 11 start_idx: 1000062 end_backend: 11 end_idx: 1000062 len: 1, start_time: 59919979.8, end_time: None
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2, start_time: 59920137.613, end_time: None
# PP start_backend: 11 start_idx: 1000063 end_backend: 11 end_idx: 1000064 len: 2, start_time: 59922529.528, end_time: None
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2, start_time: 59922761.238, end_time: None
# PP start_backend: 11 start_idx: 1000065 end_backend: 11 end_idx: 1000065 len: 1, start_time: 59923657.627, end_time: None
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1, start_time: 59923657.93, end_time: None
# PP start_backend: 11 start_idx: 1000066 end_backend: 11 end_idx: 1000066 len: 1, start_time: 59924637.025, end_time: None
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000067 len: 1, start_time: 59924637.367, end_time: None
# PP start_backend: 11 start_idx: 1000067 end_backend: 11 end_idx: 1000068 len: 2, start_time: 59925617.394, end_time: None
# PP start_backend: 21 start_idx: 2000068 end_backend: 21 end_idx: 2000068 len: 1, start_time: 59927045.743, end_time: None
# PP start_backend: 11 start_idx: 1000069 end_backend: 11 end_idx: 1000069 len: 1, start_time: 59927046.165, end_time: None
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1, start_time: 59927207.543, end_time: None
# PP start_backend: 11 start_idx: 1000070 end_backend: 11 end_idx: 1000070 len: 1, start_time: 59927208.004, end_time: None
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2, start_time: 59927370.89, end_time: None
# PP start_backend: 11 start_idx: 1000071 end_backend: 11 end_idx: 1000072 len: 2, start_time: 59929759.21, end_time: None
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2, start_time: 59929993.614, end_time: None
# PP start_backend: 11 start_idx: 1000073 end_backend: 11 end_idx: 1000073 len: 1, start_time: 59930886.751, end_time: None
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1, start_time: 59930887.588, end_time: None
# PP start_backend: 11 start_idx: 1000074 end_backend: 11 end_idx: 1000074 len: 1, start_time: 59931866.824, end_time: None
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000075 len: 1, start_time: 59931867.755, end_time: None
# PP start_backend: 11 start_idx: 1000075 end_backend: 11 end_idx: 1000076 len: 2, start_time: 59932847.188, end_time: None
# PP start_backend: 21 start_idx: 2000076 end_backend: 21 end_idx: 2000076 len: 1, start_time: 59934276.962, end_time: None
# PP start_backend: 11 start_idx: 1000077 end_backend: 11 end_idx: 1000077 len: 1, start_time: 59934277.39, end_time: None
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1, start_time: 59934438.97, end_time: None
# PP start_backend: 11 start_idx: 1000078 end_backend: 11 end_idx: 1000078 len: 1, start_time: 59934439.419, end_time: None
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2, start_time: 59934600.882, end_time: None
# PP start_backend: 11 start_idx: 1000079 end_backend: 11 end_idx: 1000080 len: 2, start_time: 59936990.799, end_time: None
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2, start_time: 59937225.393, end_time: None
# PP start_backend: 11 start_idx: 1000081 end_backend: 11 end_idx: 1000081 len: 1, start_time: 59938123.123, end_time: None
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1, start_time: 59938123.442, end_time: None
# PP start_backend: 11 start_idx: 1000082 end_backend: 11 end_idx: 1000082 len: 1, start_time: 59939105.255, end_time: None
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1, start_time: 59939105.555, end_time: None
# PP start_backend: 11 start_idx: 1000083 end_backend: 11 end_idx: 1000083 len: 1, start_time: 59940084.574, end_time: None
# Node: 1, Rank: 3, Tid: 139842750940992
# PP start_backend: 11 start_idx: 1000000 end_backend: 11 end_idx: 1000000 len: 1, start_time: 59824044.276, end_time: None
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1, start_time: 59824045.163, end_time: None
# PP start_backend: 11 start_idx: 1000001 end_backend: 11 end_idx: 1000001 len: 1, start_time: 59824045.744, end_time: None
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1, start_time: 59824046.375, end_time: None
# ...
# PP start_backend: 31 start_idx: 3000069 end_backend: 31 end_idx: 3000070 len: 2, start_time: 59927344.697, end_time: None
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2, start_time: 59928807.41, end_time: None
# PP start_backend: 31 start_idx: 3000071 end_backend: 31 end_idx: 3000072 len: 2, start_time: 59929015.18, end_time: None
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2, start_time: 59929766.05, end_time: None
# PP start_backend: 31 start_idx: 3000073 end_backend: 31 end_idx: 3000074 len: 2, start_time: 59930134.008, end_time: None
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1, start_time: 59930885.698, end_time: None
# PP start_backend: 31 start_idx: 3000075 end_backend: 31 end_idx: 3000075 len: 1, start_time: 59930886.031, end_time: None
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000076 len: 2, start_time: 59931772.467, end_time: None
# PP start_backend: 31 start_idx: 3000076 end_backend: 31 end_idx: 3000076 len: 1, start_time: 59934414.448, end_time: None
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1, start_time: 59934414.762, end_time: None
# PP start_backend: 31 start_idx: 3000077 end_backend: 31 end_idx: 3000078 len: 2, start_time: 59934576.895, end_time: None
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2, start_time: 59936044.222, end_time: None
# PP start_backend: 31 start_idx: 3000079 end_backend: 31 end_idx: 3000080 len: 2, start_time: 59936245.554, end_time: None
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2, start_time: 59936996.902, end_time: None
# PP start_backend: 31 start_idx: 3000081 end_backend: 31 end_idx: 3000082 len: 2, start_time: 59937371.365, end_time: None
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1, start_time: 59938122.609, end_time: None
# PP start_backend: 31 start_idx: 3000083 end_backend: 31 end_idx: 3000083 len: 1, start_time: 59938123.064, end_time: None
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1, start_time: 59939009.933, end_time: None
# Node: 2, Rank: 3, Tid: 140265442469696
# PP start_backend: 21 start_idx: 2000000 end_backend: 21 end_idx: 2000000 len: 1, start_time: 59823077.162, end_time: None
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000000 len: 1, start_time: 59823077.746, end_time: None
# PP start_backend: 21 start_idx: 2000001 end_backend: 21 end_idx: 2000001 len: 1, start_time: 59823078.003, end_time: None
# PP start_backend: 31 start_idx: 3000001 end_backend: 31 end_idx: 3000001 len: 1, start_time: 59823083.121, end_time: None
# PP start_backend: 21 start_idx: 2000002 end_backend: 21 end_idx: 2000003 len: 2, start_time: 59824164.773, end_time: None
# PP start_backend: 31 start_idx: 3000002 end_backend: 31 end_idx: 3000003 len: 2, start_time: 59853908.023, end_time: None
# PP start_backend: 21 start_idx: 2000004 end_backend: 21 end_idx: 2000004 len: 1, start_time: 59853909.838, end_time: None
# PP start_backend: 31 start_idx: 3000004 end_backend: 31 end_idx: 3000004 len: 1, start_time: 59854128.216, end_time: None
# PP start_backend: 21 start_idx: 2000005 end_backend: 21 end_idx: 2000005 len: 1, start_time: 59854128.962, end_time: None
# PP start_backend: 31 start_idx: 3000005 end_backend: 31 end_idx: 3000006 len: 2, start_time: 59863999.643, end_time: None
# PP start_backend: 21 start_idx: 2000006 end_backend: 21 end_idx: 2000007 len: 2, start_time: 59868334.416, end_time: None
# PP start_backend: 31 start_idx: 3000007 end_backend: 31 end_idx: 3000008 len: 2, start_time: 59868552.188, end_time: None
# PP start_backend: 21 start_idx: 2000008 end_backend: 21 end_idx: 2000009 len: 2, start_time: 59869335.209, end_time: None
# PP start_backend: 31 start_idx: 3000009 end_backend: 31 end_idx: 3000010 len: 2, start_time: 59870361.863, end_time: None
# PP start_backend: 21 start_idx: 2000010 end_backend: 21 end_idx: 2000010 len: 1, start_time: 59871113.293, end_time: None
# PP start_backend: 31 start_idx: 3000011 end_backend: 31 end_idx: 3000011 len: 1, start_time: 59871113.822, end_time: None
# PP start_backend: 21 start_idx: 2000011 end_backend: 21 end_idx: 2000012 len: 2, start_time: 59872032.216, end_time: None
# PP start_backend: 31 start_idx: 3000012 end_backend: 31 end_idx: 3000012 len: 1, start_time: 59876175.793, end_time: None
# PP start_backend: 21 start_idx: 2000013 end_backend: 21 end_idx: 2000013 len: 1, start_time: 59876176.35, end_time: None
# PP start_backend: 31 start_idx: 3000013 end_backend: 31 end_idx: 3000014 len: 2, start_time: 59876351.077, end_time: None
# PP start_backend: 21 start_idx: 2000014 end_backend: 21 end_idx: 2000015 len: 2, start_time: 59877800.957, end_time: None
# PP start_backend: 31 start_idx: 3000015 end_backend: 31 end_idx: 3000016 len: 2, start_time: 59878020.473, end_time: None
# PP start_backend: 21 start_idx: 2000016 end_backend: 21 end_idx: 2000017 len: 2, start_time: 59878793.882, end_time: None
# PP start_backend: 31 start_idx: 3000017 end_backend: 31 end_idx: 3000018 len: 2, start_time: 59879191.877, end_time: None
# PP start_backend: 21 start_idx: 2000018 end_backend: 21 end_idx: 2000018 len: 1, start_time: 59879937.66, end_time: None
# PP start_backend: 31 start_idx: 3000019 end_backend: 31 end_idx: 3000019 len: 1, start_time: 59879938.118, end_time: None
# PP start_backend: 21 start_idx: 2000019 end_backend: 21 end_idx: 2000020 len: 2, start_time: 59880845.781, end_time: None
# PP start_backend: 31 start_idx: 3000020 end_backend: 31 end_idx: 3000020 len: 1, start_time: 59883506.594, end_time: None
# PP start_backend: 21 start_idx: 2000021 end_backend: 21 end_idx: 2000021 len: 1, start_time: 59883506.927, end_time: None
# PP start_backend: 31 start_idx: 3000021 end_backend: 31 end_idx: 3000022 len: 2, start_time: 59883662.435, end_time: None
# PP start_backend: 21 start_idx: 2000022 end_backend: 21 end_idx: 2000023 len: 2, start_time: 59885134.523, end_time: None
# PP start_backend: 31 start_idx: 3000023 end_backend: 31 end_idx: 3000024 len: 2, start_time: 59885353.331, end_time: None
# PP start_backend: 21 start_idx: 2000024 end_backend: 21 end_idx: 2000025 len: 2, start_time: 59886100.005, end_time: None
# PP start_backend: 31 start_idx: 3000025 end_backend: 31 end_idx: 3000026 len: 2, start_time: 59886508.792, end_time: None
# PP start_backend: 21 start_idx: 2000026 end_backend: 21 end_idx: 2000026 len: 1, start_time: 59887255.53, end_time: None
# PP start_backend: 31 start_idx: 3000027 end_backend: 31 end_idx: 3000027 len: 1, start_time: 59887255.812, end_time: None
# PP start_backend: 21 start_idx: 2000027 end_backend: 21 end_idx: 2000028 len: 2, start_time: 59888154.313, end_time: None
# PP start_backend: 31 start_idx: 3000028 end_backend: 31 end_idx: 3000028 len: 1, start_time: 59890788.261, end_time: None
# PP start_backend: 21 start_idx: 2000029 end_backend: 21 end_idx: 2000029 len: 1, start_time: 59890788.514, end_time: None
# PP start_backend: 31 start_idx: 3000029 end_backend: 31 end_idx: 3000030 len: 2, start_time: 59890947.437, end_time: None
# PP start_backend: 21 start_idx: 2000030 end_backend: 21 end_idx: 2000031 len: 2, start_time: 59892412.118, end_time: None
# PP start_backend: 31 start_idx: 3000031 end_backend: 31 end_idx: 3000032 len: 2, start_time: 59892622.551, end_time: None
# PP start_backend: 21 start_idx: 2000032 end_backend: 21 end_idx: 2000033 len: 2, start_time: 59893367.1, end_time: None
# PP start_backend: 31 start_idx: 3000033 end_backend: 31 end_idx: 3000034 len: 2, start_time: 59893763.344, end_time: None
# PP start_backend: 21 start_idx: 2000034 end_backend: 21 end_idx: 2000034 len: 1, start_time: 59894509.69, end_time: None
# PP start_backend: 31 start_idx: 3000035 end_backend: 31 end_idx: 3000035 len: 1, start_time: 59894510.019, end_time: None
# PP start_backend: 21 start_idx: 2000035 end_backend: 21 end_idx: 2000036 len: 2, start_time: 59895402.131, end_time: None
# PP start_backend: 31 start_idx: 3000036 end_backend: 31 end_idx: 3000036 len: 1, start_time: 59898034.564, end_time: None
# PP start_backend: 21 start_idx: 2000037 end_backend: 21 end_idx: 2000037 len: 1, start_time: 59898035.274, end_time: None
# PP start_backend: 31 start_idx: 3000037 end_backend: 31 end_idx: 3000038 len: 2, start_time: 59898194.286, end_time: None
# PP start_backend: 21 start_idx: 2000038 end_backend: 21 end_idx: 2000039 len: 2, start_time: 59899654.144, end_time: None
# PP start_backend: 31 start_idx: 3000039 end_backend: 31 end_idx: 3000040 len: 2, start_time: 59899867.74, end_time: None
# PP start_backend: 21 start_idx: 2000040 end_backend: 21 end_idx: 2000041 len: 2, start_time: 59900610.191, end_time: None
# PP start_backend: 31 start_idx: 3000041 end_backend: 31 end_idx: 3000042 len: 2, start_time: 59900993.106, end_time: None
# PP start_backend: 21 start_idx: 2000042 end_backend: 21 end_idx: 2000042 len: 1, start_time: 59901739.081, end_time: None
# PP start_backend: 31 start_idx: 3000043 end_backend: 31 end_idx: 3000043 len: 1, start_time: 59901739.384, end_time: None
# PP start_backend: 21 start_idx: 2000043 end_backend: 21 end_idx: 2000044 len: 2, start_time: 59902627.834, end_time: None
# PP start_backend: 31 start_idx: 3000044 end_backend: 31 end_idx: 3000044 len: 1, start_time: 59905476.679, end_time: None
# PP start_backend: 21 start_idx: 2000045 end_backend: 21 end_idx: 2000045 len: 1, start_time: 59905476.993, end_time: None
# PP start_backend: 31 start_idx: 3000045 end_backend: 31 end_idx: 3000046 len: 2, start_time: 59905637.139, end_time: None
# PP start_backend: 21 start_idx: 2000046 end_backend: 21 end_idx: 2000047 len: 2, start_time: 59907097.207, end_time: None
# PP start_backend: 31 start_idx: 3000047 end_backend: 31 end_idx: 3000048 len: 2, start_time: 59907308.882, end_time: None
# PP start_backend: 21 start_idx: 2000048 end_backend: 21 end_idx: 2000049 len: 2, start_time: 59908054.081, end_time: None
# PP start_backend: 31 start_idx: 3000049 end_backend: 31 end_idx: 3000050 len: 2, start_time: 59908430.79, end_time: None
# PP start_backend: 21 start_idx: 2000050 end_backend: 21 end_idx: 2000050 len: 1, start_time: 59909177.904, end_time: None
# PP start_backend: 31 start_idx: 3000051 end_backend: 31 end_idx: 3000051 len: 1, start_time: 59909178.188, end_time: None
# PP start_backend: 21 start_idx: 2000051 end_backend: 21 end_idx: 2000052 len: 2, start_time: 59910064.7, end_time: None
# PP start_backend: 31 start_idx: 3000052 end_backend: 31 end_idx: 3000052 len: 1, start_time: 59912715.466, end_time: None
# PP start_backend: 21 start_idx: 2000053 end_backend: 21 end_idx: 2000053 len: 1, start_time: 59912715.786, end_time: None
# PP start_backend: 31 start_idx: 3000053 end_backend: 31 end_idx: 3000054 len: 2, start_time: 59912874.636, end_time: None
# PP start_backend: 21 start_idx: 2000054 end_backend: 21 end_idx: 2000055 len: 2, start_time: 59914335.979, end_time: None
# PP start_backend: 31 start_idx: 3000055 end_backend: 31 end_idx: 3000056 len: 2, start_time: 59914556.009, end_time: None
# PP start_backend: 21 start_idx: 2000056 end_backend: 21 end_idx: 2000057 len: 2, start_time: 59915304.482, end_time: None
# PP start_backend: 31 start_idx: 3000057 end_backend: 31 end_idx: 3000058 len: 2, start_time: 59915665.868, end_time: None
# PP start_backend: 21 start_idx: 2000058 end_backend: 21 end_idx: 2000058 len: 1, start_time: 59916413.14, end_time: None
# PP start_backend: 31 start_idx: 3000059 end_backend: 31 end_idx: 3000059 len: 1, start_time: 59916413.529, end_time: None
# PP start_backend: 21 start_idx: 2000059 end_backend: 21 end_idx: 2000060 len: 2, start_time: 59917300.455, end_time: None
# PP start_backend: 31 start_idx: 3000060 end_backend: 31 end_idx: 3000060 len: 1, start_time: 59919949.104, end_time: None
# PP start_backend: 21 start_idx: 2000061 end_backend: 21 end_idx: 2000061 len: 1, start_time: 59919949.568, end_time: None
# PP start_backend: 31 start_idx: 3000061 end_backend: 31 end_idx: 3000062 len: 2, start_time: 59920116.297, end_time: None
# PP start_backend: 21 start_idx: 2000062 end_backend: 21 end_idx: 2000063 len: 2, start_time: 59921574.28, end_time: None
# PP start_backend: 31 start_idx: 3000063 end_backend: 31 end_idx: 3000064 len: 2, start_time: 59921783.134, end_time: None
# PP start_backend: 21 start_idx: 2000064 end_backend: 21 end_idx: 2000065 len: 2, start_time: 59922536.335, end_time: None
# PP start_backend: 31 start_idx: 3000065 end_backend: 31 end_idx: 3000066 len: 2, start_time: 59922902.07, end_time: None
# PP start_backend: 21 start_idx: 2000066 end_backend: 21 end_idx: 2000066 len: 1, start_time: 59923652.42, end_time: None
# PP start_backend: 31 start_idx: 3000067 end_backend: 31 end_idx: 3000067 len: 1, start_time: 59923652.752, end_time: None
# PP start_backend: 21 start_idx: 2000067 end_backend: 21 end_idx: 2000068 len: 2, start_time: 59924538.193, end_time: None
# PP start_backend: 31 start_idx: 3000068 end_backend: 31 end_idx: 3000068 len: 1, start_time: 59927183.498, end_time: None
# PP start_backend: 21 start_idx: 2000069 end_backend: 21 end_idx: 2000069 len: 1, start_time: 59927183.861, end_time: None
# PP start_backend: 31 start_idx: 3000069 end_backend: 31 end_idx: 3000070 len: 2, start_time: 59927344.697, end_time: None
# PP start_backend: 21 start_idx: 2000070 end_backend: 21 end_idx: 2000071 len: 2, start_time: 59928807.41, end_time: None
# PP start_backend: 31 start_idx: 3000071 end_backend: 31 end_idx: 3000072 len: 2, start_time: 59929015.18, end_time: None
# PP start_backend: 21 start_idx: 2000072 end_backend: 21 end_idx: 2000073 len: 2, start_time: 59929766.05, end_time: None
# PP start_backend: 31 start_idx: 3000073 end_backend: 31 end_idx: 3000074 len: 2, start_time: 59930134.008, end_time: None
# PP start_backend: 21 start_idx: 2000074 end_backend: 21 end_idx: 2000074 len: 1, start_time: 59930885.698, end_time: None
# PP start_backend: 31 start_idx: 3000075 end_backend: 31 end_idx: 3000075 len: 1, start_time: 59930886.031, end_time: None
# PP start_backend: 21 start_idx: 2000075 end_backend: 21 end_idx: 2000076 len: 2, start_time: 59931772.467, end_time: None
# PP start_backend: 31 start_idx: 3000076 end_backend: 31 end_idx: 3000076 len: 1, start_time: 59934414.448, end_time: None
# PP start_backend: 21 start_idx: 2000077 end_backend: 21 end_idx: 2000077 len: 1, start_time: 59934414.762, end_time: None
# PP start_backend: 31 start_idx: 3000077 end_backend: 31 end_idx: 3000078 len: 2, start_time: 59934576.895, end_time: None
# PP start_backend: 21 start_idx: 2000078 end_backend: 21 end_idx: 2000079 len: 2, start_time: 59936044.222, end_time: None
# PP start_backend: 31 start_idx: 3000079 end_backend: 31 end_idx: 3000080 len: 2, start_time: 59936245.554, end_time: None
# PP start_backend: 21 start_idx: 2000080 end_backend: 21 end_idx: 2000081 len: 2, start_time: 59936996.902, end_time: None
# PP start_backend: 31 start_idx: 3000081 end_backend: 31 end_idx: 3000082 len: 2, start_time: 59937371.365, end_time: None
# PP start_backend: 21 start_idx: 2000082 end_backend: 21 end_idx: 2000082 len: 1, start_time: 59938122.609, end_time: None
# PP start_backend: 31 start_idx: 3000083 end_backend: 31 end_idx: 3000083 len: 1, start_time: 59938123.064, end_time: None
# PP start_backend: 21 start_idx: 2000083 end_backend: 21 end_idx: 2000083 len: 1, start_time: 59939009.933, end_time: None
# [140478540224320, 140478540224320, 140478540224320, 140478540224320]
# Node: 3, Rank: 0, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84, start_time: 59824001.257, end_time: None
# Node: 3, Rank: 1, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84, start_time: 59824001.257, end_time: None
# Node: 3, Rank: 2, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84, start_time: 59824001.257, end_time: None
# Node: 3, Rank: 3, Tid: 140478540224320
# PP start_backend: 31 start_idx: 3000000 end_backend: 31 end_idx: 3000083 len: 84, start_time: 59824001.257, end_time: None

# %%
import re
import argparse
import datetime
import numpy as np

# backend 0 default, backend 1 pp, backend 2, 5, 6 DP, backend 3 TP

def custom_print(message, file_path=None, mode='a'):
    print(message)  # Print to terminal
    if file_path:
        with open(file_path, mode) as file:
            file.write(message + '\n')

def backend_to_comm_type(backend, rank_tid=None):
    if backend == 0:
        return "Default"
    elif backend == 1:
        return "PP"
    elif backend in [2, 5, 6]:
        return "DP"
    elif backend == 3:
        return "TP"
    else:
        return "unknown"
    
def is_same_comm_type(backend1, backend2):
    return backend_to_comm_type(backend1) == backend_to_comm_type(backend2)

def time_to_ms(t):
    return (
        t.hour * 3600_000 +
        t.minute * 60_000 +
        t.second * 1000 +
        t.microsecond / 1000.0
    )

def parse_communication_pattern(log_file, rank_tid):
    main_pat = re.compile(
        r"Backend (\d+) RANK (\d+) tid: (\d+) .*?Idx: (\d+),"
    )
    time_pat = re.compile(
        r"t:\[(\d+:\d+:\d+\.\d+)\]"
    )

    communication_pattern = []

    start_backend = None
    end_backend = None

    idx_list = None

    start_time = None
    end_time = None

    # Track per-idx timestamps
    idx_start_times = {}
    idx_end_times = {}

    time_gap = {}

    with open(log_file, 'r') as file:
        for line in file:
            match = main_pat.search(line)
            if not match:
                continue

            backend = int(match.group(1))
            tid = int(match.group(3))
            idx = int(match.group(4))

            # filter
            if backend_to_comm_type(backend) == "TP" or backend == 0:
                continue
            if tid != rank_tid:
                continue

            # extract timestamp if present
            tmatch = time_pat.search(line)
            ts = None
            if tmatch:
                ts = datetime.datetime.strptime(tmatch.group(1), "%H:%M:%S.%f")
                ts = time_to_ms(ts)

            # record pre/post timestamps
            if "pre_coll" in line and ts:
                idx_start_times[(backend, idx)] = ts
            elif "post_coll" in line and ts:
                idx_end_times[(backend, idx)] = ts

            # comm-type transition
            if "pre_coll" in line:
                if not is_same_comm_type(backend, start_backend):
                    if start_backend is not None:
                        communication_pattern.append(
                            (start_backend, idx_list, end_backend, start_time, end_time)
                        )
                    
                    start_time = ts
                    if end_time:
                        time_gap[(start_backend, idx_list[0])] = start_time - end_time
                    start_backend = backend
                    idx_list = [idx]
                else:
                    end_backend = backend
                    idx_list.append(idx)

            if "post_coll" in line:
                end_time = ts

        # flush last segment
        if start_backend is not None:
            communication_pattern.append(
                (start_backend, idx_list, end_backend, start_time, end_time)
            )

    return communication_pattern, time_gap


output_file = "comm_pattern_pp_0.txt"
with open(output_file, 'w') as file:
    file.truncate(0)
log_file = f"<path-to-opus>/Opus/torchtitan/opus-test/dp-8-pp-2-tp-4-pm-8b/output-opus-no-ctl-dp8/torchrun_nid002320.ans"

pattern, time_gap_map_pp0 = parse_communication_pattern(log_file, 140550800791104)

for backend, idx_list, end_backend, start_time, end_time in pattern:
    custom_print(f"{backend_to_comm_type(backend)} start_backend: {backend} start_idx: {idx_list[0]} end_backend: {end_backend} end_idx: {idx_list[-1]} len: {len(idx_list)}, start_time: {start_time}, end_time: {end_time}", output_file)

# if time_gap_list:
#     avg_gap = np.mean(time_gap_list)
#     std_gap = np.std(time_gap_list)
#     min_gap = np.min(time_gap_list)
#     max_gap = np.max(time_gap_list)

#     custom_print(f"Average time gap: {avg_gap:.3f} ms", output_file)
#     custom_print(f"Standard deviation: {std_gap:.3f} ms", output_file)
#     custom_print(f"Minimum time gap: {min_gap:.3f} ms", output_file)
#     custom_print(f"Maximum time gap: {max_gap:.3f} ms", output_file)
# else:
#     custom_print("No time gaps to calculate statistics.")


output_file = "comm_pattern_pp_1.txt"
with open(output_file, 'w') as file:
    file.truncate(0)
log_file = f"<path-to-opus>/Opus/torchtitan/opus-test/dp-8-pp-2-tp-4-pm-8b/output-opus-no-ctl-dp8/torchrun_nid002617.ans"

pattern, time_gap_map_pp1 = parse_communication_pattern(log_file, 140231076472384)

for backend, idx_list, end_backend, start_time, end_time in pattern:
    custom_print(f"{backend_to_comm_type(backend)} start_backend: {backend} start_idx: {idx_list[0]} end_backend: {end_backend} end_idx: {idx_list[-1]} len: {len(idx_list)}, start_time: {start_time}, end_time: {end_time}", output_file)

common_gap = []
for (key1, gap1)in time_gap_map_pp0.items():
    for (key2, gap2) in time_gap_map_pp1.items():
        if key1 == key2 and key1[0] == 1:  # Check if backend and idx are the same
            min_gap = min(gap1, gap2)
            custom_print(f"Backend: {key1[0]}, Idx: {key1[1]}, Min Gap: {min_gap:.3f} ms", output_file)
            common_gap.append(min_gap)

if common_gap:
    avg_gap = np.mean(common_gap)
    std_gap = np.std(common_gap)
    min_gap = np.min(common_gap)
    max_gap = np.max(common_gap)

    custom_print(f"Average time gap: {avg_gap:.3f} ms", output_file)
    custom_print(f"Standard deviation: {std_gap:.3f} ms", output_file)
    custom_print(f"Minimum time gap: {min_gap:.3f} ms", output_file)
    custom_print(f"Maximum time gap: {max_gap:.3f} ms", output_file)
# Out:
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2, start_time: 62779452.516, end_time: 62779453.878
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17, start_time: 62780833.563, end_time: 62784970.478
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2, start_time: 62785005.1, end_time: 62785008.84
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17, start_time: 62785010.149, end_time: 62786920.867
# PP start_backend: 1 start_idx: 4 end_backend: 5 end_idx: 4 len: 1, start_time: 62786951.262, end_time: 62786958.389
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17, start_time: 62788973.8, end_time: 62790878.244
# PP start_backend: 1 start_idx: 5 end_backend: 5 end_idx: 5 len: 1, start_time: 62790912.08, end_time: 62790878.244
# DP start_backend: 5 start_idx: 51 end_backend: 5 end_idx: 51 len: 1, start_time: 62790912.767, end_time: 62790913.488
# PP start_backend: 1 start_idx: 6 end_backend: 5 end_idx: 6 len: 1, start_time: 62790914.417, end_time: 62791069.659
# DP start_backend: 5 start_idx: 52 end_backend: 5 end_idx: 67 len: 16, start_time: 62795352.044, end_time: 62798135.107
# PP start_backend: 1 start_idx: 7 end_backend: 5 end_idx: 7 len: 1, start_time: 62798802.922, end_time: 62798803.153
# DP start_backend: 5 start_idx: 68 end_backend: 5 end_idx: 85 len: 18, start_time: 62800178.848, end_time: 62804033.348
# PP start_backend: 1 start_idx: 8 end_backend: 5 end_idx: 8 len: 1, start_time: 62804462.208, end_time: 62804491.898
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 102 len: 20, start_time: 62804875.527, end_time: 62806944.039
# PP start_backend: 1 start_idx: 9 end_backend: 5 end_idx: 9 len: 1, start_time: 62806973.533, end_time: 62806974.482
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 119 len: 17, start_time: 62807001.09, end_time: 62808933.668
# PP start_backend: 1 start_idx: 10 end_backend: 5 end_idx: 10 len: 1, start_time: 62808959.983, end_time: 62808933.668
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 120 len: 1, start_time: 62808960.957, end_time: 62808961.635
# PP start_backend: 1 start_idx: 11 end_backend: 5 end_idx: 11 len: 1, start_time: 62808961.8, end_time: 62809042.649
# DP start_backend: 5 start_idx: 121 end_backend: 5 end_idx: 136 len: 16, start_time: 62811859.464, end_time: 62814440.675
# PP start_backend: 1 start_idx: 12 end_backend: 5 end_idx: 12 len: 1, start_time: 62814518.966, end_time: 62814519.822
# DP start_backend: 5 start_idx: 137 end_backend: 5 end_idx: 154 len: 18, start_time: 62816333.898, end_time: 62819463.608
# PP start_backend: 1 start_idx: 13 end_backend: 5 end_idx: 13 len: 1, start_time: 62819467.242, end_time: 62819467.979
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 171 len: 20, start_time: 62819472.415, end_time: 62821484.426
# PP start_backend: 1 start_idx: 14 end_backend: 5 end_idx: 14 len: 1, start_time: 62821509.718, end_time: 62821511.065
# DP start_backend: 5 start_idx: 172 end_backend: 5 end_idx: 188 len: 17, start_time: 62821533.062, end_time: 62823574.581
# PP start_backend: 1 start_idx: 15 end_backend: 5 end_idx: 15 len: 1, start_time: 62823602.99, end_time: 62823574.581
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 189 len: 1, start_time: 62823604.087, end_time: 62823605.003
# PP start_backend: 1 start_idx: 16 end_backend: 5 end_idx: 16 len: 1, start_time: 62823606.983, end_time: 62823684.345
# DP start_backend: 5 start_idx: 190 end_backend: 5 end_idx: 205 len: 16, start_time: 62826346.223, end_time: 62828870.715
# PP start_backend: 1 start_idx: 17 end_backend: 5 end_idx: 17 len: 1, start_time: 62828967.664, end_time: 62828971.726
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 223 len: 18, start_time: 62830802.172, end_time: 62833951.764
# PP start_backend: 1 start_idx: 18 end_backend: 5 end_idx: 18 len: 1, start_time: 62833962.334, end_time: 62833963.033
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 240 len: 20, start_time: 62833967.449, end_time: 62835971.51
# PP start_backend: 1 start_idx: 19 end_backend: 5 end_idx: 19 len: 1, start_time: 62836007.237, end_time: 62836008.668
# DP start_backend: 5 start_idx: 241 end_backend: 5 end_idx: 257 len: 17, start_time: 62836032.831, end_time: 62837964.977
# PP start_backend: 1 start_idx: 20 end_backend: 5 end_idx: 20 len: 1, start_time: 62837998.18, end_time: 62837964.977
# DP start_backend: 5 start_idx: 258 end_backend: 5 end_idx: 258 len: 1, start_time: 62837999.315, end_time: 62838000.484
# PP start_backend: 1 start_idx: 21 end_backend: 5 end_idx: 21 len: 1, start_time: 62838001.393, end_time: 62838075.008
# DP start_backend: 5 start_idx: 259 end_backend: 5 end_idx: 274 len: 16, start_time: 62840800.49, end_time: 62843410.768
# PP start_backend: 1 start_idx: 22 end_backend: 5 end_idx: 22 len: 1, start_time: 62843512.774, end_time: 62843513.858
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 292 len: 18, start_time: 62845264.32, end_time: 62848397.257
# PP start_backend: 1 start_idx: 23 end_backend: 5 end_idx: 23 len: 1, start_time: 62848420.601, end_time: 62848421.262
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 309 len: 20, start_time: 62848425.88, end_time: 62850489.446
# PP start_backend: 1 start_idx: 24 end_backend: 5 end_idx: 24 len: 1, start_time: 62850527.225, end_time: 62850527.813
# DP start_backend: 5 start_idx: 310 end_backend: 5 end_idx: 326 len: 17, start_time: 62850547.02, end_time: 62852481.022
# PP start_backend: 1 start_idx: 25 end_backend: 5 end_idx: 25 len: 1, start_time: 62852512.752, end_time: 62852481.022
# DP start_backend: 5 start_idx: 327 end_backend: 5 end_idx: 327 len: 1, start_time: 62852514.337, end_time: 62852515.385
# PP start_backend: 1 start_idx: 26 end_backend: 5 end_idx: 26 len: 1, start_time: 62852516.357, end_time: 62852588.322
# DP start_backend: 5 start_idx: 328 end_backend: 5 end_idx: 343 len: 16, start_time: 62855234.433, end_time: 62857884.456
# PP start_backend: 1 start_idx: 27 end_backend: 5 end_idx: 27 len: 1, start_time: 62857997.562, end_time: 62857998.335
# DP start_backend: 5 start_idx: 344 end_backend: 5 end_idx: 361 len: 18, start_time: 62859728.95, end_time: 62862819.511
# PP start_backend: 1 start_idx: 28 end_backend: 5 end_idx: 28 len: 1, start_time: 62862846.466, end_time: 62862848.012
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 378 len: 20, start_time: 62862856.674, end_time: 62864941.814
# PP start_backend: 1 start_idx: 29 end_backend: 5 end_idx: 29 len: 1, start_time: 62864977.517, end_time: 62864978.757
# DP start_backend: 5 start_idx: 379 end_backend: 5 end_idx: 395 len: 17, start_time: 62864997.929, end_time: 62866929.866
# PP start_backend: 1 start_idx: 30 end_backend: 5 end_idx: 30 len: 1, start_time: 62866963.645, end_time: 62866929.866
# DP start_backend: 5 start_idx: 396 end_backend: 5 end_idx: 396 len: 1, start_time: 62866965.137, end_time: 62866965.835
# PP start_backend: 1 start_idx: 31 end_backend: 5 end_idx: 31 len: 1, start_time: 62866966.489, end_time: 62867039.994
# DP start_backend: 5 start_idx: 397 end_backend: 5 end_idx: 412 len: 16, start_time: 62869773.023, end_time: 62872356.53
# PP start_backend: 1 start_idx: 32 end_backend: 5 end_idx: 32 len: 1, start_time: 62872464.198, end_time: 62872465.39
# DP start_backend: 5 start_idx: 413 end_backend: 5 end_idx: 430 len: 18, start_time: 62874212.652, end_time: 62877199.425
# PP start_backend: 1 start_idx: 33 end_backend: 5 end_idx: 33 len: 1, start_time: 62877222.159, end_time: 62877223.361
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 447 len: 20, start_time: 62877227.966, end_time: 62879317.616
# PP start_backend: 1 start_idx: 34 end_backend: 5 end_idx: 34 len: 1, start_time: 62879351.974, end_time: 62879352.549
# DP start_backend: 5 start_idx: 448 end_backend: 5 end_idx: 464 len: 17, start_time: 62879374.145, end_time: 62881286.754
# PP start_backend: 1 start_idx: 35 end_backend: 5 end_idx: 35 len: 1, start_time: 62881318.725, end_time: 62881286.754
# DP start_backend: 5 start_idx: 465 end_backend: 5 end_idx: 465 len: 1, start_time: 62881319.408, end_time: 62881319.596
# PP start_backend: 1 start_idx: 36 end_backend: 5 end_idx: 36 len: 1, start_time: 62881320.325, end_time: 62881394.191
# DP start_backend: 5 start_idx: 466 end_backend: 5 end_idx: 481 len: 16, start_time: 62884107.205, end_time: 62886666.716
# PP start_backend: 1 start_idx: 37 end_backend: 5 end_idx: 37 len: 1, start_time: 62886777.127, end_time: 62886778.183
# DP start_backend: 5 start_idx: 482 end_backend: 5 end_idx: 499 len: 18, start_time: 62888580.412, end_time: 62891579.539
# PP start_backend: 1 start_idx: 38 end_backend: 5 end_idx: 38 len: 1, start_time: 62891592.366, end_time: 62891592.899
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 516 len: 20, start_time: 62891597.284, end_time: 62893537.772
# PP start_backend: 1 start_idx: 39 end_backend: 5 end_idx: 39 len: 1, start_time: 62893569.976, end_time: 62893570.773
# DP start_backend: 5 start_idx: 517 end_backend: 5 end_idx: 533 len: 17, start_time: 62893591.986, end_time: 62895528.869
# PP start_backend: 1 start_idx: 40 end_backend: 5 end_idx: 40 len: 1, start_time: 62895561.751, end_time: 62895528.869
# DP start_backend: 5 start_idx: 534 end_backend: 5 end_idx: 534 len: 1, start_time: 62895566.931, end_time: 62895567.656
# PP start_backend: 1 start_idx: 41 end_backend: 5 end_idx: 41 len: 1, start_time: 62895568.55, end_time: 62895638.677
# DP start_backend: 5 start_idx: 535 end_backend: 5 end_idx: 550 len: 16, start_time: 62898397.669, end_time: 62900975.634
# PP start_backend: 1 start_idx: 42 end_backend: 5 end_idx: 42 len: 1, start_time: 62901068.07, end_time: 62901069.044
# DP start_backend: 5 start_idx: 551 end_backend: 5 end_idx: 568 len: 18, start_time: 62902892.395, end_time: 62905934.491
# PP start_backend: 1 start_idx: 43 end_backend: 5 end_idx: 43 len: 1, start_time: 62905948.335, end_time: 62905949.07
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 585 len: 20, start_time: 62905953.502, end_time: 62907970.315
# PP start_backend: 1 start_idx: 44 end_backend: 5 end_idx: 44 len: 1, start_time: 62908001.391, end_time: 62908006.875
# DP start_backend: 5 start_idx: 586 end_backend: 5 end_idx: 602 len: 17, start_time: 62908028.601, end_time: 62909909.691
# PP start_backend: 1 start_idx: 45 end_backend: 5 end_idx: 45 len: 1, start_time: 62909944.395, end_time: 62909909.691
# DP start_backend: 5 start_idx: 603 end_backend: 5 end_idx: 603 len: 1, start_time: 62909952.28, end_time: 62909953.21
# PP start_backend: 1 start_idx: 46 end_backend: 5 end_idx: 46 len: 1, start_time: 62909954.174, end_time: 62910022.989
# DP start_backend: 5 start_idx: 604 end_backend: 5 end_idx: 619 len: 16, start_time: 62912800.77, end_time: 62915391.063
# PP start_backend: 1 start_idx: 47 end_backend: 5 end_idx: 47 len: 1, start_time: 62915477.651, end_time: 62915478.808
# DP start_backend: 5 start_idx: 620 end_backend: 5 end_idx: 637 len: 18, start_time: 62917330.625, end_time: 62920642.881
# PP start_backend: 1 start_idx: 48 end_backend: 5 end_idx: 48 len: 1, start_time: 62920676.007, end_time: 62920676.616
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 654 len: 20, start_time: 62920681.044, end_time: 62922708.733
# PP start_backend: 1 start_idx: 49 end_backend: 5 end_idx: 49 len: 1, start_time: 62922744.343, end_time: 62922745.408
# DP start_backend: 5 start_idx: 655 end_backend: 5 end_idx: 671 len: 17, start_time: 62922767.077, end_time: 62924728.503
# PP start_backend: 1 start_idx: 50 end_backend: 5 end_idx: 50 len: 1, start_time: 62924763.14, end_time: 62924728.503
# DP start_backend: 5 start_idx: 672 end_backend: 5 end_idx: 672 len: 1, start_time: 62924764.282, end_time: 62924765.168
# PP start_backend: 1 start_idx: 51 end_backend: 5 end_idx: 51 len: 1, start_time: 62924766.017, end_time: 62924847.415
# DP start_backend: 5 start_idx: 673 end_backend: 5 end_idx: 688 len: 16, start_time: 62927604.9, end_time: 62930161.427
# PP start_backend: 1 start_idx: 52 end_backend: 5 end_idx: 52 len: 1, start_time: 62930261.327, end_time: 62930262.419
# DP start_backend: 5 start_idx: 689 end_backend: 5 end_idx: 706 len: 18, start_time: 62932106.597, end_time: 62935357.696
# PP start_backend: 1 start_idx: 53 end_backend: 5 end_idx: 53 len: 1, start_time: 62935386.1, end_time: 62935386.512
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3, start_time: 62935390.997, end_time: 62935405.023
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4, start_time: 62780551.197, end_time: 62785022.041
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17, start_time: 62785229.887, end_time: 62788883.527
# PP start_backend: 1 start_idx: 4 end_backend: 5 end_idx: 4 len: 1, start_time: 62788916.686, end_time: 62788916.948
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 50 len: 34, start_time: 62788982.275, end_time: 62795146.686
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 6 len: 2, start_time: 62795294.328, end_time: 62795297.283
# DP start_backend: 5 start_idx: 51 end_backend: 5 end_idx: 67 len: 17, start_time: 62795851.253, end_time: 62798605.702
# PP start_backend: 1 start_idx: 7 end_backend: 5 end_idx: 7 len: 1, start_time: 62798757.86, end_time: 62798758.182
# DP start_backend: 5 start_idx: 68 end_backend: 5 end_idx: 85 len: 18, start_time: 62798983.829, end_time: 62802553.854
# PP start_backend: 1 start_idx: 8 end_backend: 5 end_idx: 8 len: 1, start_time: 62802821.442, end_time: 62804492.253
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3, start_time: 62804909.033, end_time: 62805017.53
# PP start_backend: 1 start_idx: 9 end_backend: 6 end_idx: 9 len: 1, start_time: 62805070.721, end_time: 62805071.151
# DP start_backend: 5 start_idx: 86 end_backend: 5 end_idx: 119 len: 34, start_time: 62807004.081, end_time: 62811650.393
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 11 len: 2, start_time: 62811800.849, end_time: 62811803.641
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17, start_time: 62812362.299, end_time: 62814953.896
# PP start_backend: 1 start_idx: 12 end_backend: 5 end_idx: 12 len: 1, start_time: 62815109.438, end_time: 62815110.514
# DP start_backend: 5 start_idx: 137 end_backend: 5 end_idx: 154 len: 18, start_time: 62815140.47, end_time: 62818330.751
# PP start_backend: 1 start_idx: 13 end_backend: 5 end_idx: 13 len: 1, start_time: 62818340.495, end_time: 62819467.515
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3, start_time: 62819471.498, end_time: 62819478.583
# PP start_backend: 1 start_idx: 14 end_backend: 6 end_idx: 14 len: 1, start_time: 62819525.021, end_time: 62819525.323
# DP start_backend: 5 start_idx: 155 end_backend: 5 end_idx: 188 len: 34, start_time: 62821535.655, end_time: 62826142.607
# PP start_backend: 1 start_idx: 15 end_backend: 1 end_idx: 16 len: 2, start_time: 62826290.044, end_time: 62826293.248
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 205 len: 17, start_time: 62826844.803, end_time: 62829438.746
# PP start_backend: 1 start_idx: 17 end_backend: 5 end_idx: 17 len: 1, start_time: 62829583.769, end_time: 62829584.822
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 223 len: 18, start_time: 62829609.835, end_time: 62832587.041
# PP start_backend: 1 start_idx: 18 end_backend: 5 end_idx: 18 len: 1, start_time: 62832603.935, end_time: 62833962.62
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3, start_time: 62833966.642, end_time: 62834009.062
# PP start_backend: 1 start_idx: 19 end_backend: 6 end_idx: 19 len: 1, start_time: 62834054.971, end_time: 62834055.622
# DP start_backend: 5 start_idx: 224 end_backend: 5 end_idx: 257 len: 34, start_time: 62836031.18, end_time: 62840594.745
# PP start_backend: 1 start_idx: 20 end_backend: 1 end_idx: 21 len: 2, start_time: 62840740.943, end_time: 62840749.123
# DP start_backend: 5 start_idx: 258 end_backend: 5 end_idx: 274 len: 17, start_time: 62841299.608, end_time: 62843901.14
# PP start_backend: 1 start_idx: 22 end_backend: 5 end_idx: 22 len: 1, start_time: 62844049.586, end_time: 62844050.694
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 292 len: 18, start_time: 62844073.484, end_time: 62847110.219
# PP start_backend: 1 start_idx: 23 end_backend: 5 end_idx: 23 len: 1, start_time: 62847131.958, end_time: 62848420.925
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3, start_time: 62848424.94, end_time: 62848438.347
# PP start_backend: 1 start_idx: 24 end_backend: 6 end_idx: 24 len: 1, start_time: 62848484.367, end_time: 62848484.544
# DP start_backend: 5 start_idx: 293 end_backend: 5 end_idx: 326 len: 34, start_time: 62850549.279, end_time: 62855031.555
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 26 len: 2, start_time: 62855180.706, end_time: 62855184.829
# DP start_backend: 5 start_idx: 327 end_backend: 5 end_idx: 343 len: 17, start_time: 62855734.899, end_time: 62858362.681
# PP start_backend: 1 start_idx: 27 end_backend: 5 end_idx: 27 len: 1, start_time: 62858512.75, end_time: 62858513.855
# DP start_backend: 5 start_idx: 344 end_backend: 5 end_idx: 361 len: 18, start_time: 62858538.786, end_time: 62861554.429
# PP start_backend: 1 start_idx: 28 end_backend: 5 end_idx: 28 len: 1, start_time: 62861569.825, end_time: 62862847.784
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3, start_time: 62862851.884, end_time: 62862896.325
# PP start_backend: 1 start_idx: 29 end_backend: 6 end_idx: 29 len: 1, start_time: 62862945.682, end_time: 62862946.25
# DP start_backend: 5 start_idx: 362 end_backend: 5 end_idx: 395 len: 34, start_time: 62865001.176, end_time: 62869570.725
# PP start_backend: 1 start_idx: 30 end_backend: 1 end_idx: 31 len: 2, start_time: 62869717.313, end_time: 62869719.55
# DP start_backend: 5 start_idx: 396 end_backend: 5 end_idx: 412 len: 17, start_time: 62870269.429, end_time: 62872852.145
# PP start_backend: 1 start_idx: 32 end_backend: 5 end_idx: 32 len: 1, start_time: 62873000.417, end_time: 62873002.033
# DP start_backend: 5 start_idx: 413 end_backend: 5 end_idx: 430 len: 18, start_time: 62873025.371, end_time: 62876048.07
# PP start_backend: 1 start_idx: 33 end_backend: 5 end_idx: 33 len: 1, start_time: 62876080.596, end_time: 62877222.797
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3, start_time: 62877226.965, end_time: 62877312.832
# PP start_backend: 1 start_idx: 34 end_backend: 6 end_idx: 34 len: 1, start_time: 62877365.384, end_time: 62877365.817
# DP start_backend: 5 start_idx: 431 end_backend: 5 end_idx: 464 len: 34, start_time: 62879375.867, end_time: 62883902.864
# PP start_backend: 1 start_idx: 35 end_backend: 1 end_idx: 36 len: 2, start_time: 62884052.295, end_time: 62884055.492
# DP start_backend: 5 start_idx: 465 end_backend: 5 end_idx: 481 len: 17, start_time: 62884603.844, end_time: 62887216.599
# PP start_backend: 1 start_idx: 37 end_backend: 5 end_idx: 37 len: 1, start_time: 62887366.57, end_time: 62887367.555
# DP start_backend: 5 start_idx: 482 end_backend: 5 end_idx: 499 len: 18, start_time: 62887392.61, end_time: 62890407.202
# PP start_backend: 1 start_idx: 38 end_backend: 5 end_idx: 38 len: 1, start_time: 62890450.317, end_time: 62891592.66
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3, start_time: 62891596.7, end_time: 62891605.024
# PP start_backend: 1 start_idx: 39 end_backend: 6 end_idx: 39 len: 1, start_time: 62891658.17, end_time: 62891658.767
# DP start_backend: 5 start_idx: 500 end_backend: 5 end_idx: 533 len: 34, start_time: 62893592.783, end_time: 62898165.278
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 41 len: 2, start_time: 62898311.234, end_time: 62898339.432
# DP start_backend: 5 start_idx: 534 end_backend: 5 end_idx: 550 len: 17, start_time: 62898888.77, end_time: 62901526.735
# PP start_backend: 1 start_idx: 42 end_backend: 5 end_idx: 42 len: 1, start_time: 62901677.949, end_time: 62901679.307
# DP start_backend: 5 start_idx: 551 end_backend: 5 end_idx: 568 len: 18, start_time: 62901702.264, end_time: 62904743.196
# PP start_backend: 1 start_idx: 43 end_backend: 5 end_idx: 43 len: 1, start_time: 62904771.161, end_time: 62905948.727
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3, start_time: 62905952.776, end_time: 62905964.977
# PP start_backend: 1 start_idx: 44 end_backend: 6 end_idx: 44 len: 1, start_time: 62906021.025, end_time: 62906021.208
# DP start_backend: 5 start_idx: 569 end_backend: 5 end_idx: 602 len: 34, start_time: 62908027.516, end_time: 62912595.791
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 46 len: 2, start_time: 62912747.188, end_time: 62912749.517
# DP start_backend: 5 start_idx: 603 end_backend: 5 end_idx: 619 len: 17, start_time: 62913297.796, end_time: 62915965.395
# PP start_backend: 1 start_idx: 47 end_backend: 5 end_idx: 47 len: 1, start_time: 62916116.553, end_time: 62916118.195
# DP start_backend: 5 start_idx: 620 end_backend: 5 end_idx: 637 len: 18, start_time: 62916141.32, end_time: 62919177.547
# PP start_backend: 1 start_idx: 48 end_backend: 5 end_idx: 48 len: 1, start_time: 62919221.49, end_time: 62920677.685
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3, start_time: 62920681.651, end_time: 62920696.576
# PP start_backend: 1 start_idx: 49 end_backend: 6 end_idx: 49 len: 1, start_time: 62920741.197, end_time: 62920741.762
# DP start_backend: 5 start_idx: 638 end_backend: 5 end_idx: 671 len: 34, start_time: 62922767.192, end_time: 62927404.18
# PP start_backend: 1 start_idx: 50 end_backend: 1 end_idx: 51 len: 2, start_time: 62927550.805, end_time: 62927553.092
# DP start_backend: 5 start_idx: 672 end_backend: 5 end_idx: 688 len: 17, start_time: 62928099.004, end_time: 62930748.357
# PP start_backend: 1 start_idx: 52 end_backend: 5 end_idx: 52 len: 1, start_time: 62930897.133, end_time: 62930897.44
# DP start_backend: 5 start_idx: 689 end_backend: 5 end_idx: 706 len: 18, start_time: 62930921.268, end_time: 62933989.473
# PP start_backend: 1 start_idx: 53 end_backend: 5 end_idx: 53 len: 1, start_time: 62933992.559, end_time: 62935387.748
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3, start_time: 62935391.726, end_time: 62935424.498
# Backend: 1, Idx: 0, Min Gap: 207.846 ms
# Backend: 1, Idx: 4, Min Gap: 65.327 ms
# Backend: 1, Idx: 5, Min Gap: 34.523 ms
# Backend: 1, Idx: 7, Min Gap: 225.647 ms
# Backend: 1, Idx: 8, Min Gap: 383.629 ms
# Backend: 1, Idx: 9, Min Gap: 26.608 ms
# Backend: 1, Idx: 10, Min Gap: 27.289 ms
# Backend: 1, Idx: 12, Min Gap: 29.956 ms
# Backend: 1, Idx: 13, Min Gap: 3.983 ms
# Backend: 1, Idx: 14, Min Gap: 21.997 ms
# Backend: 1, Idx: 15, Min Gap: 29.506 ms
# Backend: 1, Idx: 17, Min Gap: 25.013 ms
# Backend: 1, Idx: 18, Min Gap: 4.022 ms
# Backend: 1, Idx: 19, Min Gap: 24.163 ms
# Backend: 1, Idx: 20, Min Gap: 34.338 ms
# Backend: 1, Idx: 22, Min Gap: 22.790 ms
# Backend: 1, Idx: 23, Min Gap: 4.015 ms
# Backend: 1, Idx: 24, Min Gap: 19.207 ms
# Backend: 1, Idx: 25, Min Gap: 33.315 ms
# Backend: 1, Idx: 27, Min Gap: 24.931 ms
# Backend: 1, Idx: 28, Min Gap: 4.100 ms
# Backend: 1, Idx: 29, Min Gap: 19.172 ms
# Backend: 1, Idx: 30, Min Gap: 35.271 ms
# Backend: 1, Idx: 32, Min Gap: 23.338 ms
# Backend: 1, Idx: 33, Min Gap: 4.168 ms
# Backend: 1, Idx: 34, Min Gap: 21.596 ms
# Backend: 1, Idx: 35, Min Gap: 32.654 ms
# Backend: 1, Idx: 37, Min Gap: 25.055 ms
# Backend: 1, Idx: 38, Min Gap: 4.040 ms
# Backend: 1, Idx: 39, Min Gap: 21.213 ms
# Backend: 1, Idx: 40, Min Gap: 38.062 ms
# Backend: 1, Idx: 42, Min Gap: 22.957 ms
# Backend: 1, Idx: 43, Min Gap: 4.049 ms
# Backend: 1, Idx: 44, Min Gap: 21.726 ms
# Backend: 1, Idx: 45, Min Gap: 42.589 ms
# Backend: 1, Idx: 47, Min Gap: 23.125 ms
# Backend: 1, Idx: 48, Min Gap: 3.966 ms
# Backend: 1, Idx: 49, Min Gap: 21.669 ms
# Backend: 1, Idx: 50, Min Gap: 35.779 ms
# Backend: 1, Idx: 52, Min Gap: 23.828 ms
# Backend: 1, Idx: 53, Min Gap: 3.978 ms
# Average time gap: 40.986 ms
# Standard deviation: 69.600 ms
# Minimum time gap: 3.966 ms
# Maximum time gap: 383.629 ms
