# %%
import re
import argparse

# backend 0 default, backend 1 pp, backend 2, 5, 6 DP, backend 3 TP

def custom_print(message, file_path=None, mode='a'):
    print(message)  # Print to terminal
    if file_path:
        with open(file_path, mode) as file:
            file.write(message + '\n')

def backend_to_comm_type(backend, rank_tid=None):
    if backend == 0:
        return "Default"
    elif backend == 1:
        return "PP"
    elif backend in [2, 5, 6]:
        return "DP"
    elif backend == 3:
        return "TP"
    else:
        return "unknown"
    
def is_same_comm_type(backend1, backend2):
    return backend_to_comm_type(backend1) == backend_to_comm_type(backend2)


def parse_communication_pattern(log_file, rank_tid):
    pattern = re.compile(r"Backend (\d+) RANK (\d+) tid: (\d+) .*?Idx: (\d+),")
    communication_pattern = []

    with open(log_file, 'r') as file:
        start_backend = None
        idx_list = None

        end_backend = None

        for line in file:
            match = pattern.search(line)
            if match:
                backend = int(match.group(1))
                tid = int(match.group(3))
                idx = int(match.group(4))

                # remove TP traffic and backend 0 traffic
                if backend_to_comm_type(backend) == "TP" or backend == 0:
                    continue

                if tid == rank_tid:
                    if not is_same_comm_type(backend, start_backend):
                        # transition to a new backend
                        if start_backend is not None:
                            communication_pattern.append((start_backend, idx_list, end_backend))
                        start_backend = backend
                        idx_list = [idx]
                        end_backend = backend
                    else:
                        idx_list.append(idx)
                        end_backend = backend

        # Append the last backend, rank, and idx
        if start_backend is not None:
            communication_pattern.append((start_backend, idx_list, end_backend))

    return communication_pattern

def get_rank_tid(log_file, node_id, num_local_ranks):
    global_rank_base = node_id * num_local_ranks

    pattern = re.compile(r"Backend 0 RANK (\d+) tid: (\d+)")
    rank_tid_map = {}


    with open(log_file, 'r') as file:
        for line in file:
            match = pattern.search(line)
            if match:
                global_rank = int(match.group(1))
                tid = int(match.group(2))
                if global_rank not in rank_tid_map:
                    rank_tid_map[global_rank] = tid

    tid_list = []

    for rank in range(global_rank_base, global_rank_base + num_local_ranks):
        if rank in rank_tid_map:
            tid_list.append(rank_tid_map[rank])
        else:
            raise ValueError(f"Rank {rank} not found in log file {log_file}")

    return tid_list

node_list = ["nid001224", "nid001225", "nid001228", "nid001229"]
num_local_ranks = 4

for i, node in enumerate(node_list):
    log_file = f"<path-to-opus>/Opus/torchtitan/opus-test/dp-2-pp-2-tp-4-pm-8b-provision/output-opus-no-controller-b24/torchrun_{node}.ans"
    rank_tid_list = get_rank_tid(log_file, i, num_local_ranks)
    print(rank_tid_list)

    for rank, tid in enumerate(rank_tid_list):
        # rank is local rank

        output_file = f"comm_pattern_b24/comm_pattern_{i}_rank{rank}.txt"
        # Clean the output file before writing
        with open(output_file, 'w') as file:
            file.truncate(0)
        custom_print(f"Node: {node}, Rank: {rank}, Tid: {tid}", output_file)
        pattern = parse_communication_pattern(log_file, tid)

        for backend, idx_list, end_backend in pattern:
            custom_print(f"{backend_to_comm_type(backend)} start_backend: {backend} start_idx: {idx_list[0]} end_backend: {end_backend} end_idx: {idx_list[-1]} len: {len(idx_list)}", output_file)
# Out:
# [139704668067648, 139958066890560, 140361820665664, 139745134581568]
# Node: nid001224, Rank: 0, Tid: 139704668067648
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001224, Rank: 1, Tid: 139958066890560
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001224, Rank: 2, Tid: 140361820665664
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001224, Rank: 3, Tid: 139745134581568
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# [140198168495936, 139898743408448, 140304530048832, 140181044434752]
# Node: nid001225, Rank: 0, Tid: 140198168495936
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001225, Rank: 1, Tid: 139898743408448
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001225, Rank: 2, Tid: 140304530048832
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001225, Rank: 3, Tid: 140181044434752
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# [140068979435328, 140402071889728, 140024314672960, 140148102453056]
# Node: nid001228, Rank: 0, Tid: 140068979435328
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 119 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 205 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 291 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 377 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 463 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 549 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 635 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 705 end_backend: 5 end_idx: 721 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 791 end_backend: 5 end_idx: 807 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001228, Rank: 1, Tid: 140402071889728
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 119 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 205 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 291 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 377 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 463 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 549 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 635 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 705 end_backend: 5 end_idx: 721 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 791 end_backend: 5 end_idx: 807 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001228, Rank: 2, Tid: 140024314672960
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 119 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 205 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 291 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 377 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 463 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 549 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 635 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# ...
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 291 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 377 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 463 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 549 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 635 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 705 end_backend: 5 end_idx: 721 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 791 end_backend: 5 end_idx: 807 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001229, Rank: 1, Tid: 140491543930688
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 119 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 205 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 291 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 377 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 463 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 549 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 635 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 705 end_backend: 5 end_idx: 721 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 791 end_backend: 5 end_idx: 807 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001229, Rank: 2, Tid: 140613199902528
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 119 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 205 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 291 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 377 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 463 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 549 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 635 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 705 end_backend: 5 end_idx: 721 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 791 end_backend: 5 end_idx: 807 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3
# Node: nid001229, Rank: 3, Tid: 140544051046208
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17
# PP start_backend: 1 start_idx: 4 end_backend: 1 end_idx: 4 len: 1
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 9 len: 5
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18
# PP start_backend: 1 start_idx: 10 end_backend: 1 end_idx: 10 len: 1
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3
# PP start_backend: 1 start_idx: 11 end_backend: 1 end_idx: 11 len: 1
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 119 len: 17
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 16 len: 5
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18
# PP start_backend: 1 start_idx: 17 end_backend: 1 end_idx: 17 len: 1
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3
# PP start_backend: 1 start_idx: 18 end_backend: 1 end_idx: 18 len: 1
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 205 len: 17
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 23 len: 5
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18
# PP start_backend: 1 start_idx: 24 end_backend: 1 end_idx: 24 len: 1
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3
# PP start_backend: 1 start_idx: 25 end_backend: 1 end_idx: 25 len: 1
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 291 len: 17
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 30 len: 5
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18
# PP start_backend: 1 start_idx: 31 end_backend: 1 end_idx: 31 len: 1
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3
# PP start_backend: 1 start_idx: 32 end_backend: 1 end_idx: 32 len: 1
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 377 len: 17
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 37 len: 5
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18
# PP start_backend: 1 start_idx: 38 end_backend: 1 end_idx: 38 len: 1
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3
# PP start_backend: 1 start_idx: 39 end_backend: 1 end_idx: 39 len: 1
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 463 len: 17
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 44 len: 5
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18
# PP start_backend: 1 start_idx: 45 end_backend: 1 end_idx: 45 len: 1
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3
# PP start_backend: 1 start_idx: 46 end_backend: 1 end_idx: 46 len: 1
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 549 len: 17
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 51 len: 5
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18
# PP start_backend: 1 start_idx: 52 end_backend: 1 end_idx: 52 len: 1
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3
# PP start_backend: 1 start_idx: 53 end_backend: 1 end_idx: 53 len: 1
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 635 len: 17
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 58 len: 5
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18
# PP start_backend: 1 start_idx: 59 end_backend: 1 end_idx: 59 len: 1
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3
# PP start_backend: 1 start_idx: 60 end_backend: 1 end_idx: 60 len: 1
# DP start_backend: 5 start_idx: 705 end_backend: 5 end_idx: 721 len: 17
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 65 len: 5
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18
# PP start_backend: 1 start_idx: 66 end_backend: 1 end_idx: 66 len: 1
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3
# PP start_backend: 1 start_idx: 67 end_backend: 1 end_idx: 67 len: 1
# DP start_backend: 5 start_idx: 791 end_backend: 5 end_idx: 807 len: 17
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 72 len: 5
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18
# PP start_backend: 1 start_idx: 73 end_backend: 1 end_idx: 73 len: 1
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3

# %%
import re
import argparse
import datetime
import numpy as np

# backend 0 default, backend 1 pp, backend 2, 5, 6 DP, backend 3 TP

def custom_print(message, file_path=None, mode='a'):
    print(message)  # Print to terminal
    if file_path:
        with open(file_path, mode) as file:
            file.write(message + '\n')

def backend_to_comm_type(backend, rank_tid=None):
    if backend == 0:
        return "Default"
    elif backend == 1:
        return "PP"
    elif backend in [2, 5, 6]:
        return "DP"
    elif backend == 3:
        return "TP"
    else:
        return "unknown"
    
def is_same_comm_type(backend1, backend2):
    return backend_to_comm_type(backend1) == backend_to_comm_type(backend2)

def time_to_ms(t):
    return (
        t.hour * 3600_000 +
        t.minute * 60_000 +
        t.second * 1000 +
        t.microsecond / 1000.0
    )

def parse_communication_pattern(log_file, rank_tid):
    main_pat = re.compile(
        r"Backend (\d+) RANK (\d+) tid: (\d+) .*?Idx: (\d+),"
    )
    time_pat = re.compile(
        r"t:\[(\d+:\d+:\d+\.\d+)\]"
    )

    communication_pattern = []

    start_backend = None
    end_backend = None

    idx_list = None

    start_time = None
    end_time = None

    # Track per-idx timestamps
    idx_start_times = {}
    idx_end_times = {}

    time_gap = {}

    with open(log_file, 'r') as file:
        for line in file:
            match = main_pat.search(line)
            if not match:
                continue

            backend = int(match.group(1))
            tid = int(match.group(3))
            idx = int(match.group(4))

            # filter
            if backend_to_comm_type(backend) == "TP" or backend == 0:
                continue
            if tid != rank_tid:
                continue

            # extract timestamp if present
            tmatch = time_pat.search(line)
            ts = None
            if tmatch:
                ts = datetime.datetime.strptime(tmatch.group(1), "%H:%M:%S.%f")
                ts = time_to_ms(ts)

            # record pre/post timestamps
            if "pre_coll" in line and ts:
                idx_start_times[(backend, idx)] = ts
            elif "post_coll" in line and ts:
                idx_end_times[(backend, idx)] = ts

            # comm-type transition
            if "pre_coll" in line:
                if not is_same_comm_type(backend, start_backend):
                    if start_backend is not None:
                        communication_pattern.append(
                            (start_backend, idx_list, end_backend, start_time, end_time)
                        )
                    
                    start_time = ts
                    if end_time:
                        time_gap[(start_backend, idx_list[0])] = start_time - end_time
                    start_backend = backend
                    idx_list = [idx]
                else:
                    end_backend = backend
                    idx_list.append(idx)

            if "post_coll" in line:
                end_time = ts

        # flush last segment
        if start_backend is not None:
            communication_pattern.append(
                (start_backend, idx_list, end_backend, start_time, end_time)
            )

    return communication_pattern, time_gap

# log_file = f"<path-to-opus>/Opus/torchtitan/opus-test/dp-2-pp-2-tp-4-pm-8b-provision/output-opus-v3-l_0-b24-provision/torchrun_nid001012.ans"

output_file = "comm_pattern_v3_b24_pp_0.txt"
with open(output_file, 'w') as file:
    file.truncate(0)
log_file = f"<path-to-opus>/Opus/torchtitan/opus-test/dp-2-pp-2-tp-4-pm-8b-provision/output-opus-v3-l_0-b24-provision/torchrun_nid001012.ans"

pattern, time_gap_map_pp0 = parse_communication_pattern(log_file, 139783679366720)

for backend, idx_list, end_backend, start_time, end_time in pattern:
    custom_print(f"{backend_to_comm_type(backend)} start_backend: {backend} start_idx: {idx_list[0]} end_backend: {end_backend} end_idx: {idx_list[-1]} len: {len(idx_list)}, start_time: {start_time}, end_time: {end_time}", output_file)

# if time_gap_list:
#     avg_gap = np.mean(time_gap_list)
#     std_gap = np.std(time_gap_list)
#     min_gap = np.min(time_gap_list)
#     max_gap = np.max(time_gap_list)

#     custom_print(f"Average time gap: {avg_gap:.3f} ms", output_file)
#     custom_print(f"Standard deviation: {std_gap:.3f} ms", output_file)
#     custom_print(f"Minimum time gap: {min_gap:.3f} ms", output_file)
#     custom_print(f"Maximum time gap: {max_gap:.3f} ms", output_file)
# else:
#     custom_print("No time gaps to calculate statistics.")


output_file = "comm_pattern_v3_b24_pp_1.txt"
with open(output_file, 'w') as file:
    file.truncate(0)
log_file = f"<path-to-opus>/Opus/torchtitan/opus-test/dp-2-pp-2-tp-4-pm-8b-provision/output-opus-v3-l_0-b24-provision/torchrun_nid001016.ans"

pattern, time_gap_map_pp1 = parse_communication_pattern(log_file, 140552075859520)

for backend, idx_list, end_backend, start_time, end_time in pattern:
    custom_print(f"{backend_to_comm_type(backend)} start_backend: {backend} start_idx: {idx_list[0]} end_backend: {end_backend} end_idx: {idx_list[-1]} len: {len(idx_list)}, start_time: {start_time}, end_time: {end_time}", output_file)

common_gap = []
for (key1, gap1)in time_gap_map_pp0.items():
    for (key2, gap2) in time_gap_map_pp1.items():
        if key1 == key2 and key1[0] == 1:  # Check if backend and idx are the same
            min_gap = min(gap1, gap2)
            custom_print(f"Backend: {key1[0]}, Idx: {key1[1]}, Min Gap: {min_gap:.3f} ms", output_file)
            common_gap.append(min_gap)

if common_gap:
    avg_gap = np.mean(common_gap)
    std_gap = np.std(common_gap)
    min_gap = np.min(common_gap)
    max_gap = np.max(common_gap)

    custom_print(f"Average time gap: {avg_gap:.3f} ms", output_file)
    custom_print(f"Standard deviation: {std_gap:.3f} ms", output_file)
    custom_print(f"Minimum time gap: {min_gap:.3f} ms", output_file)
    custom_print(f"Maximum time gap: {max_gap:.3f} ms", output_file)
# Out:
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 1 len: 2, start_time: 60997633.798, end_time: 60997636.121
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17, start_time: 60997716.462, end_time: 60999634.318
# PP start_backend: 1 start_idx: 2 end_backend: 1 end_idx: 3 len: 2, start_time: 61009866.501, end_time: 61009874.613
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 33 len: 17, start_time: 61009878.296, end_time: 61011159.342
# PP start_backend: 1 start_idx: 4 end_backend: 5 end_idx: 4 len: 1, start_time: 61011892.649, end_time: 61011893.385
# DP start_backend: 5 start_idx: 34 end_backend: 5 end_idx: 50 len: 17, start_time: 61011924.061, end_time: 61013212.865
# PP start_backend: 1 start_idx: 5 end_backend: 5 end_idx: 5 len: 1, start_time: 61013264.159, end_time: 61013212.865
# DP start_backend: 5 start_idx: 51 end_backend: 5 end_idx: 51 len: 1, start_time: 61013265.913, end_time: 61013266.979
# PP start_backend: 1 start_idx: 6 end_backend: 5 end_idx: 6 len: 1, start_time: 61013268.185, end_time: 61013314.106
# DP start_backend: 5 start_idx: 52 end_backend: 5 end_idx: 67 len: 16, start_time: 61015905.998, end_time: 61017954.96
# PP start_backend: 1 start_idx: 7 end_backend: 5 end_idx: 7 len: 1, start_time: 61018595.568, end_time: 61017954.96
# DP start_backend: 5 start_idx: 68 end_backend: 5 end_idx: 68 len: 1, start_time: 61018596.547, end_time: 61018597.712
# PP start_backend: 1 start_idx: 8 end_backend: 5 end_idx: 8 len: 1, start_time: 61018598.65, end_time: 61018645.156
# DP start_backend: 5 start_idx: 69 end_backend: 5 end_idx: 84 len: 16, start_time: 61018709.138, end_time: 61020686.167
# PP start_backend: 1 start_idx: 9 end_backend: 5 end_idx: 9 len: 1, start_time: 61020773.835, end_time: 61020776.975
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18, start_time: 61022739.05, end_time: 61024600.759
# PP start_backend: 1 start_idx: 10 end_backend: 5 end_idx: 10 len: 1, start_time: 61024666.066, end_time: 61024729.313
# DP start_backend: 6 start_idx: 0 end_backend: 5 end_idx: 119 len: 20, start_time: 61024930.16, end_time: 61026364.52
# PP start_backend: 1 start_idx: 11 end_backend: 5 end_idx: 11 len: 1, start_time: 61026396.218, end_time: 61026398.038
# DP start_backend: 5 start_idx: 120 end_backend: 5 end_idx: 136 len: 17, start_time: 61026462.822, end_time: 61027762.427
# PP start_backend: 1 start_idx: 12 end_backend: 5 end_idx: 12 len: 1, start_time: 61027867.47, end_time: 61027762.427
# DP start_backend: 5 start_idx: 137 end_backend: 5 end_idx: 137 len: 1, start_time: 61027867.903, end_time: 61027868.823
# PP start_backend: 1 start_idx: 13 end_backend: 5 end_idx: 13 len: 1, start_time: 61027869.548, end_time: 61027920.115
# DP start_backend: 5 start_idx: 138 end_backend: 5 end_idx: 153 len: 16, start_time: 61030149.606, end_time: 61032148.681
# PP start_backend: 1 start_idx: 14 end_backend: 5 end_idx: 14 len: 1, start_time: 61032692.741, end_time: 61032148.681
# DP start_backend: 5 start_idx: 154 end_backend: 5 end_idx: 154 len: 1, start_time: 61032694.587, end_time: 61032696.165
# PP start_backend: 1 start_idx: 15 end_backend: 5 end_idx: 15 len: 1, start_time: 61032697.01, end_time: 61032745.481
# DP start_backend: 5 start_idx: 155 end_backend: 5 end_idx: 170 len: 16, start_time: 61033052.936, end_time: 61035048.049
# PP start_backend: 1 start_idx: 16 end_backend: 5 end_idx: 16 len: 1, start_time: 61035133.994, end_time: 61035135.392
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18, start_time: 61037087.742, end_time: 61038871.79
# PP start_backend: 1 start_idx: 17 end_backend: 5 end_idx: 17 len: 1, start_time: 61038875.023, end_time: 61038877.503
# DP start_backend: 6 start_idx: 3 end_backend: 5 end_idx: 205 len: 20, start_time: 61038895.51, end_time: 61040247.882
# PP start_backend: 1 start_idx: 18 end_backend: 5 end_idx: 18 len: 1, start_time: 61040280.821, end_time: 61040282.488
# DP start_backend: 5 start_idx: 206 end_backend: 5 end_idx: 222 len: 17, start_time: 61040337.703, end_time: 61041642.463
# PP start_backend: 1 start_idx: 19 end_backend: 5 end_idx: 19 len: 1, start_time: 61041679.118, end_time: 61041642.463
# DP start_backend: 5 start_idx: 223 end_backend: 5 end_idx: 223 len: 1, start_time: 61041679.573, end_time: 61041680.774
# PP start_backend: 1 start_idx: 20 end_backend: 5 end_idx: 20 len: 1, start_time: 61041681.611, end_time: 61041729.087
# DP start_backend: 5 start_idx: 224 end_backend: 5 end_idx: 239 len: 16, start_time: 61043950.924, end_time: 61045931.536
# PP start_backend: 1 start_idx: 21 end_backend: 5 end_idx: 21 len: 1, start_time: 61046473.37, end_time: 61045931.536
# DP start_backend: 5 start_idx: 240 end_backend: 5 end_idx: 240 len: 1, start_time: 61046475.104, end_time: 61046476.294
# PP start_backend: 1 start_idx: 22 end_backend: 5 end_idx: 22 len: 1, start_time: 61046477.139, end_time: 61046529.817
# DP start_backend: 5 start_idx: 241 end_backend: 5 end_idx: 256 len: 16, start_time: 61046861.035, end_time: 61048861.49
# PP start_backend: 1 start_idx: 23 end_backend: 5 end_idx: 23 len: 1, start_time: 61048947.078, end_time: 61048949.195
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18, start_time: 61050910.645, end_time: 61052692.338
# PP start_backend: 1 start_idx: 24 end_backend: 5 end_idx: 24 len: 1, start_time: 61052694.387, end_time: 61052695.852
# DP start_backend: 6 start_idx: 6 end_backend: 5 end_idx: 291 len: 20, start_time: 61052713.072, end_time: 61054069.437
# PP start_backend: 1 start_idx: 25 end_backend: 5 end_idx: 25 len: 1, start_time: 61054100.408, end_time: 61054101.292
# DP start_backend: 5 start_idx: 292 end_backend: 5 end_idx: 308 len: 17, start_time: 61054151.742, end_time: 61055449.73
# PP start_backend: 1 start_idx: 26 end_backend: 5 end_idx: 26 len: 1, start_time: 61055510.604, end_time: 61055449.73
# DP start_backend: 5 start_idx: 309 end_backend: 5 end_idx: 309 len: 1, start_time: 61055511.289, end_time: 61055512.262
# PP start_backend: 1 start_idx: 27 end_backend: 5 end_idx: 27 len: 1, start_time: 61055512.915, end_time: 61055563.64
# DP start_backend: 5 start_idx: 310 end_backend: 5 end_idx: 325 len: 16, start_time: 61057803.352, end_time: 61059793.797
# PP start_backend: 1 start_idx: 28 end_backend: 5 end_idx: 28 len: 1, start_time: 61060340.064, end_time: 61059793.797
# DP start_backend: 5 start_idx: 326 end_backend: 5 end_idx: 326 len: 1, start_time: 61060341.406, end_time: 61060342.675
# PP start_backend: 1 start_idx: 29 end_backend: 5 end_idx: 29 len: 1, start_time: 61060343.602, end_time: 61060393.929
# DP start_backend: 5 start_idx: 327 end_backend: 5 end_idx: 342 len: 16, start_time: 61060699.043, end_time: 61062713.624
# PP start_backend: 1 start_idx: 30 end_backend: 5 end_idx: 30 len: 1, start_time: 61062799.637, end_time: 61062800.253
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18, start_time: 61064823.857, end_time: 61066593.416
# PP start_backend: 1 start_idx: 31 end_backend: 5 end_idx: 31 len: 1, start_time: 61066595.909, end_time: 61066597.167
# DP start_backend: 6 start_idx: 9 end_backend: 5 end_idx: 377 len: 20, start_time: 61066613.729, end_time: 61067979.65
# PP start_backend: 1 start_idx: 32 end_backend: 5 end_idx: 32 len: 1, start_time: 61068014.455, end_time: 61068015.802
# DP start_backend: 5 start_idx: 378 end_backend: 5 end_idx: 394 len: 17, start_time: 61068103.871, end_time: 61069406.139
# PP start_backend: 1 start_idx: 33 end_backend: 5 end_idx: 33 len: 1, start_time: 61069480.031, end_time: 61069406.139
# DP start_backend: 5 start_idx: 395 end_backend: 5 end_idx: 395 len: 1, start_time: 61069481.921, end_time: 61069483.251
# PP start_backend: 1 start_idx: 34 end_backend: 5 end_idx: 34 len: 1, start_time: 61069484.056, end_time: 61069533.878
# DP start_backend: 5 start_idx: 396 end_backend: 5 end_idx: 411 len: 16, start_time: 61071762.663, end_time: 61073751.34
# PP start_backend: 1 start_idx: 35 end_backend: 5 end_idx: 35 len: 1, start_time: 61074300.664, end_time: 61073751.34
# DP start_backend: 5 start_idx: 412 end_backend: 5 end_idx: 412 len: 1, start_time: 61074301.819, end_time: 61074303.374
# PP start_backend: 1 start_idx: 36 end_backend: 5 end_idx: 36 len: 1, start_time: 61074304.461, end_time: 61074354.106
# DP start_backend: 5 start_idx: 413 end_backend: 5 end_idx: 428 len: 16, start_time: 61074656.726, end_time: 61076653.51
# PP start_backend: 1 start_idx: 37 end_backend: 5 end_idx: 37 len: 1, start_time: 61076739.796, end_time: 61076743.021
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18, start_time: 61078688.836, end_time: 61080465.88
# PP start_backend: 1 start_idx: 38 end_backend: 5 end_idx: 38 len: 1, start_time: 61080468.046, end_time: 61080469.963
# DP start_backend: 6 start_idx: 12 end_backend: 5 end_idx: 463 len: 20, start_time: 61080486.47, end_time: 61081868.961
# PP start_backend: 1 start_idx: 39 end_backend: 5 end_idx: 39 len: 1, start_time: 61081899.267, end_time: 61081899.87
# DP start_backend: 5 start_idx: 464 end_backend: 5 end_idx: 480 len: 17, start_time: 61081975.707, end_time: 61083256.68
# PP start_backend: 1 start_idx: 40 end_backend: 5 end_idx: 40 len: 1, start_time: 61083322.958, end_time: 61083256.68
# DP start_backend: 5 start_idx: 481 end_backend: 5 end_idx: 481 len: 1, start_time: 61083324.031, end_time: 61083325.305
# PP start_backend: 1 start_idx: 41 end_backend: 5 end_idx: 41 len: 1, start_time: 61083326.088, end_time: 61083377.759
# DP start_backend: 5 start_idx: 482 end_backend: 5 end_idx: 497 len: 16, start_time: 61085615.8, end_time: 61087598.787
# PP start_backend: 1 start_idx: 42 end_backend: 5 end_idx: 42 len: 1, start_time: 61088141.861, end_time: 61087598.787
# DP start_backend: 5 start_idx: 498 end_backend: 5 end_idx: 498 len: 1, start_time: 61088142.35, end_time: 61088143.926
# PP start_backend: 1 start_idx: 43 end_backend: 5 end_idx: 43 len: 1, start_time: 61088145.0, end_time: 61088195.123
# DP start_backend: 5 start_idx: 499 end_backend: 5 end_idx: 514 len: 16, start_time: 61088684.35, end_time: 61090701.234
# PP start_backend: 1 start_idx: 44 end_backend: 5 end_idx: 44 len: 1, start_time: 61090789.699, end_time: 61090790.313
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18, start_time: 61092733.595, end_time: 61094470.11
# PP start_backend: 1 start_idx: 45 end_backend: 5 end_idx: 45 len: 1, start_time: 61094474.978, end_time: 61094476.215
# DP start_backend: 6 start_idx: 15 end_backend: 5 end_idx: 549 len: 20, start_time: 61094496.968, end_time: 61095830.861
# PP start_backend: 1 start_idx: 46 end_backend: 5 end_idx: 46 len: 1, start_time: 61095866.412, end_time: 61095867.163
# DP start_backend: 5 start_idx: 550 end_backend: 5 end_idx: 566 len: 17, start_time: 61095912.359, end_time: 61097185.606
# PP start_backend: 1 start_idx: 47 end_backend: 5 end_idx: 47 len: 1, start_time: 61097301.615, end_time: 61097185.606
# DP start_backend: 5 start_idx: 567 end_backend: 5 end_idx: 567 len: 1, start_time: 61097302.315, end_time: 61097304.398
# PP start_backend: 1 start_idx: 48 end_backend: 5 end_idx: 48 len: 1, start_time: 61097305.66, end_time: 61097356.256
# DP start_backend: 5 start_idx: 568 end_backend: 5 end_idx: 583 len: 16, start_time: 61099656.142, end_time: 61101613.009
# PP start_backend: 1 start_idx: 49 end_backend: 5 end_idx: 49 len: 1, start_time: 61102160.42, end_time: 61101613.009
# DP start_backend: 5 start_idx: 584 end_backend: 5 end_idx: 584 len: 1, start_time: 61102162.003, end_time: 61102163.257
# PP start_backend: 1 start_idx: 50 end_backend: 5 end_idx: 50 len: 1, start_time: 61102164.344, end_time: 61102213.289
# DP start_backend: 5 start_idx: 585 end_backend: 5 end_idx: 600 len: 16, start_time: 61102650.353, end_time: 61104621.233
# PP start_backend: 1 start_idx: 51 end_backend: 5 end_idx: 51 len: 1, start_time: 61104708.29, end_time: 61104710.353
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18, start_time: 61106747.632, end_time: 61108463.588
# PP start_backend: 1 start_idx: 52 end_backend: 5 end_idx: 52 len: 1, start_time: 61108471.398, end_time: 61108474.225
# DP start_backend: 6 start_idx: 18 end_backend: 5 end_idx: 635 len: 20, start_time: 61108492.093, end_time: 61109826.801
# PP start_backend: 1 start_idx: 53 end_backend: 5 end_idx: 53 len: 1, start_time: 61109860.696, end_time: 61109861.841
# DP start_backend: 5 start_idx: 636 end_backend: 5 end_idx: 652 len: 17, start_time: 61109901.592, end_time: 61111190.86
# PP start_backend: 1 start_idx: 54 end_backend: 5 end_idx: 54 len: 1, start_time: 61111329.446, end_time: 61111190.86
# DP start_backend: 5 start_idx: 653 end_backend: 5 end_idx: 653 len: 1, start_time: 61111331.155, end_time: 61111332.639
# PP start_backend: 1 start_idx: 55 end_backend: 5 end_idx: 55 len: 1, start_time: 61111333.582, end_time: 61111382.375
# DP start_backend: 5 start_idx: 654 end_backend: 5 end_idx: 669 len: 16, start_time: 61113703.191, end_time: 61115668.721
# PP start_backend: 1 start_idx: 56 end_backend: 5 end_idx: 56 len: 1, start_time: 61116210.708, end_time: 61115668.721
# DP start_backend: 5 start_idx: 670 end_backend: 5 end_idx: 670 len: 1, start_time: 61116211.361, end_time: 61116212.643
# PP start_backend: 1 start_idx: 57 end_backend: 5 end_idx: 57 len: 1, start_time: 61116213.849, end_time: 61116262.792
# DP start_backend: 5 start_idx: 671 end_backend: 5 end_idx: 686 len: 16, start_time: 61116723.052, end_time: 61118697.864
# PP start_backend: 1 start_idx: 58 end_backend: 5 end_idx: 58 len: 1, start_time: 61118785.972, end_time: 61118789.057
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18, start_time: 61120794.198, end_time: 61122534.0
# PP start_backend: 1 start_idx: 59 end_backend: 5 end_idx: 59 len: 1, start_time: 61122540.141, end_time: 61122541.769
# DP start_backend: 6 start_idx: 21 end_backend: 5 end_idx: 721 len: 20, start_time: 61122560.201, end_time: 61123929.212
# PP start_backend: 1 start_idx: 60 end_backend: 5 end_idx: 60 len: 1, start_time: 61123959.56, end_time: 61123959.943
# DP start_backend: 5 start_idx: 722 end_backend: 5 end_idx: 738 len: 17, start_time: 61123997.605, end_time: 61125329.984
# PP start_backend: 1 start_idx: 61 end_backend: 5 end_idx: 61 len: 1, start_time: 61125424.098, end_time: 61125329.984
# DP start_backend: 5 start_idx: 739 end_backend: 5 end_idx: 739 len: 1, start_time: 61125424.566, end_time: 61125426.052
# PP start_backend: 1 start_idx: 62 end_backend: 5 end_idx: 62 len: 1, start_time: 61125427.144, end_time: 61125476.351
# DP start_backend: 5 start_idx: 740 end_backend: 5 end_idx: 755 len: 16, start_time: 61127773.3, end_time: 61129774.443
# PP start_backend: 1 start_idx: 63 end_backend: 5 end_idx: 63 len: 1, start_time: 61130316.116, end_time: 61129774.443
# DP start_backend: 5 start_idx: 756 end_backend: 5 end_idx: 756 len: 1, start_time: 61130317.98, end_time: 61130319.026
# PP start_backend: 1 start_idx: 64 end_backend: 5 end_idx: 64 len: 1, start_time: 61130320.373, end_time: 61130372.685
# DP start_backend: 5 start_idx: 757 end_backend: 5 end_idx: 772 len: 16, start_time: 61130754.106, end_time: 61132748.139
# PP start_backend: 1 start_idx: 65 end_backend: 5 end_idx: 65 len: 1, start_time: 61132834.377, end_time: 61132835.908
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18, start_time: 61134870.357, end_time: 61136651.938
# PP start_backend: 1 start_idx: 66 end_backend: 5 end_idx: 66 len: 1, start_time: 61136654.05, end_time: 61136655.498
# DP start_backend: 6 start_idx: 24 end_backend: 5 end_idx: 807 len: 20, start_time: 61136674.054, end_time: 61138042.346
# PP start_backend: 1 start_idx: 67 end_backend: 5 end_idx: 67 len: 1, start_time: 61138072.724, end_time: 61138073.724
# DP start_backend: 5 start_idx: 808 end_backend: 5 end_idx: 824 len: 17, start_time: 61138108.919, end_time: 61139395.94
# PP start_backend: 1 start_idx: 68 end_backend: 5 end_idx: 68 len: 1, start_time: 61139554.357, end_time: 61139395.94
# DP start_backend: 5 start_idx: 825 end_backend: 5 end_idx: 825 len: 1, start_time: 61139555.436, end_time: 61139556.672
# PP start_backend: 1 start_idx: 69 end_backend: 5 end_idx: 69 len: 1, start_time: 61139557.419, end_time: 61139605.222
# DP start_backend: 5 start_idx: 826 end_backend: 5 end_idx: 841 len: 16, start_time: 61141907.651, end_time: 61143879.254
# PP start_backend: 1 start_idx: 70 end_backend: 5 end_idx: 70 len: 1, start_time: 61144419.877, end_time: 61143879.254
# DP start_backend: 5 start_idx: 842 end_backend: 5 end_idx: 842 len: 1, start_time: 61144422.48, end_time: 61144424.801
# PP start_backend: 1 start_idx: 71 end_backend: 5 end_idx: 71 len: 1, start_time: 61144425.626, end_time: 61144477.282
# DP start_backend: 5 start_idx: 843 end_backend: 5 end_idx: 858 len: 16, start_time: 61144874.887, end_time: 61146886.331
# PP start_backend: 1 start_idx: 72 end_backend: 5 end_idx: 72 len: 1, start_time: 61146972.735, end_time: 61146974.714
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18, start_time: 61148996.149, end_time: 61150773.198
# PP start_backend: 1 start_idx: 73 end_backend: 5 end_idx: 73 len: 1, start_time: 61150777.88, end_time: 61150780.513
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3, start_time: 61150799.004, end_time: 61150807.997
# PP start_backend: 1 start_idx: 0 end_backend: 1 end_idx: 3 len: 4, start_time: 60996312.644, end_time: 61009877.143
# DP start_backend: 5 start_idx: 0 end_backend: 5 end_idx: 16 len: 17, start_time: 61009926.45, end_time: 61011857.694
# PP start_backend: 1 start_idx: 4 end_backend: 5 end_idx: 4 len: 1, start_time: 61011897.821, end_time: 61011899.3
# DP start_backend: 5 start_idx: 17 end_backend: 5 end_idx: 50 len: 34, start_time: 61011925.179, end_time: 61015686.993
# PP start_backend: 1 start_idx: 5 end_backend: 1 end_idx: 6 len: 2, start_time: 61015843.334, end_time: 61015848.277
# DP start_backend: 5 start_idx: 51 end_backend: 5 end_idx: 67 len: 17, start_time: 61016456.117, end_time: 61018484.122
# PP start_backend: 1 start_idx: 7 end_backend: 1 end_idx: 8 len: 2, start_time: 61018644.296, end_time: 61018649.034
# DP start_backend: 5 start_idx: 68 end_backend: 5 end_idx: 84 len: 17, start_time: 61019256.812, end_time: 61021260.724
# PP start_backend: 1 start_idx: 9 end_backend: 5 end_idx: 9 len: 1, start_time: 61021419.421, end_time: 61021421.472
# DP start_backend: 5 start_idx: 85 end_backend: 5 end_idx: 102 len: 18, start_time: 61021450.628, end_time: 61024641.981
# PP start_backend: 1 start_idx: 10 end_backend: 5 end_idx: 10 len: 1, start_time: 61024648.036, end_time: 61024729.349
# DP start_backend: 6 start_idx: 0 end_backend: 6 end_idx: 2 len: 3, start_time: 61024931.724, end_time: 61025012.76
# PP start_backend: 1 start_idx: 11 end_backend: 6 end_idx: 11 len: 1, start_time: 61026440.628, end_time: 61026441.573
# DP start_backend: 5 start_idx: 103 end_backend: 5 end_idx: 136 len: 34, start_time: 61026463.84, end_time: 61029929.945
# PP start_backend: 1 start_idx: 12 end_backend: 1 end_idx: 13 len: 2, start_time: 61030086.66, end_time: 61030090.232
# DP start_backend: 5 start_idx: 137 end_backend: 5 end_idx: 153 len: 17, start_time: 61030809.234, end_time: 61032831.079
# PP start_backend: 1 start_idx: 14 end_backend: 1 end_idx: 15 len: 2, start_time: 61032989.484, end_time: 61032993.743
# DP start_backend: 5 start_idx: 154 end_backend: 5 end_idx: 170 len: 17, start_time: 61033600.483, end_time: 61035604.801
# PP start_backend: 1 start_idx: 16 end_backend: 5 end_idx: 16 len: 1, start_time: 61035761.135, end_time: 61035762.45
# DP start_backend: 5 start_idx: 171 end_backend: 5 end_idx: 188 len: 18, start_time: 61035793.725, end_time: 61037555.8
# PP start_backend: 1 start_idx: 17 end_backend: 5 end_idx: 17 len: 1, start_time: 61038875.6, end_time: 61038877.514
# DP start_backend: 6 start_idx: 3 end_backend: 6 end_idx: 5 len: 3, start_time: 61038898.687, end_time: 61038905.775
# PP start_backend: 1 start_idx: 18 end_backend: 6 end_idx: 18 len: 1, start_time: 61040319.587, end_time: 61040320.628
# DP start_backend: 5 start_idx: 189 end_backend: 5 end_idx: 222 len: 34, start_time: 61040343.561, end_time: 61043729.416
# PP start_backend: 1 start_idx: 19 end_backend: 1 end_idx: 20 len: 2, start_time: 61043886.666, end_time: 61043891.015
# DP start_backend: 5 start_idx: 223 end_backend: 5 end_idx: 239 len: 17, start_time: 61044589.985, end_time: 61046640.371
# PP start_backend: 1 start_idx: 21 end_backend: 1 end_idx: 22 len: 2, start_time: 61046801.141, end_time: 61046804.88
# DP start_backend: 5 start_idx: 240 end_backend: 5 end_idx: 256 len: 17, start_time: 61047408.23, end_time: 61049431.977
# PP start_backend: 1 start_idx: 23 end_backend: 5 end_idx: 23 len: 1, start_time: 61049590.676, end_time: 61049591.987
# DP start_backend: 5 start_idx: 257 end_backend: 5 end_idx: 274 len: 18, start_time: 61049622.513, end_time: 61051387.009
# PP start_backend: 1 start_idx: 24 end_backend: 5 end_idx: 24 len: 1, start_time: 61052695.209, end_time: 61052695.885
# DP start_backend: 6 start_idx: 6 end_backend: 6 end_idx: 8 len: 3, start_time: 61052718.463, end_time: 61052725.56
# PP start_backend: 1 start_idx: 25 end_backend: 6 end_idx: 25 len: 1, start_time: 61054138.532, end_time: 61054138.966
# DP start_backend: 5 start_idx: 275 end_backend: 5 end_idx: 308 len: 34, start_time: 61054159.206, end_time: 61057576.507
# PP start_backend: 1 start_idx: 26 end_backend: 1 end_idx: 27 len: 2, start_time: 61057736.844, end_time: 61057739.537
# DP start_backend: 5 start_idx: 309 end_backend: 5 end_idx: 325 len: 17, start_time: 61058443.706, end_time: 61060483.505
# PP start_backend: 1 start_idx: 28 end_backend: 1 end_idx: 29 len: 2, start_time: 61060640.35, end_time: 61060644.451
# DP start_backend: 5 start_idx: 326 end_backend: 5 end_idx: 342 len: 17, start_time: 61061253.97, end_time: 61063335.909
# PP start_backend: 1 start_idx: 30 end_backend: 5 end_idx: 30 len: 1, start_time: 61063492.791, end_time: 61063493.656
# DP start_backend: 5 start_idx: 343 end_backend: 5 end_idx: 360 len: 18, start_time: 61063530.626, end_time: 61065407.598
# PP start_backend: 1 start_idx: 31 end_backend: 5 end_idx: 31 len: 1, start_time: 61066596.543, end_time: 61066597.162
# DP start_backend: 6 start_idx: 9 end_backend: 6 end_idx: 11 len: 3, start_time: 61066619.851, end_time: 61066626.806
# PP start_backend: 1 start_idx: 32 end_backend: 6 end_idx: 32 len: 1, start_time: 61068053.127, end_time: 61068053.66
# DP start_backend: 5 start_idx: 361 end_backend: 5 end_idx: 394 len: 34, start_time: 61068117.672, end_time: 61071543.716
# PP start_backend: 1 start_idx: 33 end_backend: 1 end_idx: 34 len: 2, start_time: 61071701.586, end_time: 61071706.204
# DP start_backend: 5 start_idx: 395 end_backend: 5 end_idx: 411 len: 17, start_time: 61072435.519, end_time: 61074441.388
# PP start_backend: 1 start_idx: 35 end_backend: 1 end_idx: 36 len: 2, start_time: 61074598.972, end_time: 61074602.246
# DP start_backend: 5 start_idx: 412 end_backend: 5 end_idx: 428 len: 17, start_time: 61075208.083, end_time: 61077208.182
# PP start_backend: 1 start_idx: 37 end_backend: 5 end_idx: 37 len: 1, start_time: 61077365.567, end_time: 61077366.015
# DP start_backend: 5 start_idx: 429 end_backend: 5 end_idx: 446 len: 18, start_time: 61077396.625, end_time: 61079232.425
# PP start_backend: 1 start_idx: 38 end_backend: 5 end_idx: 38 len: 1, start_time: 61080468.524, end_time: 61080469.966
# DP start_backend: 6 start_idx: 12 end_backend: 6 end_idx: 14 len: 3, start_time: 61080489.549, end_time: 61080495.021
# PP start_backend: 1 start_idx: 39 end_backend: 6 end_idx: 39 len: 1, start_time: 61081952.1, end_time: 61081952.721
# DP start_backend: 5 start_idx: 447 end_backend: 5 end_idx: 480 len: 34, start_time: 61081976.51, end_time: 61085394.324
# PP start_backend: 1 start_idx: 40 end_backend: 1 end_idx: 41 len: 2, start_time: 61085556.107, end_time: 61085559.237
# DP start_backend: 5 start_idx: 481 end_backend: 5 end_idx: 497 len: 17, start_time: 61086382.641, end_time: 61088469.033
# PP start_backend: 1 start_idx: 42 end_backend: 1 end_idx: 43 len: 2, start_time: 61088627.259, end_time: 61088630.142
# DP start_backend: 5 start_idx: 498 end_backend: 5 end_idx: 514 len: 17, start_time: 61089238.758, end_time: 61091251.792
# PP start_backend: 1 start_idx: 44 end_backend: 5 end_idx: 44 len: 1, start_time: 61091409.862, end_time: 61091410.508
# DP start_backend: 5 start_idx: 515 end_backend: 5 end_idx: 532 len: 18, start_time: 61091444.916, end_time: 61093230.291
# PP start_backend: 1 start_idx: 45 end_backend: 5 end_idx: 45 len: 1, start_time: 61094475.137, end_time: 61094476.212
# DP start_backend: 6 start_idx: 15 end_backend: 6 end_idx: 17 len: 3, start_time: 61094497.163, end_time: 61094502.22
# PP start_backend: 1 start_idx: 46 end_backend: 6 end_idx: 46 len: 1, start_time: 61095902.84, end_time: 61095903.816
# DP start_backend: 5 start_idx: 533 end_backend: 5 end_idx: 566 len: 34, start_time: 61095922.28, end_time: 61099439.146
# PP start_backend: 1 start_idx: 47 end_backend: 1 end_idx: 48 len: 2, start_time: 61099595.181, end_time: 61099598.795
# DP start_backend: 5 start_idx: 567 end_backend: 5 end_idx: 583 len: 17, start_time: 61100377.649, end_time: 61102432.961
# PP start_backend: 1 start_idx: 49 end_backend: 1 end_idx: 50 len: 2, start_time: 61102589.869, end_time: 61102592.899
# DP start_backend: 5 start_idx: 584 end_backend: 5 end_idx: 600 len: 17, start_time: 61103196.997, end_time: 61105268.739
# PP start_backend: 1 start_idx: 51 end_backend: 5 end_idx: 51 len: 1, start_time: 61105423.769, end_time: 61105424.479
# DP start_backend: 5 start_idx: 601 end_backend: 5 end_idx: 618 len: 18, start_time: 61105460.945, end_time: 61107445.77
# PP start_backend: 1 start_idx: 52 end_backend: 5 end_idx: 52 len: 1, start_time: 61108472.702, end_time: 61108474.234
# DP start_backend: 6 start_idx: 18 end_backend: 6 end_idx: 20 len: 3, start_time: 61108494.808, end_time: 61108501.915
# PP start_backend: 1 start_idx: 53 end_backend: 6 end_idx: 53 len: 1, start_time: 61109898.465, end_time: 61109899.984
# DP start_backend: 5 start_idx: 619 end_backend: 5 end_idx: 652 len: 34, start_time: 61109921.688, end_time: 61113486.661
# PP start_backend: 1 start_idx: 54 end_backend: 1 end_idx: 55 len: 2, start_time: 61113642.316, end_time: 61113645.739
# DP start_backend: 5 start_idx: 653 end_backend: 5 end_idx: 669 len: 17, start_time: 61114348.353, end_time: 61116507.848
# PP start_backend: 1 start_idx: 56 end_backend: 1 end_idx: 57 len: 2, start_time: 61116664.28, end_time: 61116668.965
# DP start_backend: 5 start_idx: 670 end_backend: 5 end_idx: 686 len: 17, start_time: 61117271.979, end_time: 61119316.835
# PP start_backend: 1 start_idx: 58 end_backend: 5 end_idx: 58 len: 1, start_time: 61119473.31, end_time: 61119473.818
# DP start_backend: 5 start_idx: 687 end_backend: 5 end_idx: 704 len: 18, start_time: 61119507.521, end_time: 61121441.492
# PP start_backend: 1 start_idx: 59 end_backend: 5 end_idx: 59 len: 1, start_time: 61122540.722, end_time: 61122541.844
# DP start_backend: 6 start_idx: 21 end_backend: 6 end_idx: 23 len: 3, start_time: 61122561.742, end_time: 61122566.679
# PP start_backend: 1 start_idx: 60 end_backend: 6 end_idx: 60 len: 1, start_time: 61123993.566, end_time: 61123994.214
# DP start_backend: 5 start_idx: 705 end_backend: 5 end_idx: 738 len: 34, start_time: 61124014.794, end_time: 61127561.476
# PP start_backend: 1 start_idx: 61 end_backend: 1 end_idx: 62 len: 2, start_time: 61127717.346, end_time: 61127721.252
# DP start_backend: 5 start_idx: 739 end_backend: 5 end_idx: 755 len: 17, start_time: 61128420.071, end_time: 61130541.102
# PP start_backend: 1 start_idx: 63 end_backend: 1 end_idx: 64 len: 2, start_time: 61130697.109, end_time: 61130701.402
# DP start_backend: 5 start_idx: 756 end_backend: 5 end_idx: 772 len: 17, start_time: 61131306.128, end_time: 61133386.378
# PP start_backend: 1 start_idx: 65 end_backend: 5 end_idx: 65 len: 1, start_time: 61133542.516, end_time: 61133544.541
# DP start_backend: 5 start_idx: 773 end_backend: 5 end_idx: 790 len: 18, start_time: 61133580.844, end_time: 61135563.994
# PP start_backend: 1 start_idx: 66 end_backend: 5 end_idx: 66 len: 1, start_time: 61136654.484, end_time: 61136655.537
# DP start_backend: 6 start_idx: 24 end_backend: 6 end_idx: 26 len: 3, start_time: 61136676.736, end_time: 61136682.577
# PP start_backend: 1 start_idx: 67 end_backend: 6 end_idx: 67 len: 1, start_time: 61138106.897, end_time: 61138107.48
# DP start_backend: 5 start_idx: 791 end_backend: 5 end_idx: 824 len: 34, start_time: 61138135.131, end_time: 61141690.3
# PP start_backend: 1 start_idx: 68 end_backend: 1 end_idx: 69 len: 2, start_time: 61141846.002, end_time: 61141850.395
# DP start_backend: 5 start_idx: 825 end_backend: 5 end_idx: 841 len: 17, start_time: 61142573.844, end_time: 61144659.25
# PP start_backend: 1 start_idx: 70 end_backend: 1 end_idx: 71 len: 2, start_time: 61144819.737, end_time: 61144822.868
# DP start_backend: 5 start_idx: 842 end_backend: 5 end_idx: 858 len: 17, start_time: 61145428.939, end_time: 61147523.55
# PP start_backend: 1 start_idx: 72 end_backend: 5 end_idx: 72 len: 1, start_time: 61147680.045, end_time: 61147682.018
# DP start_backend: 5 start_idx: 859 end_backend: 5 end_idx: 876 len: 18, start_time: 61147711.324, end_time: 61149653.586
# PP start_backend: 1 start_idx: 73 end_backend: 5 end_idx: 73 len: 1, start_time: 61150778.537, end_time: 61150780.565
# DP start_backend: 6 start_idx: 27 end_backend: 6 end_idx: 29 len: 3, start_time: 61150801.4, end_time: 61150810.394
# Backend: 1, Idx: 0, Min Gap: 49.307 ms
# Backend: 1, Idx: 4, Min Gap: 25.879 ms
# Backend: 1, Idx: 5, Min Gap: 53.048 ms
# Backend: 1, Idx: 7, Min Gap: 607.778 ms
# Backend: 1, Idx: 9, Min Gap: 29.156 ms
# Backend: 1, Idx: 10, Min Gap: 200.847 ms
# Backend: 1, Idx: 11, Min Gap: 22.267 ms
# Backend: 1, Idx: 12, Min Gap: 105.476 ms
# Backend: 1, Idx: 14, Min Gap: 545.906 ms
# Backend: 1, Idx: 16, Min Gap: 31.275 ms
# Backend: 1, Idx: 17, Min Gap: 18.007 ms
# Backend: 1, Idx: 18, Min Gap: 22.933 ms
# Backend: 1, Idx: 19, Min Gap: 37.110 ms
# Backend: 1, Idx: 21, Min Gap: 543.568 ms
# Backend: 1, Idx: 23, Min Gap: 30.526 ms
# Backend: 1, Idx: 24, Min Gap: 17.220 ms
# Backend: 1, Idx: 25, Min Gap: 20.240 ms
# Backend: 1, Idx: 26, Min Gap: 61.559 ms
# Backend: 1, Idx: 28, Min Gap: 547.609 ms
# Backend: 1, Idx: 30, Min Gap: 36.970 ms
# Backend: 1, Idx: 31, Min Gap: 16.562 ms
# Backend: 1, Idx: 32, Min Gap: 64.012 ms
# Backend: 1, Idx: 33, Min Gap: 75.782 ms
# Backend: 1, Idx: 35, Min Gap: 550.479 ms
# Backend: 1, Idx: 37, Min Gap: 30.610 ms
# Backend: 1, Idx: 38, Min Gap: 16.507 ms
# Backend: 1, Idx: 39, Min Gap: 23.789 ms
# Backend: 1, Idx: 40, Min Gap: 67.351 ms
# Backend: 1, Idx: 42, Min Gap: 543.563 ms
# Backend: 1, Idx: 44, Min Gap: 34.408 ms
# Backend: 1, Idx: 45, Min Gap: 20.753 ms
# Backend: 1, Idx: 46, Min Gap: 18.464 ms
# Backend: 1, Idx: 47, Min Gap: 116.709 ms
# Backend: 1, Idx: 49, Min Gap: 548.994 ms
# Backend: 1, Idx: 51, Min Gap: 36.466 ms
# Backend: 1, Idx: 52, Min Gap: 17.868 ms
# Backend: 1, Idx: 53, Min Gap: 21.704 ms
# Backend: 1, Idx: 54, Min Gap: 140.295 ms
# Backend: 1, Idx: 56, Min Gap: 542.640 ms
# Backend: 1, Idx: 58, Min Gap: 33.703 ms
# Backend: 1, Idx: 59, Min Gap: 18.432 ms
# Backend: 1, Idx: 60, Min Gap: 20.580 ms
# Backend: 1, Idx: 61, Min Gap: 94.582 ms
# Backend: 1, Idx: 63, Min Gap: 543.537 ms
# Backend: 1, Idx: 65, Min Gap: 36.303 ms
# Backend: 1, Idx: 66, Min Gap: 18.556 ms
# Backend: 1, Idx: 67, Min Gap: 27.651 ms
# Backend: 1, Idx: 68, Min Gap: 159.496 ms
# Backend: 1, Idx: 70, Min Gap: 543.226 ms
# Backend: 1, Idx: 72, Min Gap: 29.306 ms
# Backend: 1, Idx: 73, Min Gap: 18.491 ms
# Average time gap: 145.833 ms
# Standard deviation: 204.144 ms
# Minimum time gap: 16.507 ms
# Maximum time gap: 607.778 ms
