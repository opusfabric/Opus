# %%
import re
from datetime import datetime
import numpy as np

# %%
def extract_data(file_path):
    data = {}
    with open(file_path, 'r') as file:
        for line in file:
            # Match the log line with the required pattern
            match = re.search(r'(\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2},\d{3}) - root - INFO - .*?step:\s+(\d+).*?memory:\s+([\d.]+GiB).*?tps:\s+([\d.]+).*?tflops:\s+([\d.]+)', line)
            if match:
                timestamp = match.group(1)
                step = int(match.group(2))
                memory = match.group(3)
                tps = float(match.group(4))
                tflops = float(match.group(5))
                
                # Only store data for steps 1 to 10
                if 1 <= step <= 10:
                    if step not in data:
                        data[step] = {
                            'timestamp': timestamp,
                            'memory': memory,
                            'tps': tps,
                            'tflops': tflops
                        }
    return data

# %%
import csv

# Example usage

def store_data(file_path_base, experiment, file_name, output_file):
    file_path = file_path_base + experiment + "/" + file_name

    result = extract_data(file_path)

    print(experiment)

    for step in sorted(result.keys()):
        print(f"Step {step}: {result[step]}")

    # Calculate per step latency and average latency with standard deviation
    if 4 in result and 10 in result:
        time_format = "%Y-%m-%d %H:%M:%S,%f"
        step_times = []

        for step in range(4, 11):
            if step in result:
                step_time = datetime.strptime(result[step]['timestamp'], time_format)
                step_times.append((step, step_time))

        # Calculate per step latency
        per_step_latencies = []
        for i in range(1, len(step_times)):
            step_diff = step_times[i][0] - step_times[i - 1][0]
            time_diff = (step_times[i][1] - step_times[i - 1][1]).total_seconds()
            latency = time_diff / step_diff
            per_step_latencies.append(latency)
            print(f"Latency between step {step_times[i - 1][0]} and step {step_times[i][0]}: {latency:.3f} seconds")

        # Calculate average latency and standard deviation
        avg_latency = np.mean(per_step_latencies)
        std_latency = np.std(per_step_latencies)
        min_latency = np.min(per_step_latencies)
        print(f"{experiment}, avg step latency: {avg_latency:.3f} seconds, std: {std_latency:.3f} seconds, min: {min_latency:.3f} seconds")
        # Save step latency and standard deviation to a CSV file
        
        with open(output_file, mode='a', newline='') as file:  # Open in append mode
            writer = csv.writer(file)
            writer.writerow([experiment, min_latency, avg_latency, std_latency])

        print(f"Latency data appended to {output_file}")

        print(f"Latency data saved to {output_file}")
    else:
        print("Step 4 or Step 10 data is missing.")

# %%
import os

file_path_base = '<path-to-opus>/Opus/torchtitan/opus-test/deepseek-dp-2-pp-2-tp-4-pm/'


latency = [0, 10, 50, 100, 250, 500, 750, 1000]
experiments =  ["output-no-controller"] + [f"output-opus-l_{l}-baseline" for l in latency]
file_name = [
    next(
        (f for f in os.listdir(os.path.join(file_path_base, exp)) if f.startswith("torchrun_nid") and f.endswith(".ans")),
        None
    )
    for exp in experiments
]

output_file = 'latency_results_baseline.csv'

# Write the CSV header if the file does not exist or is empty
# Clean the CSV file before writing
if os.path.exists(output_file):
    with open(output_file, mode='w', newline='') as file:
        file.truncate(0)
if not os.path.exists(output_file) or os.stat(output_file).st_size == 0:
    with open(output_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Experiment', 'Min latency (s)', 'Average Latency (s)', 'Standard Deviation (s)'])
for experiment, file_name in zip(experiments, file_name):
    store_data(file_path_base, experiment, file_name, output_file)
# Out:
# output-no-controller
# Step 1: {'timestamp': '2026-02-02 02:52:17,950', 'memory': '29.14GiB', 'tps': 45.0, 'tflops': 0.72}
# Step 2: {'timestamp': '2026-02-02 02:52:31,654', 'memory': '36.58GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 3: {'timestamp': '2026-02-02 02:52:45,317', 'memory': '37.57GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 4: {'timestamp': '2026-02-02 02:52:58,808', 'memory': '37.37GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 5: {'timestamp': '2026-02-02 02:53:12,124', 'memory': '36.80GiB', 'tps': 77.0, 'tflops': 1.24}
# Step 6: {'timestamp': '2026-02-02 02:53:25,739', 'memory': '36.80GiB', 'tps': 75.0, 'tflops': 1.21}
# Step 7: {'timestamp': '2026-02-02 02:53:39,251', 'memory': '36.81GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 8: {'timestamp': '2026-02-02 02:53:52,631', 'memory': '36.90GiB', 'tps': 77.0, 'tflops': 1.23}
# Step 9: {'timestamp': '2026-02-02 02:54:06,073', 'memory': '37.03GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 10: {'timestamp': '2026-02-02 02:54:19,567', 'memory': '36.90GiB', 'tps': 76.0, 'tflops': 1.22}
# Latency between step 4 and step 5: 13.316 seconds
# Latency between step 5 and step 6: 13.615 seconds
# Latency between step 6 and step 7: 13.512 seconds
# Latency between step 7 and step 8: 13.380 seconds
# Latency between step 8 and step 9: 13.442 seconds
# Latency between step 9 and step 10: 13.494 seconds
# output-no-controller, avg step latency: 13.460 seconds, std: 0.096 seconds, min: 13.316 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_0-baseline
# Step 1: {'timestamp': '2026-02-02 18:48:25,089', 'memory': '29.23GiB', 'tps': 31.0, 'tflops': 0.5}
# Step 2: {'timestamp': '2026-02-02 18:48:38,767', 'memory': '36.68GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 3: {'timestamp': '2026-02-02 18:48:52,542', 'memory': '37.37GiB', 'tps': 74.0, 'tflops': 1.19}
# Step 4: {'timestamp': '2026-02-02 18:49:06,909', 'memory': '37.37GiB', 'tps': 71.0, 'tflops': 1.15}
# Step 5: {'timestamp': '2026-02-02 18:49:20,355', 'memory': '36.76GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 6: {'timestamp': '2026-02-02 18:49:33,748', 'memory': '36.92GiB', 'tps': 76.0, 'tflops': 1.23}
# Step 7: {'timestamp': '2026-02-02 18:49:47,160', 'memory': '37.24GiB', 'tps': 76.0, 'tflops': 1.23}
# Step 8: {'timestamp': '2026-02-02 18:50:00,500', 'memory': '36.76GiB', 'tps': 77.0, 'tflops': 1.23}
# Step 9: {'timestamp': '2026-02-02 18:50:16,503', 'memory': '37.24GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 10: {'timestamp': '2026-02-02 18:50:29,937', 'memory': '36.92GiB', 'tps': 76.0, 'tflops': 1.23}
# Latency between step 4 and step 5: 13.446 seconds
# Latency between step 5 and step 6: 13.393 seconds
# Latency between step 6 and step 7: 13.412 seconds
# Latency between step 7 and step 8: 13.340 seconds
# Latency between step 8 and step 9: 16.003 seconds
# Latency between step 9 and step 10: 13.434 seconds
# output-opus-l_0-baseline, avg step latency: 13.838 seconds, std: 0.969 seconds, min: 13.340 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_10-baseline
# Step 1: {'timestamp': '2026-02-02 18:41:52,932', 'memory': '29.14GiB', 'tps': 31.0, 'tflops': 0.49}
# Step 2: {'timestamp': '2026-02-02 18:42:06,704', 'memory': '36.60GiB', 'tps': 74.0, 'tflops': 1.2}
# Step 3: {'timestamp': '2026-02-02 18:42:20,477', 'memory': '37.37GiB', 'tps': 74.0, 'tflops': 1.19}
# Step 4: {'timestamp': '2026-02-02 18:42:34,131', 'memory': '37.37GiB', 'tps': 75.0, 'tflops': 1.21}
# Step 5: {'timestamp': '2026-02-02 18:42:47,699', 'memory': '36.83GiB', 'tps': 76.0, 'tflops': 1.21}
# Step 6: {'timestamp': '2026-02-02 18:43:01,226', 'memory': '36.82GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 7: {'timestamp': '2026-02-02 18:43:14,580', 'memory': '36.82GiB', 'tps': 77.0, 'tflops': 1.23}
# Step 8: {'timestamp': '2026-02-02 18:43:28,261', 'memory': '36.79GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 9: {'timestamp': '2026-02-02 18:43:41,777', 'memory': '36.82GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 10: {'timestamp': '2026-02-02 18:43:55,683', 'memory': '36.85GiB', 'tps': 74.0, 'tflops': 1.19}
# Latency between step 4 and step 5: 13.568 seconds
# Latency between step 5 and step 6: 13.527 seconds
# Latency between step 6 and step 7: 13.354 seconds
# Latency between step 7 and step 8: 13.681 seconds
# Latency between step 8 and step 9: 13.516 seconds
# Latency between step 9 and step 10: 13.906 seconds
# output-opus-l_10-baseline, avg step latency: 13.592 seconds, std: 0.170 seconds, min: 13.354 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_50-baseline
# Step 1: {'timestamp': '2026-02-02 18:38:41,054', 'memory': '29.13GiB', 'tps': 30.0, 'tflops': 0.48}
# Step 2: {'timestamp': '2026-02-02 18:38:54,726', 'memory': '36.60GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 3: {'timestamp': '2026-02-02 18:39:08,406', 'memory': '37.38GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 4: {'timestamp': '2026-02-02 18:39:22,264', 'memory': '37.38GiB', 'tps': 74.0, 'tflops': 1.19}
# Step 5: {'timestamp': '2026-02-02 18:39:35,981', 'memory': '37.38GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 6: {'timestamp': '2026-02-02 18:39:49,794', 'memory': '36.54GiB', 'tps': 74.0, 'tflops': 1.19}
# Step 7: {'timestamp': '2026-02-02 18:40:03,875', 'memory': '36.77GiB', 'tps': 73.0, 'tflops': 1.17}
# Step 8: {'timestamp': '2026-02-02 18:40:17,761', 'memory': '36.79GiB', 'tps': 74.0, 'tflops': 1.18}
# Step 9: {'timestamp': '2026-02-02 18:40:32,475', 'memory': '36.63GiB', 'tps': 70.0, 'tflops': 1.12}
# Step 10: {'timestamp': '2026-02-02 18:40:47,011', 'memory': '36.63GiB', 'tps': 70.0, 'tflops': 1.13}
# Latency between step 4 and step 5: 13.717 seconds
# Latency between step 5 and step 6: 13.813 seconds
# Latency between step 6 and step 7: 14.081 seconds
# Latency between step 7 and step 8: 13.886 seconds
# Latency between step 8 and step 9: 14.714 seconds
# Latency between step 9 and step 10: 14.536 seconds
# output-opus-l_50-baseline, avg step latency: 14.124 seconds, std: 0.374 seconds, min: 13.717 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_100-baseline
# Step 1: {'timestamp': '2026-02-02 18:35:20,184', 'memory': '29.15GiB', 'tps': 19.0, 'tflops': 0.31}
# Step 2: {'timestamp': '2026-02-02 18:35:35,159', 'memory': '36.68GiB', 'tps': 69.0, 'tflops': 1.1}
# Step 3: {'timestamp': '2026-02-02 18:35:49,802', 'memory': '37.38GiB', 'tps': 70.0, 'tflops': 1.13}
# Step 4: {'timestamp': '2026-02-02 18:36:04,480', 'memory': '37.38GiB', 'tps': 70.0, 'tflops': 1.12}
# Step 5: {'timestamp': '2026-02-02 18:36:19,169', 'memory': '37.75GiB', 'tps': 70.0, 'tflops': 1.13}
# Step 6: {'timestamp': '2026-02-02 18:36:33,801', 'memory': '37.75GiB', 'tps': 70.0, 'tflops': 1.12}
# Step 7: {'timestamp': '2026-02-02 18:36:48,318', 'memory': '36.74GiB', 'tps': 71.0, 'tflops': 1.13}
# Step 8: {'timestamp': '2026-02-02 18:37:02,965', 'memory': '36.78GiB', 'tps': 70.0, 'tflops': 1.12}
# Step 9: {'timestamp': '2026-02-02 18:37:17,410', 'memory': '36.90GiB', 'tps': 71.0, 'tflops': 1.14}
# Step 10: {'timestamp': '2026-02-02 18:37:31,930', 'memory': '37.15GiB', 'tps': 71.0, 'tflops': 1.13}
# Latency between step 4 and step 5: 14.689 seconds
# Latency between step 5 and step 6: 14.632 seconds
# Latency between step 6 and step 7: 14.517 seconds
# Latency between step 7 and step 8: 14.647 seconds
# Latency between step 8 and step 9: 14.445 seconds
# Latency between step 9 and step 10: 14.520 seconds
# output-opus-l_100-baseline, avg step latency: 14.575 seconds, std: 0.086 seconds, min: 14.445 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_250-baseline
# Step 1: {'timestamp': '2026-02-02 18:45:02,885', 'memory': '29.14GiB', 'tps': 28.0, 'tflops': 0.45}
# Step 2: {'timestamp': '2026-02-02 18:45:17,986', 'memory': '36.79GiB', 'tps': 68.0, 'tflops': 1.09}
# Step 3: {'timestamp': '2026-02-02 18:45:32,754', 'memory': '37.57GiB', 'tps': 69.0, 'tflops': 1.11}
# Step 4: {'timestamp': '2026-02-02 18:45:47,680', 'memory': '37.38GiB', 'tps': 69.0, 'tflops': 1.1}
# Step 5: {'timestamp': '2026-02-02 18:46:02,413', 'memory': '37.66GiB', 'tps': 70.0, 'tflops': 1.12}
# Step 6: {'timestamp': '2026-02-02 18:46:17,350', 'memory': '37.01GiB', 'tps': 69.0, 'tflops': 1.1}
# Step 7: {'timestamp': '2026-02-02 18:46:32,110', 'memory': '37.07GiB', 'tps': 69.0, 'tflops': 1.11}
# Step 8: {'timestamp': '2026-02-02 18:46:46,913', 'memory': '36.98GiB', 'tps': 69.0, 'tflops': 1.11}
# Step 9: {'timestamp': '2026-02-02 18:47:01,655', 'memory': '37.08GiB', 'tps': 69.0, 'tflops': 1.12}
# Step 10: {'timestamp': '2026-02-02 18:47:16,785', 'memory': '36.66GiB', 'tps': 68.0, 'tflops': 1.09}
# Latency between step 4 and step 5: 14.733 seconds
# Latency between step 5 and step 6: 14.937 seconds
# Latency between step 6 and step 7: 14.760 seconds
# Latency between step 7 and step 8: 14.803 seconds
# Latency between step 8 and step 9: 14.742 seconds
# Latency between step 9 and step 10: 15.130 seconds
# output-opus-l_250-baseline, avg step latency: 14.851 seconds, std: 0.142 seconds, min: 14.733 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_500-baseline
# Step 1: {'timestamp': '2026-02-02 18:51:37,261', 'memory': '29.13GiB', 'tps': 28.0, 'tflops': 0.45}
# Step 2: {'timestamp': '2026-02-02 18:51:53,434', 'memory': '36.78GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 3: {'timestamp': '2026-02-02 18:52:09,413', 'memory': '37.37GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 4: {'timestamp': '2026-02-02 18:52:25,415', 'memory': '37.56GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 5: {'timestamp': '2026-02-02 18:52:41,564', 'memory': '36.88GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 6: {'timestamp': '2026-02-02 18:52:57,598', 'memory': '36.88GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 7: {'timestamp': '2026-02-02 18:53:13,501', 'memory': '36.77GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 8: {'timestamp': '2026-02-02 18:53:29,363', 'memory': '36.80GiB', 'tps': 65.0, 'tflops': 1.04}
# Step 9: {'timestamp': '2026-02-02 18:53:45,049', 'memory': '36.77GiB', 'tps': 65.0, 'tflops': 1.05}
# Step 10: {'timestamp': '2026-02-02 18:54:00,681', 'memory': '36.77GiB', 'tps': 66.0, 'tflops': 1.05}
# Latency between step 4 and step 5: 16.149 seconds
# Latency between step 5 and step 6: 16.034 seconds
# Latency between step 6 and step 7: 15.903 seconds
# Latency between step 7 and step 8: 15.862 seconds
# Latency between step 8 and step 9: 15.686 seconds
# Latency between step 9 and step 10: 15.632 seconds
# output-opus-l_500-baseline, avg step latency: 15.878 seconds, std: 0.181 seconds, min: 15.632 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_750-baseline
# Step 1: {'timestamp': '2026-02-02 18:55:10,873', 'memory': '29.13GiB', 'tps': 25.0, 'tflops': 0.4}
# Step 2: {'timestamp': '2026-02-02 18:55:28,701', 'memory': '36.68GiB', 'tps': 57.0, 'tflops': 0.92}
# Step 3: {'timestamp': '2026-02-02 18:55:46,118', 'memory': '37.38GiB', 'tps': 59.0, 'tflops': 0.95}
# Step 4: {'timestamp': '2026-02-02 18:56:03,499', 'memory': '37.38GiB', 'tps': 59.0, 'tflops': 0.95}
# Step 5: {'timestamp': '2026-02-02 18:56:20,768', 'memory': '37.57GiB', 'tps': 59.0, 'tflops': 0.95}
# Step 6: {'timestamp': '2026-02-02 18:56:38,016', 'memory': '36.59GiB', 'tps': 59.0, 'tflops': 0.95}
# Step 7: {'timestamp': '2026-02-02 18:56:55,335', 'memory': '36.78GiB', 'tps': 59.0, 'tflops': 0.95}
# Step 8: {'timestamp': '2026-02-02 18:57:12,504', 'memory': '36.88GiB', 'tps': 60.0, 'tflops': 0.96}
# Step 9: {'timestamp': '2026-02-02 18:57:29,715', 'memory': '36.78GiB', 'tps': 60.0, 'tflops': 0.96}
# Step 10: {'timestamp': '2026-02-02 18:57:47,415', 'memory': '37.05GiB', 'tps': 58.0, 'tflops': 0.93}
# Latency between step 4 and step 5: 17.269 seconds
# Latency between step 5 and step 6: 17.248 seconds
# Latency between step 6 and step 7: 17.319 seconds
# Latency between step 7 and step 8: 17.169 seconds
# Latency between step 8 and step 9: 17.211 seconds
# Latency between step 9 and step 10: 17.700 seconds
# output-opus-l_750-baseline, avg step latency: 17.319 seconds, std: 0.176 seconds, min: 17.169 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv
# output-opus-l_1000-baseline
# Step 1: {'timestamp': '2026-02-02 18:59:01,185', 'memory': '29.13GiB', 'tps': 24.0, 'tflops': 0.39}
# Step 2: {'timestamp': '2026-02-02 18:59:19,905', 'memory': '36.59GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 3: {'timestamp': '2026-02-02 18:59:38,575', 'memory': '37.37GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 4: {'timestamp': '2026-02-02 18:59:57,153', 'memory': '37.57GiB', 'tps': 55.0, 'tflops': 0.89}
# Step 5: {'timestamp': '2026-02-02 19:00:15,873', 'memory': '36.88GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 6: {'timestamp': '2026-02-02 19:00:34,677', 'memory': '36.88GiB', 'tps': 54.0, 'tflops': 0.88}
# Step 7: {'timestamp': '2026-02-02 19:00:53,219', 'memory': '36.99GiB', 'tps': 55.0, 'tflops': 0.89}
# Step 8: {'timestamp': '2026-02-02 19:01:11,810', 'memory': '36.88GiB', 'tps': 55.0, 'tflops': 0.89}
# Step 9: {'timestamp': '2026-02-02 19:01:30,509', 'memory': '36.88GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 10: {'timestamp': '2026-02-02 19:01:49,258', 'memory': '37.00GiB', 'tps': 55.0, 'tflops': 0.88}
# Latency between step 4 and step 5: 18.720 seconds
# Latency between step 5 and step 6: 18.804 seconds
# Latency between step 6 and step 7: 18.542 seconds
# Latency between step 7 and step 8: 18.591 seconds
# Latency between step 8 and step 9: 18.699 seconds
# Latency between step 9 and step 10: 18.749 seconds
# output-opus-l_1000-baseline, avg step latency: 18.684 seconds, std: 0.090 seconds, min: 18.542 seconds
# Latency data appended to latency_results_baseline.csv
# Latency data saved to latency_results_baseline.csv

# %%
import os

file_path_base = '<path-to-opus>/Opus/torchtitan/opus-test/deepseek-dp-2-pp-2-tp-4-pm/'


latency = [0, 10, 50, 100, 250, 500]
experiments =  ["output-no-controller"] + [f"output-opus-l_{l}-provision-cuda-pre" for l in latency]
file_name = [
    next(
        (f for f in os.listdir(os.path.join(file_path_base, exp)) if f.startswith("torchrun_nid") and f.endswith(".ans")),
        None
    )
    for exp in experiments
]

output_file = 'latency_results_provision-cuda-pre.csv'

# Write the CSV header if the file does not exist or is empty
# Clean the CSV file before writing
if os.path.exists(output_file):
    with open(output_file, mode='w', newline='') as file:
        file.truncate(0)
if not os.path.exists(output_file) or os.stat(output_file).st_size == 0:
    with open(output_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Experiment', 'Min latency (s)', 'Average Latency (s)', 'Standard Deviation (s)'])
for experiment, file_name in zip(experiments, file_name):
    store_data(file_path_base, experiment, file_name, output_file)
# Out:
# output-no-controller
# Step 1: {'timestamp': '2026-02-02 02:52:17,950', 'memory': '29.14GiB', 'tps': 45.0, 'tflops': 0.72}
# Step 2: {'timestamp': '2026-02-02 02:52:31,654', 'memory': '36.58GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 3: {'timestamp': '2026-02-02 02:52:45,317', 'memory': '37.57GiB', 'tps': 75.0, 'tflops': 1.2}
# Step 4: {'timestamp': '2026-02-02 02:52:58,808', 'memory': '37.37GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 5: {'timestamp': '2026-02-02 02:53:12,124', 'memory': '36.80GiB', 'tps': 77.0, 'tflops': 1.24}
# Step 6: {'timestamp': '2026-02-02 02:53:25,739', 'memory': '36.80GiB', 'tps': 75.0, 'tflops': 1.21}
# Step 7: {'timestamp': '2026-02-02 02:53:39,251', 'memory': '36.81GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 8: {'timestamp': '2026-02-02 02:53:52,631', 'memory': '36.90GiB', 'tps': 77.0, 'tflops': 1.23}
# Step 9: {'timestamp': '2026-02-02 02:54:06,073', 'memory': '37.03GiB', 'tps': 76.0, 'tflops': 1.22}
# Step 10: {'timestamp': '2026-02-02 02:54:19,567', 'memory': '36.90GiB', 'tps': 76.0, 'tflops': 1.22}
# Latency between step 4 and step 5: 13.316 seconds
# Latency between step 5 and step 6: 13.615 seconds
# Latency between step 6 and step 7: 13.512 seconds
# Latency between step 7 and step 8: 13.380 seconds
# Latency between step 8 and step 9: 13.442 seconds
# Latency between step 9 and step 10: 13.494 seconds
# output-no-controller, avg step latency: 13.460 seconds, std: 0.096 seconds, min: 13.316 seconds
# Latency data appended to latency_results_provision-cuda-pre.csv
# Latency data saved to latency_results_provision-cuda-pre.csv
# output-opus-l_0-provision-cuda-pre
# Step 1: {'timestamp': '2026-02-03 04:27:45,526', 'memory': '27.09GiB', 'tps': 30.0, 'tflops': 0.48}
# Step 2: {'timestamp': '2026-02-03 04:28:01,811', 'memory': '34.19GiB', 'tps': 63.0, 'tflops': 1.01}
# Step 3: {'timestamp': '2026-02-03 04:28:18,018', 'memory': '34.47GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 4: {'timestamp': '2026-02-03 04:28:34,239', 'memory': '34.47GiB', 'tps': 63.0, 'tflops': 1.01}
# Step 5: {'timestamp': '2026-02-03 04:28:50,413', 'memory': '34.65GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 6: {'timestamp': '2026-02-03 04:29:06,837', 'memory': '34.77GiB', 'tps': 62.0, 'tflops': 1.0}
# Step 7: {'timestamp': '2026-02-03 04:29:23,031', 'memory': '34.77GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 8: {'timestamp': '2026-02-03 04:29:39,162', 'memory': '34.86GiB', 'tps': 64.0, 'tflops': 1.02}
# Step 9: {'timestamp': '2026-02-03 04:29:55,350', 'memory': '34.77GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 10: {'timestamp': '2026-02-03 04:30:11,406', 'memory': '34.77GiB', 'tps': 64.0, 'tflops': 1.02}
# Latency between step 4 and step 5: 16.174 seconds
# Latency between step 5 and step 6: 16.424 seconds
# Latency between step 6 and step 7: 16.194 seconds
# Latency between step 7 and step 8: 16.131 seconds
# Latency between step 8 and step 9: 16.188 seconds
# Latency between step 9 and step 10: 16.056 seconds
# output-opus-l_0-provision-cuda-pre, avg step latency: 16.195 seconds, std: 0.113 seconds, min: 16.056 seconds
# Latency data appended to latency_results_provision-cuda-pre.csv
# Latency data saved to latency_results_provision-cuda-pre.csv
# output-opus-l_10-provision-cuda-pre
# Step 1: {'timestamp': '2026-02-03 04:20:36,614', 'memory': '27.10GiB', 'tps': 31.0, 'tflops': 0.5}
# Step 2: {'timestamp': '2026-02-03 04:20:52,965', 'memory': '34.75GiB', 'tps': 63.0, 'tflops': 1.01}
# Step 3: {'timestamp': '2026-02-03 04:21:09,190', 'memory': '34.75GiB', 'tps': 63.0, 'tflops': 1.01}
# Step 4: {'timestamp': '2026-02-03 04:21:25,226', 'memory': '34.75GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 5: {'timestamp': '2026-02-03 04:21:41,208', 'memory': '34.75GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 6: {'timestamp': '2026-02-03 04:21:57,313', 'memory': '34.75GiB', 'tps': 64.0, 'tflops': 1.02}
# Step 7: {'timestamp': '2026-02-03 04:22:13,522', 'memory': '34.75GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 8: {'timestamp': '2026-02-03 04:22:29,536', 'memory': '34.75GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 9: {'timestamp': '2026-02-03 04:22:45,386', 'memory': '34.75GiB', 'tps': 65.0, 'tflops': 1.04}
# Step 10: {'timestamp': '2026-02-03 04:23:01,274', 'memory': '35.06GiB', 'tps': 64.0, 'tflops': 1.04}
# Latency between step 4 and step 5: 15.982 seconds
# Latency between step 5 and step 6: 16.105 seconds
# Latency between step 6 and step 7: 16.209 seconds
# Latency between step 7 and step 8: 16.014 seconds
# Latency between step 8 and step 9: 15.850 seconds
# Latency between step 9 and step 10: 15.888 seconds
# output-opus-l_10-provision-cuda-pre, avg step latency: 16.008 seconds, std: 0.122 seconds, min: 15.850 seconds
# Latency data appended to latency_results_provision-cuda-pre.csv
# Latency data saved to latency_results_provision-cuda-pre.csv
# output-opus-l_50-provision-cuda-pre
# Step 1: {'timestamp': '2026-02-03 04:17:04,158', 'memory': '27.01GiB', 'tps': 31.0, 'tflops': 0.5}
# Step 2: {'timestamp': '2026-02-03 04:17:20,153', 'memory': '34.75GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 3: {'timestamp': '2026-02-03 04:17:36,074', 'memory': '34.75GiB', 'tps': 64.0, 'tflops': 1.03}
# Step 4: {'timestamp': '2026-02-03 04:17:52,303', 'memory': '35.04GiB', 'tps': 63.0, 'tflops': 1.01}
# Step 5: {'timestamp': '2026-02-03 04:18:08,646', 'memory': '34.86GiB', 'tps': 63.0, 'tflops': 1.01}
# Step 6: {'timestamp': '2026-02-03 04:18:25,211', 'memory': '35.05GiB', 'tps': 62.0, 'tflops': 0.99}
# Step 7: {'timestamp': '2026-02-03 04:18:42,086', 'memory': '35.05GiB', 'tps': 61.0, 'tflops': 0.98}
# Step 8: {'timestamp': '2026-02-03 04:18:58,505', 'memory': '35.14GiB', 'tps': 62.0, 'tflops': 1.0}
# Step 9: {'timestamp': '2026-02-03 04:19:14,810', 'memory': '35.05GiB', 'tps': 63.0, 'tflops': 1.01}
# Step 10: {'timestamp': '2026-02-03 04:19:31,011', 'memory': '35.05GiB', 'tps': 63.0, 'tflops': 1.02}
# Latency between step 4 and step 5: 16.343 seconds
# Latency between step 5 and step 6: 16.565 seconds
# Latency between step 6 and step 7: 16.875 seconds
# Latency between step 7 and step 8: 16.419 seconds
# Latency between step 8 and step 9: 16.305 seconds
# Latency between step 9 and step 10: 16.201 seconds
# output-opus-l_50-provision-cuda-pre, avg step latency: 16.451 seconds, std: 0.220 seconds, min: 16.201 seconds
# Latency data appended to latency_results_provision-cuda-pre.csv
# Latency data saved to latency_results_provision-cuda-pre.csv
# output-opus-l_100-provision-cuda-pre
# Step 1: {'timestamp': '2026-02-03 04:13:31,869', 'memory': '27.38GiB', 'tps': 20.0, 'tflops': 0.32}
# Step 2: {'timestamp': '2026-02-03 04:13:48,674', 'memory': '34.66GiB', 'tps': 61.0, 'tflops': 0.98}
# Step 3: {'timestamp': '2026-02-03 04:14:05,466', 'memory': '34.95GiB', 'tps': 61.0, 'tflops': 0.98}
# Step 4: {'timestamp': '2026-02-03 04:14:22,030', 'memory': '34.96GiB', 'tps': 62.0, 'tflops': 0.99}
# Step 5: {'timestamp': '2026-02-03 04:14:38,409', 'memory': '34.96GiB', 'tps': 63.0, 'tflops': 1.0}
# Step 6: {'timestamp': '2026-02-03 04:14:54,912', 'memory': '34.77GiB', 'tps': 62.0, 'tflops': 1.0}
# Step 7: {'timestamp': '2026-02-03 04:15:11,094', 'memory': '34.77GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 8: {'timestamp': '2026-02-03 04:15:27,243', 'memory': '34.96GiB', 'tps': 63.0, 'tflops': 1.02}
# Step 9: {'timestamp': '2026-02-03 04:15:43,342', 'memory': '35.05GiB', 'tps': 64.0, 'tflops': 1.02}
# Step 10: {'timestamp': '2026-02-03 04:16:00,008', 'memory': '34.77GiB', 'tps': 61.0, 'tflops': 0.99}
# Latency between step 4 and step 5: 16.379 seconds
# Latency between step 5 and step 6: 16.503 seconds
# Latency between step 6 and step 7: 16.182 seconds
# Latency between step 7 and step 8: 16.149 seconds
# Latency between step 8 and step 9: 16.099 seconds
# Latency between step 9 and step 10: 16.666 seconds
# output-opus-l_100-provision-cuda-pre, avg step latency: 16.330 seconds, std: 0.205 seconds, min: 16.099 seconds
# Latency data appended to latency_results_provision-cuda-pre.csv
# Latency data saved to latency_results_provision-cuda-pre.csv
# output-opus-l_250-provision-cuda-pre
# Step 1: {'timestamp': '2026-02-03 04:24:05,602', 'memory': '26.91GiB', 'tps': 30.0, 'tflops': 0.48}
# Step 2: {'timestamp': '2026-02-03 04:24:23,132', 'memory': '34.57GiB', 'tps': 58.0, 'tflops': 0.94}
# Step 3: {'timestamp': '2026-02-03 04:24:41,157', 'memory': '34.38GiB', 'tps': 57.0, 'tflops': 0.91}
# Step 4: {'timestamp': '2026-02-03 04:24:58,787', 'memory': '34.57GiB', 'tps': 58.0, 'tflops': 0.93}
# Step 5: {'timestamp': '2026-02-03 04:25:16,439', 'memory': '34.38GiB', 'tps': 58.0, 'tflops': 0.93}
# Step 6: {'timestamp': '2026-02-03 04:25:33,574', 'memory': '34.96GiB', 'tps': 60.0, 'tflops': 0.96}
# Step 7: {'timestamp': '2026-02-03 04:25:51,064', 'memory': '34.96GiB', 'tps': 59.0, 'tflops': 0.94}
# Step 8: {'timestamp': '2026-02-03 04:26:08,186', 'memory': '35.14GiB', 'tps': 60.0, 'tflops': 0.96}
# Step 9: {'timestamp': '2026-02-03 04:26:25,546', 'memory': '35.14GiB', 'tps': 59.0, 'tflops': 0.95}
# Step 10: {'timestamp': '2026-02-03 04:26:42,761', 'memory': '34.96GiB', 'tps': 60.0, 'tflops': 0.96}
# Latency between step 4 and step 5: 17.652 seconds
# Latency between step 5 and step 6: 17.135 seconds
# Latency between step 6 and step 7: 17.490 seconds
# Latency between step 7 and step 8: 17.122 seconds
# Latency between step 8 and step 9: 17.360 seconds
# Latency between step 9 and step 10: 17.215 seconds
# output-opus-l_250-provision-cuda-pre, avg step latency: 17.329 seconds, std: 0.194 seconds, min: 17.122 seconds
# Latency data appended to latency_results_provision-cuda-pre.csv
# Latency data saved to latency_results_provision-cuda-pre.csv
# output-opus-l_500-provision-cuda-pre
# Step 1: {'timestamp': '2026-02-03 04:31:17,568', 'memory': '27.28GiB', 'tps': 29.0, 'tflops': 0.47}
# Step 2: {'timestamp': '2026-02-03 04:31:36,534', 'memory': '34.38GiB', 'tps': 54.0, 'tflops': 0.87}
# Step 3: {'timestamp': '2026-02-03 04:31:55,577', 'memory': '34.77GiB', 'tps': 54.0, 'tflops': 0.86}
# Step 4: {'timestamp': '2026-02-03 04:32:14,268', 'memory': '34.76GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 5: {'timestamp': '2026-02-03 04:32:32,879', 'memory': '35.16GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 6: {'timestamp': '2026-02-03 04:32:51,369', 'memory': '34.96GiB', 'tps': 55.0, 'tflops': 0.89}
# Step 7: {'timestamp': '2026-02-03 04:33:10,253', 'memory': '34.96GiB', 'tps': 54.0, 'tflops': 0.87}
# Step 8: {'timestamp': '2026-02-03 04:33:28,875', 'memory': '35.16GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 9: {'timestamp': '2026-02-03 04:33:47,481', 'memory': '34.96GiB', 'tps': 55.0, 'tflops': 0.88}
# Step 10: {'timestamp': '2026-02-03 04:34:05,743', 'memory': '35.04GiB', 'tps': 56.0, 'tflops': 0.9}
# Latency between step 4 and step 5: 18.611 seconds
# Latency between step 5 and step 6: 18.490 seconds
# Latency between step 6 and step 7: 18.884 seconds
# Latency between step 7 and step 8: 18.622 seconds
# Latency between step 8 and step 9: 18.606 seconds
# Latency between step 9 and step 10: 18.262 seconds
# output-opus-l_500-provision-cuda-pre, avg step latency: 18.579 seconds, std: 0.185 seconds, min: 18.262 seconds
# Latency data appended to latency_results_provision-cuda-pre.csv
# Latency data saved to latency_results_provision-cuda-pre.csv

# %% [markdown]
# The previous result show that this experiment has 12 reconfigurations per step

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

colors = [
    "#1f77b4",  # blue
    "#ff7f0e",  # orange
    "#2ca02c",  # green
    "#d62728",  # red
    "#9467bd",  # purple
    "#8c564b",  # brown
    "#e377c2",  # pink
    "#7f7f7f",  # gray
    "#bcbd22",  # olive
    "#17becf",  # cyan
]
fontsize=14

# Ensure the experiments are plotted in the specified order
experiments_1 = [
    'output-opus-l_0-baseline',
    'output-opus-l_10-baseline',
    'output-opus-l_50-baseline',
    'output-opus-l_100-baseline',
    'output-opus-l_250-baseline',
    'output-opus-l_500-baseline',
    'output-opus-l_750-baseline',
    'output-opus-l_1000-baseline',
]

experiments_2 = [
    'output-opus-l_0-provision',
    'output-opus-l_10-provision',
    'output-opus-l_50-provision',
    'output-opus-l_100-provision',
    'output-opus-l_250-provision',
    'output-opus-l_500-provision',
    'output-opus-l_750-provision',
    'output-opus-l_1000-provision',
]

xlabels = ['0', '0.01', '0.05', '0.1', '0.25', '0.5', '0.75', '1']

baseline = 13.459833333333334
estimated = [baseline] + [baseline + 6 * 0.001 * l for l in latency]

# Read the first CSV file
output_file = 'latency_results_baseline.csv'
data = pd.read_csv(output_file)

# Group by Experiment and calculate the mean of Average Latency and Standard Deviation
data = data[data['Experiment'].isin(experiments_1)].copy()

data['Experiment'] = pd.Categorical(
    data['Experiment'],
    categories=experiments_1,
    ordered=True
)
grouped_data = data.sort_values('Experiment')
grouped_data = data.sort_values('Experiment')

# Read the second CSV file
output_file_2 = 'latency_results_provision.csv'
data_2 = pd.read_csv(output_file_2)
data_2 = data_2[data_2['Experiment'].isin(experiments_2)].copy()

# Group by Experiment and calculate the mean of Average Latency and Standard Deviation for the second file
data_2['Experiment'] = pd.Categorical(data_2['Experiment'], categories=experiments_2, ordered=True)
grouped_data_2 = data_2.sort_values('Experiment')

# Plot the data
plt.figure(figsize=(5, 3))
x = np.arange(len(xlabels))

bar_width = 0.35

# plt.bar(
#     x[0],
#     baseline,
#     bar_width * 2,
#     label='w/o Opus'
# )

# --------------------
# Remaining 10 categories: paired bars
# --------------------
plt.bar(
    x - bar_width / 2,
    grouped_data['Average Latency (s)'],
    bar_width,
    yerr=grouped_data['Standard Deviation (s)'],
    capsize=5,
    label='Opus Baseline'
)

plt.bar(
    x + bar_width / 2,
    grouped_data_2['Average Latency (s)'],
    bar_width,
    yerr=grouped_data_2['Standard Deviation (s)'],
    capsize=5,
    label='Opus Provision'
)

# Add a 1.x overhead on the top number
for i, (baseline_latency, provision_latency) in enumerate(zip(grouped_data['Average Latency (s)'], grouped_data_2['Average Latency (s)'])):
    plt.text(
        x[i] - bar_width / 2,
        baseline_latency + 0.1,
        f"{baseline_latency / baseline:.2f}",
        ha='center',
        va='bottom',
        fontsize=8,
        rotation=60  # Tilt the number by 45 degrees
    )
    plt.text(
        x[i] + bar_width / 2,
        provision_latency + 0.1,
        f"{provision_latency / baseline:.2f}",
        ha='center',
        va='bottom',
        fontsize=8,
        rotation=60  # Tilt the number by 45 degrees
    )

# plt.plot(
#     xlabels, 
#     estimated, 
#     marker='o', 
#     markersize=4,  # Make the dot smaller
#     linestyle='dashed', 
#     linewidth=1,  # Make the line thinner
#     label='Estimated'
# )
# Add labels and legend
plt.xticks(x, xlabels)
plt.xlabel('Reconfig Latency (s)')
plt.ylabel('Avg Step Latency (s)')
plt.ylim(0, 32)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

colors = [
    "#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd",
    "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf",
]

fontsize = 14

experiments_1 = [
    'output-opus-l_0-baseline',
    'output-opus-l_10-baseline',
    'output-opus-l_50-baseline',
    'output-opus-l_100-baseline',
    'output-opus-l_250-baseline',
    'output-opus-l_500-baseline',
    'output-opus-l_750-baseline',
    'output-opus-l_1000-baseline',
]

experiments_2 = [
    'output-opus-l_0-provision',
    'output-opus-l_10-provision',
    'output-opus-l_50-provision',
    'output-opus-l_100-provision',
    'output-opus-l_250-provision',
    'output-opus-l_500-provision',
    'output-opus-l_750-provision',
    'output-opus-l_1000-provision',
]

latency = [0, 0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 1]
xlabels = [str(l) for l in latency]

baseline = 13.459833333333334
estimated = [baseline + 6 * l for l in latency]  # matches your scale

# ---- Load data ----
data = pd.read_csv('latency_results_baseline.csv')
data = data[data['Experiment'].isin(experiments_1)].copy()
data['Experiment'] = pd.Categorical(data['Experiment'], categories=experiments_1, ordered=True)
grouped_data = data.sort_values('Experiment')

data_2 = pd.read_csv('latency_results_provision.csv')
data_2 = data_2[data_2['Experiment'].isin(experiments_2)].copy()
data_2['Experiment'] = pd.Categorical(data_2['Experiment'], categories=experiments_2, ordered=True)
grouped_data_2 = data_2.sort_values('Experiment')

# ---- Plot ----
plt.figure(figsize=(5, 3))
x = np.arange(len(latency))

# Opus Baseline line
plt.plot(
    x,
    grouped_data['Average Latency (s)'],
    marker='o',
    linewidth=2,
    label='Opus Baseline',
    color=colors[0]
)

# Opus Provision line
plt.plot(
    x,
    grouped_data_2['Average Latency (s)'],
    marker='s',
    linewidth=2,
    label='Opus Provision',
    color=colors[1]
)

# Estimated dashed line
plt.plot(
    x,
    estimated,
    linestyle='dashed',
    linewidth=1.5,
    marker='o',
    markersize=4,
    label='Estimated',
    color=colors[2]
)

# Horizontal baseline dashed line
plt.axhline(
    y=baseline,
    linestyle='dashed',
    linewidth=1.5,
    color=colors[3],
    label='Native'
)

# ---- Overhead annotations ----
for i, (base_lat, prov_lat) in enumerate(zip(
    grouped_data['Average Latency (s)'],
    grouped_data_2['Average Latency (s)']
)):
    plt.text(x[i], base_lat + 0.1, f"{base_lat / baseline:.2f}",
             ha='center', fontsize=8, rotation=60)
    plt.text(x[i], prov_lat + 0.1, f"{prov_lat / baseline:.2f}",
             ha='center', fontsize=8, rotation=60)

# ---- Labels ----
plt.xticks(x, xlabels)
plt.xlabel('Reconfig Latency (s)', fontsize=fontsize)
plt.ylabel('Avg Step Latency (s)', fontsize=fontsize)
plt.ylim(10, 25)
plt.legend(loc='upper left', fontsize=fontsize)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 3))

xlabels = ['0', '10', '50', '100', '250', '500', '750', '1000']
x = np.arange(len(xlabels))

# plt.bar(
#     x[0],
#     baseline,
#     bar_width * 2,
#     label='w/o Opus'
# )

# --------------------
# Remaining 10 categories: paired bars
# --------------------
plt.bar(
    x - bar_width / 2,
    grouped_data['Average Latency (s)'] / baseline,
    bar_width,
    # yerr=grouped_data['Standard Deviation (s)'],
    capsize=5,
    label='Opus Baseline'
)

plt.bar(
    x + bar_width / 2,
    grouped_data_2['Average Latency (s)'] / baseline,
    bar_width,
    # yerr=grouped_data_2['Standard Deviation (s)'],
    capsize=5,
    label='Opus Provision'
)

# Add a 1.x overhead on the top number
for i, (baseline_latency, provision_latency) in enumerate(zip(grouped_data['Average Latency (s)'], grouped_data_2['Average Latency (s)'])):
    plt.text(
        x[i] - bar_width / 2,
        baseline_latency / baseline + 0.1,
        f"{baseline_latency / baseline:.2f}",
        ha='center',
        va='bottom',
        fontsize=8,
        rotation=60  # Tilt the number by 45 degrees
    )
    plt.text(
        x[i] + bar_width / 2,
        provision_latency / baseline + 0.1,
        f"{provision_latency / baseline:.2f}",
        ha='center',
        va='bottom',
        fontsize=8,
        rotation=60  # Tilt the number by 45 degrees
    )

# plt.plot(
#     xlabels, 
#     estimated, 
#     marker='o', 
#     markersize=4,  # Make the dot smaller
#     linestyle='dashed', 
#     linewidth=1,  # Make the line thinner
#     label='Estimated'
# )
# Add labels and legend
plt.xticks(x, xlabels)
plt.xlabel('Reconfig Latency (ms)')
plt.ylabel('Normalized Step Latency (s)')
plt.ylim(0, 2)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #TODO I recommend changing X axis to milliseconds and going up to 500 milliseconds
